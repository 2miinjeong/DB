# %%
import requests

# TMDB API 키
TMDB_API_KEY = 'cd88d12bfe4c5d842ef9a464b2f0bcd1'
language = 'ko'

#TV SERIES LISTS > POPULAR
#인기있는 tv 시리즈 출력을 위한 API
def fetch_popular_series(language='ko-KR', region='KR'):
    url = f'https://api.themoviedb.org/3/tv/popular'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'region': region,
        'page': 1  
    }

    response = requests.get(url, params=params)
    data = response.json()
    return data['results']
    #반환된 data 중 results가 포함하고 있는 리스트들 저장

#TV SERIES > DETAILS
def fetch_series_details(series_id, language='ko-KR'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'append_to_response': 'credits'  # 출연진 및 제작진 정보를 가져오기 위해 추가
    }

    response = requests.get(url, params=params)
    data = response.json()
    return data

#TV SERIES > IMAGES(로고, 포스터 이미지)
def fetch_series_images(series_id, language='ko'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/images'
   
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'append_to_response': 'credits'  # 출연진 및 제작진 정보를 가져오기 위해 추가
    }

    response = requests.get(url, params=params)
    data = response.json()
    
    # 한국어 포스터가 없거나 로고가 없을 시, 영어 이미지 출력
    if ('posters' not in data or len(data['posters']) == 0) or ('logos' not in data or len(data['logos']) == 0):
        params['language'] = 'en'
        response = requests.get(url, params=params)
        data = response.json()

        if 'posters' in data and len(data['posters']) > 0:
            data['posters'] = data['posters'][:1]
        if 'logos' in data and len(data['logos']) > 0:
            data['logos'] = data['logos'][:1]

    return data

#TV SERIES > VIDEOS
#TRAILER 
def fetch_series_videos(series_id, language='ko'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/videos'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language
    }
    response = requests.get(url, params=params)
    data = response.json()

    trailer_key = None
    for item in data.get('results', []):
        if item.get('type') == 'Trailer':
            trailer_key = item.get('key')
            break

    return trailer_key

def print_series_info(series, series_images, series_videos):
    print("id:", series['id'])
    print("제목:", series['name'])
    print("장르:", ", ".join([genre['name'] for genre in series['genres']]))
    print("회차 정보:", f"{series['number_of_episodes']}")
    print("줄거리:", series['overview'])
    
    #CAST
    if 'credits' in series and 'cast' in series['credits']:
        print("출연진:")
        for cast in series['credits']['cast'][:3]:
            print(f"- {cast['name']}")
    
    #CREW
    if 'credits' in series and 'crew' in series['credits']:
        print("제작진:")
        if series['credits']['crew']:  # 제작진 정보가 있는 경우에만 출력
            crew = series['credits']['crew'][0]  # 첫 번째 제작진 정보만 출력
            print(f"- {crew['name']}")
    
    #LOGO
    if 'logos' in series_images:
        for logo in series_images['logos']:
            print("로고 URL:", f"https://image.tmdb.org/t/p/original{logo['file_path']}")

    #POSTER_URL
    if 'posters' in series_images:
         for poster in series_images['posters']:
            print("포스터 URL:", f"https://image.tmdb.org/t/p/original{poster['file_path']}")

    #TRAILER_URL
    if 'results' in series_videos:
        for video in series_videos['results']:
            print("예고편 URL:", f"https://www.youtube.com/watch?v={results['key']}")

def main():
    popular_tv_series = fetch_popular_series()

    for series in popular_tv_series:
        series_details = fetch_series_details(series['id'])
        series_images = fetch_series_images(series['id'])
        print_series_info(series_details, series_images)
        print()

if __name__ == "__main__":
    main()
# Out:
# id: 2734
# 제목: 로 앤 오더: 성범죄 전담반
# 장르: 범죄, 드라마, 미스터리
# 회차 정보: 551
# 줄거리: 추악한 성범죄를 수사하는 뉴욕 경찰 성범죄전담수사반의 활약을 그린 드라마.
# 출연진:
# - 마리슈카 하기테이
# - Ice-T
# - Peter Scanavino
# 제작진:
# - Dick Wolf
# 로고 URL: https://image.tmdb.org/t/p/original/AhtQAQVcqWl6b0UZSo9vmHE3skK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/onmSVwYsPMYtO8OjLdjS8FfRNKb.jpg
# 예고편 URL: https://www.themoviedb.org/tv/2734/videos
#
# id: 82873
# 제목: The Kelly Clarkson Show
# 장르: Talk
# 회차 정보: 605
# 줄거리:
# 출연진:
# - Kelly Clarkson
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/9Gg1oM8Us8gCS5aJA8e0ZRuIHnf.jpg
# 예고편 URL: https://www.themoviedb.org/tv/82873/videos
#
# id: 59941
# 제목: The Tonight Show Starring Jimmy Fallon
# 장르: 코미디, Talk
# 회차 정보: 1379
# 줄거리:
# 출연진:
# - 지미 팰런
# - Steve Higgins
# 제작진:
# - Lorne Michaels
# 포스터 URL: https://image.tmdb.org/t/p/original/g4amxJvtpnY79J77xeamnAEUO8r.jpg
# 예고편 URL: https://www.themoviedb.org/tv/59941/videos
#
# id: 1416
# 제목: 그레이 아나토미
# 장르: 드라마
# 회차 정보: 429
# 줄거리: 시애틀에 있는 병원 의사들의 삶에 대한 이야기. 의사로서의 감정과 개인적인 감정에 대한 묘사가 적절히 조화를 이루어 그려진다. 인턴이지만 결국 레지던트가 되는 메러디스 그레이는 시애틀 병원의 동료 의사들과 함께 사적, 직업적인 열정에 휩쓸리는 자신을 발견한다.
# 출연진:
# - 엘렌 폼페오
# - Chandra Wilson
# - James Pickens Jr.
# 제작진:
# - 숀다 라임스
# 로고 URL: https://image.tmdb.org/t/p/original/keAZqhg9lmOHEhmG5njqIsuxf0f.png
# 포스터 URL: https://image.tmdb.org/t/p/original/jcEl8SISNfGdlQFwLzeEtsjDvpw.jpg
# 예고편 URL: https://www.themoviedb.org/tv/1416/videos
#
# id: 1620
# 제목: CSI: 마이애미
# 장르: 드라마, 미스터리, 범죄
# 회차 정보: 232
# 줄거리: 플로리다 주의 마이애미 데이드 경찰청. 호레이쇼 반장과 CSI 과학 수사 대원들은 논리적인 증거 분석과 본능적인 수사로 마이애미에서 일어나는 위험한 범죄들을 해결해나간다.
# 출연진:
# - David Caruso
# - Emily Procter
# - Omar Benson Miller
# 제작진:
# - Scott Lautanen
# 로고 URL: https://image.tmdb.org/t/p/original/gnThzFN5qgTW3vKLl5mVlqRBQ5T.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pNW64pjaHvf6purNaFhq4SHYRfl.jpg
# 예고편 URL: https://www.themoviedb.org/tv/1620/videos
#
# id: 1431
# 제목: CSI: 라스베가스
# 장르: 범죄, 드라마, 미스터리
# 회차 정보: 335
# 줄거리: 2000년 10월 CBS에서 방영을 시작한 범죄수사물. 최첨단 장비와 과학적인 분석으로 미궁속의 사건을 해결해 가는 라스베가스 시경 과학수사과 심야근무반. 17년 경력의 베테랑 길 그리섬, 혼자서 키우는 딸과 직장 사이에 균형을 잃지 않으며 항상 최선을 다하는 캐서린 윌로스, 도박의 유혹을 뿌리치지 못하지만 날카로운 분석력을 보유한 워릭 브라운, 하바드 출신의 새라 사이들, 그리고 매력적인 남자 닉 스톡스 등 5명이 한 팀으로 구성된 이들은 사건이 미궁에 빠질 때마다 첨단 기술과 예리한 분석력으로 결정적인 단서와 증거를 확보하여 진범을 가려내기 위해 365일 24시간을 투자한다.
# 출연진:
# - Ted Danson
# - George Eads
# - Jorja Fox
# 제작진:
# - Andi Brittan
# 로고 URL: https://image.tmdb.org/t/p/original/fLhKSEsurxHq3mwEDvCQhnApxkg.png
# 포스터 URL: https://image.tmdb.org/t/p/original/i5hmoRjHNWady4AtAGICTUXknKH.jpg
# 예고편 URL: https://www.themoviedb.org/tv/1431/videos
#
# id: 4556
# 제목: 스크럽스
# 장르: 코미디
# 회차 정보: 182
# 줄거리:
# 출연진:
# - 잭 브래프
# - Donald Faison
# - John C. McGinley
# 제작진:
# - 잭 브래프
# 로고 URL: https://image.tmdb.org/t/p/original/6lCg07nxaLGpEap849catTySkvi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/u1z05trCA7AuSuDhi365grwdos1.jpg
# 예고편 URL: https://www.themoviedb.org/tv/4556/videos
#
# id: 61818
# 제목: Late Night with Seth Meyers
# 장르: Talk, 코미디
# 회차 정보: 1512
# 줄거리:
# 출연진:
# - Seth Meyers
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/g6MrJxNaHYGYU7Sxo72e5B8gKOV.jpg
# 예고편 URL: https://www.themoviedb.org/tv/61818/videos
#
# id: 1438
# 제목: 더 와이어
# 장르: 범죄, 드라마
# 회차 정보: 60
# 줄거리: 2002년 6월 HBO에서 방영을 시작한 범죄수사물. 볼티모어에서 일어난 살인 사건의 범인으로 지목된 마약 딜러 에이본 박스데일의 조카 디안젤로. 그가 증인의 진술 번복으로 풀려나자 이를 수상하게 여긴 강력계 형사 맥널티는 특별전담팀을 꾸린다.
# 출연진:
# - Dominic West
# - 랜스 레딕
# - Sonja Sohn
# 제작진:
# - Joe Chappelle
# 로고 URL: https://image.tmdb.org/t/p/original/cP5IrOYxU7qtFl3Gyjtj9iPufCn.png
# 포스터 URL: https://image.tmdb.org/t/p/original/4lbclFySvugI51fwsyxBTOm4DqK.jpg
# 예고편 URL: https://www.themoviedb.org/tv/1438/videos
#
# id: 4376
# 제목: JAG
# 장르: 드라마, Action & Adventure, 범죄
# 회차 정보: 227
# 줄거리:
# 출연진:
# - David James Elliott
# - Catherine Bell
# - Patrick Labyorteaux
# 제작진:
# - Donald P. Bellisario
# 로고 URL: https://image.tmdb.org/t/p/original/ac4uUoKUD0kTxXHm04dp7u10ksc.png
# 포스터 URL: https://image.tmdb.org/t/p/original/zPyHpkJZ5O08lbgrQQIROXtb3xz.jpg
# 예고편 URL: https://www.themoviedb.org/tv/4376/videos
#
# id: 34307
# 제목: 쉐임리스
# 장르: 드라마, 코미디
# 회차 정보: 134
# 줄거리: 미국 시카고 후미진 마을에서 힘겹게 살고 있는 싱글 대디 프랭크와 총명하고 독립적인 그의 여섯 자녀들의 리얼한 이야기
# 출연진:
# - 윌리엄 H. 메이시
# - 제레미 앨런 화이트
# - Ethan Cutkosky
# 제작진:
# - John Wells
# 로고 URL: https://image.tmdb.org/t/p/original/vmxGfz06Eha0n1UvSckq907wFFz.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9akij7PqZ1g6zl42DQQTtL9CTSb.jpg
# 예고편 URL: https://www.themoviedb.org/tv/34307/videos
#
# id: 57243
# 제목: 닥터 후
# 장르: Action & Adventure, 드라마, Sci-Fi & Fantasy
# 회차 정보: 153
# 줄거리: 타임로드라는 종족의 외계인인 닥터가 그의 동료들과 함께 시공간을 누비는 여행을 하며 때때로 지구와 인류 그리고 우주를 구하는 이야기.
# 출연진:
# - Jodie Whittaker
# - Mandip Gill
# - John Bishop
# 제작진:
# - Claire Pritchard
# 로고 URL: https://image.tmdb.org/t/p/original/r6aeDXC3UE8PfzdorYfQWpPJTho.png
# 포스터 URL: https://image.tmdb.org/t/p/original/4edFyasCrkH4MKs6H4mHqlrxA6b.jpg
# 예고편 URL: https://www.themoviedb.org/tv/57243/videos
#
# id: 1396
# 제목: 브레이킹 배드
# 장르: 드라마, 범죄
# 회차 정보: 62
# 줄거리: 2008년 1월 AMC에서 방영을 시작한 범죄 스릴러. Breaking Bad는 막가기를 뜻하는 미국 남부 지방의 속어이다. 한때 노벨화학상까지 바라 볼 정도로 뛰어난 과학자였던 고등학교 화학 교사 월터 화이트는 자신의 50세 생일 날에 폐암 3기 진단을 받는다. 어느 날 동서와 함께 마약 단속 현장을 참관한 그는 현장에서 달아나는 옛 제자 제시를 발견한다. 뇌성마비에 걸린 고등학생 아들과 임신한 아내를 위해 제시에게 동업을 제의한 월터는 자신의 화학지식을 이용해 전례없는 고순도 고품질의 메스암페타민을 제조한다.
# 출연진:
# - 브라이언 크랜스턴
# - 아론 폴
# - 애나 건
# 제작진:
# - Jennifer Bryan
# 로고 URL: https://image.tmdb.org/t/p/original/chw44B2VnLha8iiTdyZcIW0ZELC.png
# 포스터 URL: https://image.tmdb.org/t/p/original/ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg
# 예고편 URL: https://www.themoviedb.org/tv/1396/videos
#
# id: 4604
# 제목: 스몰빌
# 장르: Sci-Fi & Fantasy, Action & Adventure, 드라마
# 회차 정보: 216
# 줄거리: 우리에게 슈퍼맨으로 친숙한 클라크 켄트의 유년기를 새로이 재조명한 워너 브라더스사의 SF시리즈물 드라마
# 출연진:
# - Tom Welling
# - Erica Durance
# - Cassidy Freeman
# 제작진:
# - Alfredo Septién
# 로고 URL: https://image.tmdb.org/t/p/original/ePZAsSSkT2G0j1F1U13ZE675N6I.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pUhJGETy2sec4vEkiqJ9eGeIywc.jpg
# 예고편 URL: https://www.themoviedb.org/tv/4604/videos
#
# id: 1695
# 제목: 몽크
# 장르: 코미디, 범죄, 드라마, 미스터리
# 회차 정보: 125
# 줄거리: 현대 샌프란시스코를 배경으로 하는 코미디 수사물 미드. 3년 전 자동차 폭발 사건으로 아내를 잃은이후 큰 충격에서 빠져나오지 못한 채, 독특한 강박관념에 사로잡혀 많은 사람들이 모인 군중과 높은 곳, 그리고 어둠을 두려워하는 증세를 보이는 전직 경찰 에이드리언 몽크가 샌프란시스코 경찰을 도와 복잡한 사건들을 해결한다.
# 출연진:
# - 토니 샬호브
# - 테드 러바인
# - Jason Gray-Stanford
# 제작진:
# - Tom Scharpling
# 로고 URL: https://image.tmdb.org/t/p/original/pIOqR6IchhSOmaIZIyDGW9QB982.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/3axGMbUecXXOPSeG47v2i9wK5y5.jpg
# 예고편 URL: https://www.themoviedb.org/tv/1695/videos
#
# id: 4419
# 제목: 리얼 타임 위드 빌 마허
# 장르: 코미디, Talk
# 회차 정보: 659
# 줄거리:
# 출연진:
# - Bill Maher
# 제작진:
# - Alessio Pollacci
# 포스터 URL: https://image.tmdb.org/t/p/original/pbpoLLp4kvnYVfnEGiEhagpJuVZ.jpg
# 예고편 URL: https://www.themoviedb.org/tv/4419/videos
#
# id: 4601
# 제목: 로 앤 오더: 크리미널 인텐트
# 장르: 드라마
# 회차 정보: 195
# 줄거리:
# 출연진:
# - 빈센트 도노프리오
# - Kathryn Erbe
# - 줄리아 오먼드
# 제작진:
# - Peter Jankowski
# 로고 URL: https://image.tmdb.org/t/p/original/zzNoDbK0vvAOdZIzUiwKUjbwyyO.png
# 포스터 URL: https://image.tmdb.org/t/p/original/68MUdrxeokhmd8pvlAjkD6yIfHR.jpg
# 예고편 URL: https://www.themoviedb.org/tv/4601/videos
#
# id: 1412
# 제목: 애로우
# 장르: 범죄, 드라마, Action & Adventure
# 회차 정보: 170
# 줄거리: 스탈링 시티의 잘나가는 재벌 2세 올리버 퀸은 아버지와 보트 여행에 나섰다가 태풍을 만나 난파를 당한다. 그는 5년 동안 외딴 섬에 표류되어 생존을 위한 처절한 사투를 벌이고 마침내 고향으로 돌아온다. 아버지의 유언에 따라 스탈링 시티의 엘리트 범죄자들을 사냥하기위해 스스로 자경단원을 자처하는 올리버퀸. 그러나 그의 앞날에는 그의 상상보다 더 큰 진실과 음모가 기다리고 있는데...
# 출연진:
# - Stephen Amell
# - David Ramsey
# - Katie Cassidy
# 제작진:
# - Mark Bunting
# 로고 URL: https://image.tmdb.org/t/p/original/jUu02PexmdU5xAeDYsv1huceChE.png
# 포스터 URL: https://image.tmdb.org/t/p/original/gKG5QGz5Ngf8fgWpBsWtlg5L2SF.jpg
# 예고편 URL: https://www.themoviedb.org/tv/1412/videos
#
# id: 206559
# 제목: Binnelanders
# 장르: Soap
# 회차 정보: 4592
# 줄거리:
# 출연진:
# - Hans Strydom
# - Reynardt Hugo
# - Hykie Berg
# 제작진:
# - Jak de Priester
# 예고편 URL: https://www.themoviedb.org/tv/206559/videos
#
# id: 2316
# 제목: 오피스
# 장르: 코미디
# 회차 정보: 186
# 줄거리: 팬실베니아 스크랜튼에 위치한 사무용지 판매회사 던더 미플린의 스크랜턴 지점. 무미건조한 사무실에서 깐깐한 지점장과 독특한 캐릭터의 부하들이 벌이는 코믹 해프닝과 가슴 찡한 이야기가 펼쳐진다. BBC에서 방영된 동명 영국 시리즈의 할리우드 리메이크.
# 출연진:
# - Rainn Wilson
# - 존 크래신스키
# - 제나 피셔
# 제작진:
# - Steve Burgess
# 로고 URL: https://image.tmdb.org/t/p/original/zWozteGoJM0NhHj5lhXSqhu6rUA.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7DJKHzAi83BmQrWLrYYOqcoKfhR.jpg
# 예고편 URL: https://www.themoviedb.org/tv/2316/videos

# %%
import requests

# TMDB API 키
TMDB_API_KEY = 'cd88d12bfe4c5d842ef9a464b2f0bcd1'
language = 'ko'

#TV SERIES LISTS > POPULAR
#인기있는 tv 시리즈 출력을 위한 API
def fetch_popular_series(language='ko-KR', region='KR'):
    url = f'https://api.themoviedb.org/3/tv/popular'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'region': region,
        'page': 1  # 첫 페이지만 가져옴
    }

    response = requests.get(url, params=params)
    data = response.json()
    return data['results']
    #반환된 data 중 results가 포함하고 있는 리스트들 저장

#TV SERIES > DETAILS
def fetch_series_details(series_id, language='ko-KR'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'append_to_response': 'credits'  # 출연진 및 제작진 정보를 가져오기 위해 추가
    }

    response = requests.get(url, params=params)
    data = response.json()
    
    if 'overview' not in data or not data['overview']:
        params['language'] = 'en'
        response = requests.get(url, params=params)
        data = response.json()

    return data

#TV SERIES > IMAGES(로고, 포스터 이미지)
def fetch_series_images(series_id, language='ko'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/images'
   
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'append_to_response': 'credits'  # 출연진 및 제작진 정보를 가져오기 위해 추가
    }

    response = requests.get(url, params=params)
    data = response.json()
    
    # 한국어 포스터가 없거나 로고가 없을 시, 영어 이미지 출력
    if ('posters' not in data or len(data['posters']) == 0) or ('logos' not in data or len(data['logos']) == 0):
        params['language'] = 'en'
        response = requests.get(url, params=params)
        data = response.json()

        if 'posters' in data and len(data['posters']) > 0:
            data['posters'] = data['posters'][:1]
        if 'logos' in data and len(data['logos']) > 0:
            data['logos'] = data['logos'][:1]

    return data

#TV SERIES > VIDEOS
#TRAILER 
def fetch_series_videos(series_id, language='en'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/videos'

    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
    }
    response = requests.get(url, params=params)
    data = response.json()

    key_mapping = {
        'Trailer': 'trailer',
        'Clip': 'clip',
        'Teaser': 'teaser',
        'Opening Credits': 'opening_credits'
    }

    for item in data.get('results', []):
        video_type = item.get('type')
        if video_type in key_mapping:
            return item.get('key')

    return None


def print_series_info(series, series_images, series_videos):
    print("id:", series['id'])
    print("제목:", series['name'])
    print("장르:", ", ".join([genre['name'] for genre in series['genres']]))
    print("회차 정보:", f"{series['number_of_episodes']}")
    print("줄거리:", series['overview'])
    
    #CAST
    if 'credits' in series and 'cast' in series['credits']:
        print("출연진:")
        for cast in series['credits']['cast'][:3]:
            print(f"- {cast['name']}")
    
    #CREW
    if 'credits' in series and 'crew' in series['credits']:
        print("제작진:")
        if series['credits']['crew']:  # 제작진 정보가 있는 경우에만 출력
            crew = series['credits']['crew'][0]  # 첫 번째 제작진 정보만 출력
            print(f"- {crew['name']}")
    
    #LOGO
    if 'logos' in series_images:
        for logo in series_images['logos']:
            print("로고 URL:", f"https://image.tmdb.org/t/p/original{logo['file_path']}")

    #POSTER_URL
    if 'posters' in series_images:
         for poster in series_images['posters']:
            print("포스터 URL:", f"https://image.tmdb.org/t/p/original{poster['file_path']}")

    #TRAILER_URL
    if series_videos is not None:  # 시리즈 비디오 정보가 있는 경우에만 출력
        print("예고편 URL:", f"https://www.youtube.com/watch?v={series_videos}")

def main():
    popular_tv_series = fetch_popular_series()

    for series in popular_tv_series:
        series_details = fetch_series_details(series['id'])
        series_images = fetch_series_images(series['id'])
        series_videos = fetch_series_videos(series['id'])  # 영상 정보 가져오기 추가
        print_series_info(series_details, series_images, series_videos)  # 영상 정보 전달
        print()

if __name__ == "__main__":
    main()
# Out:
# id: 2734
# 제목: 로 앤 오더: 성범죄 전담반
# 장르: 범죄, 드라마, 미스터리
# 회차 정보: 551
# 줄거리: 추악한 성범죄를 수사하는 뉴욕 경찰 성범죄전담수사반의 활약을 그린 드라마.
# 출연진:
# - 마리슈카 하기테이
# - Ice-T
# - Peter Scanavino
# 제작진:
# - Dick Wolf
# 로고 URL: https://image.tmdb.org/t/p/original/AhtQAQVcqWl6b0UZSo9vmHE3skK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/onmSVwYsPMYtO8OjLdjS8FfRNKb.jpg
# 예고편 URL: https://www.youtube.com/watch?v=IRXNVdiqMuU
#
# id: 82873
# 제목: The Kelly Clarkson Show
# 장르: Talk
# 회차 정보: 605
# 줄거리: Kelly Clarkson presents the biggest newsmakers and names in film, television and music; as well as emerging new talent and everyday people who are beacons of hope in their communities.
# 출연진:
# - Kelly Clarkson
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/9Gg1oM8Us8gCS5aJA8e0ZRuIHnf.jpg
# 예고편 URL: https://www.youtube.com/watch?v=BhrdON83gqk
#
# id: 59941
# 제목: The Tonight Show Starring Jimmy Fallon
# 장르: Comedy, Talk
# 회차 정보: 1379
# 줄거리: After Jay Leno's second retirement from the program, Jimmy Fallon stepped in as his permanent replacement. After 42 years in Los Angeles the program was brought back to New York.
# 출연진:
# - Jimmy Fallon
# - Steve Higgins
# 제작진:
# - Mario Martines
# 포스터 URL: https://image.tmdb.org/t/p/original/g4amxJvtpnY79J77xeamnAEUO8r.jpg
#
# id: 1416
# 제목: 그레이 아나토미
# 장르: 드라마
# 회차 정보: 429
# 줄거리: 시애틀에 있는 병원 의사들의 삶에 대한 이야기. 의사로서의 감정과 개인적인 감정에 대한 묘사가 적절히 조화를 이루어 그려진다. 인턴이지만 결국 레지던트가 되는 메러디스 그레이는 시애틀 병원의 동료 의사들과 함께 사적, 직업적인 열정에 휩쓸리는 자신을 발견한다.
# 출연진:
# - 엘렌 폼페오
# - Chandra Wilson
# - James Pickens Jr.
# 제작진:
# - 숀다 라임스
# 로고 URL: https://image.tmdb.org/t/p/original/keAZqhg9lmOHEhmG5njqIsuxf0f.png
# 포스터 URL: https://image.tmdb.org/t/p/original/jcEl8SISNfGdlQFwLzeEtsjDvpw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qbkEtYz9acA
#
# id: 1620
# 제목: CSI: 마이애미
# 장르: 드라마, 미스터리, 범죄
# 회차 정보: 232
# 줄거리: 플로리다 주의 마이애미 데이드 경찰청. 호레이쇼 반장과 CSI 과학 수사 대원들은 논리적인 증거 분석과 본능적인 수사로 마이애미에서 일어나는 위험한 범죄들을 해결해나간다.
# 출연진:
# - David Caruso
# - Emily Procter
# - Omar Benson Miller
# 제작진:
# - Scott Lautanen
# 로고 URL: https://image.tmdb.org/t/p/original/gnThzFN5qgTW3vKLl5mVlqRBQ5T.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pNW64pjaHvf6purNaFhq4SHYRfl.jpg
# 예고편 URL: https://www.youtube.com/watch?v=x2n-h9E8_ck
#
# id: 1431
# 제목: CSI: 라스베가스
# 장르: 범죄, 드라마, 미스터리
# 회차 정보: 335
# 줄거리: 2000년 10월 CBS에서 방영을 시작한 범죄수사물. 최첨단 장비와 과학적인 분석으로 미궁속의 사건을 해결해 가는 라스베가스 시경 과학수사과 심야근무반. 17년 경력의 베테랑 길 그리섬, 혼자서 키우는 딸과 직장 사이에 균형을 잃지 않으며 항상 최선을 다하는 캐서린 윌로스, 도박의 유혹을 뿌리치지 못하지만 날카로운 분석력을 보유한 워릭 브라운, 하바드 출신의 새라 사이들, 그리고 매력적인 남자 닉 스톡스 등 5명이 한 팀으로 구성된 이들은 사건이 미궁에 빠질 때마다 첨단 기술과 예리한 분석력으로 결정적인 단서와 증거를 확보하여 진범을 가려내기 위해 365일 24시간을 투자한다.
# 출연진:
# - Ted Danson
# - George Eads
# - Jorja Fox
# 제작진:
# - Andi Brittan
# 로고 URL: https://image.tmdb.org/t/p/original/fLhKSEsurxHq3mwEDvCQhnApxkg.png
# 포스터 URL: https://image.tmdb.org/t/p/original/i5hmoRjHNWady4AtAGICTUXknKH.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ApT1EYvrwuk
#
# id: 4556
# 제목: Scrubs
# 장르: Comedy
# 회차 정보: 182
# 줄거리: In the unreal world of Sacred Heart Hospital, John "J.D." Dorian learns the ways of medicine, friendship and life.
# 출연진:
# - Zach Braff
# - Donald Faison
# - John C. McGinley
# 제작진:
# - Josh Bycel
# 로고 URL: https://image.tmdb.org/t/p/original/6lCg07nxaLGpEap849catTySkvi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/u1z05trCA7AuSuDhi365grwdos1.jpg
# 예고편 URL: https://www.youtube.com/watch?v=zOgb3KIJDY8
#
# id: 61818
# 제목: Late Night with Seth Meyers
# 장르: Talk, Comedy
# 회차 정보: 1512
# 줄거리: Seth Meyers, who is "Saturday Night Live’s" longest serving anchor on the show’s wildly popular "Weekend Update," takes over as host of NBC’s "Late Night" — home to A-list celebrity guests, memorable comedy and the best in musical talent. As the Emmy Award-winning head writer for "SNL," Meyers has established a reputation for sharp wit and perfectly timed comedy, and has gained fame for his spot-on jokes and satire. Meyers takes his departure from "SNL" to his new post at "Late Night," as Jimmy Fallon moves to "The Tonight Show".
# 출연진:
# - Seth Meyers
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/g6MrJxNaHYGYU7Sxo72e5B8gKOV.jpg
# 예고편 URL: https://www.youtube.com/watch?v=rLwbzGyC6t4
#
# id: 1438
# 제목: 더 와이어
# 장르: 범죄, 드라마
# 회차 정보: 60
# 줄거리: 2002년 6월 HBO에서 방영을 시작한 범죄수사물. 볼티모어에서 일어난 살인 사건의 범인으로 지목된 마약 딜러 에이본 박스데일의 조카 디안젤로. 그가 증인의 진술 번복으로 풀려나자 이를 수상하게 여긴 강력계 형사 맥널티는 특별전담팀을 꾸린다.
# 출연진:
# - Dominic West
# - 랜스 레딕
# - Sonja Sohn
# 제작진:
# - Joe Chappelle
# 로고 URL: https://image.tmdb.org/t/p/original/cP5IrOYxU7qtFl3Gyjtj9iPufCn.png
# 포스터 URL: https://image.tmdb.org/t/p/original/4lbclFySvugI51fwsyxBTOm4DqK.jpg
# 예고편 URL: https://www.youtube.com/watch?v=uDcQbk78CSw
#
# id: 4376
# 제목: JAG
# 장르: Drama, Action & Adventure, Crime
# 회차 정보: 227
# 줄거리: Harmon "Harm" Rabb Jr. is a former pilot turned lawyer working for the military's JAG (Judge Advocate General) division, the elite legal wing of officers that prosecutes and defends those accused of military-related crimes. He works closely with Lt. Col. Sarah Mackenzie, and together they do what needs to be done to find the truth.
# 출연진:
# - David James Elliott
# - Catherine Bell
# - Patrick Labyorteaux
# 제작진:
# - Donald P. Bellisario
# 로고 URL: https://image.tmdb.org/t/p/original/ac4uUoKUD0kTxXHm04dp7u10ksc.png
# 포스터 URL: https://image.tmdb.org/t/p/original/zPyHpkJZ5O08lbgrQQIROXtb3xz.jpg
#
# id: 34307
# 제목: 쉐임리스
# 장르: 드라마, 코미디
# 회차 정보: 134
# 줄거리: 미국 시카고 후미진 마을에서 힘겹게 살고 있는 싱글 대디 프랭크와 총명하고 독립적인 그의 여섯 자녀들의 리얼한 이야기
# 출연진:
# - 윌리엄 H. 메이시
# - 제레미 앨런 화이트
# - Ethan Cutkosky
# 제작진:
# - John Wells
# 로고 URL: https://image.tmdb.org/t/p/original/vmxGfz06Eha0n1UvSckq907wFFz.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9akij7PqZ1g6zl42DQQTtL9CTSb.jpg
# 예고편 URL: https://www.youtube.com/watch?v=9tvkYS5cA58
#
# id: 57243
# 제목: 닥터 후
# 장르: Action & Adventure, 드라마, Sci-Fi & Fantasy
# 회차 정보: 153
# 줄거리: 타임로드라는 종족의 외계인인 닥터가 그의 동료들과 함께 시공간을 누비는 여행을 하며 때때로 지구와 인류 그리고 우주를 구하는 이야기.
# 출연진:
# - Jodie Whittaker
# - Mandip Gill
# - John Bishop
# 제작진:
# - Claire Pritchard
# 로고 URL: https://image.tmdb.org/t/p/original/r6aeDXC3UE8PfzdorYfQWpPJTho.png
# 포스터 URL: https://image.tmdb.org/t/p/original/4edFyasCrkH4MKs6H4mHqlrxA6b.jpg
# 예고편 URL: https://www.youtube.com/watch?v=8L1kU45poro
#
# id: 1396
# 제목: 브레이킹 배드
# 장르: 드라마, 범죄
# 회차 정보: 62
# 줄거리: 2008년 1월 AMC에서 방영을 시작한 범죄 스릴러. Breaking Bad는 막가기를 뜻하는 미국 남부 지방의 속어이다. 한때 노벨화학상까지 바라 볼 정도로 뛰어난 과학자였던 고등학교 화학 교사 월터 화이트는 자신의 50세 생일 날에 폐암 3기 진단을 받는다. 어느 날 동서와 함께 마약 단속 현장을 참관한 그는 현장에서 달아나는 옛 제자 제시를 발견한다. 뇌성마비에 걸린 고등학생 아들과 임신한 아내를 위해 제시에게 동업을 제의한 월터는 자신의 화학지식을 이용해 전례없는 고순도 고품질의 메스암페타민을 제조한다.
# 출연진:
# - 브라이언 크랜스턴
# - 아론 폴
# - 애나 건
# 제작진:
# - Jennifer Bryan
# 로고 URL: https://image.tmdb.org/t/p/original/chw44B2VnLha8iiTdyZcIW0ZELC.png
# 포스터 URL: https://image.tmdb.org/t/p/original/ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg
# 예고편 URL: https://www.youtube.com/watch?v=XZ8daibM3AE
#
# id: 4604
# 제목: 스몰빌
# 장르: Sci-Fi & Fantasy, Action & Adventure, 드라마
# 회차 정보: 216
# 줄거리: 우리에게 슈퍼맨으로 친숙한 클라크 켄트의 유년기를 새로이 재조명한 워너 브라더스사의 SF시리즈물 드라마
# 출연진:
# - Tom Welling
# - Erica Durance
# - Cassidy Freeman
# 제작진:
# - Alfredo Septién
# 로고 URL: https://image.tmdb.org/t/p/original/ePZAsSSkT2G0j1F1U13ZE675N6I.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pUhJGETy2sec4vEkiqJ9eGeIywc.jpg
# 예고편 URL: https://www.youtube.com/watch?v=70Y32si4yb8
#
# id: 1695
# 제목: 몽크
# 장르: 코미디, 범죄, 드라마, 미스터리
# 회차 정보: 125
# 줄거리: 현대 샌프란시스코를 배경으로 하는 코미디 수사물 미드. 3년 전 자동차 폭발 사건으로 아내를 잃은이후 큰 충격에서 빠져나오지 못한 채, 독특한 강박관념에 사로잡혀 많은 사람들이 모인 군중과 높은 곳, 그리고 어둠을 두려워하는 증세를 보이는 전직 경찰 에이드리언 몽크가 샌프란시스코 경찰을 도와 복잡한 사건들을 해결한다.
# 출연진:
# - 토니 샬호브
# - 테드 러바인
# - Jason Gray-Stanford
# 제작진:
# - Josh Siegal
# 로고 URL: https://image.tmdb.org/t/p/original/pIOqR6IchhSOmaIZIyDGW9QB982.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/3axGMbUecXXOPSeG47v2i9wK5y5.jpg
# 예고편 URL: https://www.youtube.com/watch?v=mftbaaU82Uc
#
# id: 4419
# 제목: Real Time with Bill Maher
# 장르: Comedy, Talk
# 회차 정보: 659
# 줄거리: Each week Bill Maher surrounds himself with a panel of guests which include politicians, actors, comedians, musicians and the like to discuss what's going on in the world.
# 출연진:
# - Bill Maher
# 제작진:
# - Alessio Pollacci
# 포스터 URL: https://image.tmdb.org/t/p/original/pbpoLLp4kvnYVfnEGiEhagpJuVZ.jpg
#
# id: 4601
# 제목: Law & Order: Criminal Intent
# 장르: Drama
# 회차 정보: 195
# 줄거리: The third installment of the “Law & Order” franchise takes viewers deep into the minds of its criminals while following the intense psychological approaches the Major Case Squad uses to solve its crimes.
# 출연진:
# - Vincent D'Onofrio
# - Kathryn Erbe
# - Julia Ormond
# 제작진:
# - Dick Wolf
# 로고 URL: https://image.tmdb.org/t/p/original/zzNoDbK0vvAOdZIzUiwKUjbwyyO.png
# 포스터 URL: https://image.tmdb.org/t/p/original/68MUdrxeokhmd8pvlAjkD6yIfHR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=75IXY062Iqw
#
# id: 1412
# 제목: 애로우
# 장르: 범죄, 드라마, Action & Adventure
# 회차 정보: 170
# 줄거리: 스탈링 시티의 잘나가는 재벌 2세 올리버 퀸은 아버지와 보트 여행에 나섰다가 태풍을 만나 난파를 당한다. 그는 5년 동안 외딴 섬에 표류되어 생존을 위한 처절한 사투를 벌이고 마침내 고향으로 돌아온다. 아버지의 유언에 따라 스탈링 시티의 엘리트 범죄자들을 사냥하기위해 스스로 자경단원을 자처하는 올리버퀸. 그러나 그의 앞날에는 그의 상상보다 더 큰 진실과 음모가 기다리고 있는데...
# 출연진:
# - Stephen Amell
# - David Ramsey
# - Katie Cassidy
# 제작진:
# - Mark Bunting
# 로고 URL: https://image.tmdb.org/t/p/original/jUu02PexmdU5xAeDYsv1huceChE.png
# 포스터 URL: https://image.tmdb.org/t/p/original/gKG5QGz5Ngf8fgWpBsWtlg5L2SF.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qo6hU98dXOc
#
# id: 206559
# 제목: Binnelanders
# 장르: Soap
# 회차 정보: 4592
# 줄거리: A South African Afrikaans soap opera. It is set in and around the fictional private hospital, Binneland Kliniek, in Pretoria, and the storyline follows the trials, trauma and tribulations of the staff and patients of the hospital.
# 출연진:
# - Hans Strydom
# - Reynardt Hugo
# - Hykie Berg
# 제작진:
# - Jak de Priester
# 예고편 URL: https://www.youtube.com/watch?v=Uegxh8K8g3E
#
# id: 2316
# 제목: 오피스
# 장르: 코미디
# 회차 정보: 186
# 줄거리: 팬실베니아 스크랜튼에 위치한 사무용지 판매회사 던더 미플린의 스크랜턴 지점. 무미건조한 사무실에서 깐깐한 지점장과 독특한 캐릭터의 부하들이 벌이는 코믹 해프닝과 가슴 찡한 이야기가 펼쳐진다. BBC에서 방영된 동명 영국 시리즈의 할리우드 리메이크.
# 출연진:
# - Rainn Wilson
# - 존 크래신스키
# - 제나 피셔
# 제작진:
# - Steve Burgess
# 로고 URL: https://image.tmdb.org/t/p/original/zWozteGoJM0NhHj5lhXSqhu6rUA.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7DJKHzAi83BmQrWLrYYOqcoKfhR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=96ix3P9WaRc

# %%
import requests

# TMDB API 키
TMDB_API_KEY = 'cd88d12bfe4c5d842ef9a464b2f0bcd1'
language = 'ko'

#TV SERIES LISTS > POPULAR
#인기있는 tv 시리즈 출력을 위한 API
def fetch_popular_series(language='ko-KR', region='KR', page=1, total_results=200):
    url = f'https://api.themoviedb.org/3/tv/popular'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'region': region,
        'page': page,  # 페이지 번호 설정
    }

    results = []
    while len(results) < total_results:
        response = requests.get(url, params=params)
        data = response.json()
        results.extend(data['results'])
        page += 1
        params['page'] = page

    return results[:total_results]

def fetch_series_rating(series_id):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/content_ratings'
    params = {
        'api_key': TMDB_API_KEY
    }

    response = requests.get(url, params=params)
    data = response.json()
    
    kr_rating = None
    de_rating = None
    
    if 'results' in data:
        for result in data['results']:
            iso_3166_1 = result.get('iso_3166_1')
            rating = result.get('rating')
            
            if iso_3166_1 == 'KR':
                kr_rating = rating
            elif iso_3166_1 == 'DE':
                de_rating = rating
    
    if kr_rating:
        return kr_rating
    elif de_rating:
        return de_rating
    else:
        return None
    
#TV SERIES > DETAILS
def fetch_series_details(series_id, language='ko-KR'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'append_to_response': 'credits'  # 출연진 및 제작진 정보를 가져오기 위해 추가
    }

    response = requests.get(url, params=params)
    data = response.json()
    
    if 'overview' not in data or not data['overview']:
        params['language'] = 'en'
        response = requests.get(url, params=params)
        data = response.json()

    return data

#TV SERIES > IMAGES(로고, 포스터 이미지)
def fetch_series_images(series_id, language='ko'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/images'
   
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'append_to_response': 'credits'  # 출연진 및 제작진 정보를 가져오기 위해 추가
    }

    response = requests.get(url, params=params)
    data = response.json()
    
    # 한국어 포스터가 없거나 로고가 없을 시, 영어 이미지 출력
    if ('posters' not in data or len(data['posters']) == 0) or ('logos' not in data or len(data['logos']) == 0):
        params['language'] = 'en'
        response = requests.get(url, params=params)
        data = response.json()

        if 'posters' in data and len(data['posters']) > 0:
            data['posters'] = data['posters'][:1]
        if 'logos' in data and len(data['logos']) > 0:
            data['logos'] = data['logos'][:1]

    return data

#TV SERIES > VIDEOS
#TRAILER 
def fetch_series_videos(series_id, language='en'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/videos'

    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
    }
    response = requests.get(url, params=params)
    data = response.json()

    key_mapping = {
        'Trailer': 'trailer',
        'Clip': 'clip',
        'Teaser': 'teaser',
        'Opening Credits': 'opening_credits'
    }

    for item in data.get('results', []):
        video_type = item.get('type')
        if video_type in key_mapping:
            return item.get('key')

    return None


def print_series_info(series, series_images, series_videos):
    print("id:", series['id'])
    print("제목:", series['name'])
    print("장르:", ", ".join([genre['name'] for genre in series['genres']]))
    print("시즌 수:", f"{series['number_of_seasons']}")
    print("줄거리:", series['overview'])
    
    #RATING
    series_id = series['id']
    rating = fetch_series_rating(series_id)
    print("등급:", rating)


    #CAST
    if 'credits' in series and 'cast' in series['credits']:
        print("출연진:")
        for cast in series['credits']['cast'][:3]:
            print(f"{cast['name']}")
    
    #CREW
    if 'credits' in series and 'crew' in series['credits']:
        print("제작진:")
        if series['credits']['crew']:  # 제작진 정보가 있는 경우에만 출력
            crew = series['credits']['crew'][0]  # 첫 번째 제작진 정보만 출력
            print(f"{crew['name']}")
    
    #LOGO
    if 'logos' in series_images:
        for logo in series_images['logos']:
            print("로고 URL:", f"https://image.tmdb.org/t/p/original{logo['file_path']}")

    #POSTER_URL
    if 'posters' in series_images:
         for poster in series_images['posters']:
            print("포스터 URL:", f"https://image.tmdb.org/t/p/original{poster['file_path']}")

    #TRAILER_URL
    if series_videos is not None:  # 시리즈 비디오 정보가 있는 경우에만 출력
        print("예고편 URL:", f"https://www.youtube.com/watch?v={series_videos}")

def main():
    popular_tv_series = fetch_popular_series()

    for series in popular_tv_series:
        series_details = fetch_series_details(series['id'])
        series_images = fetch_series_images(series['id'])
        series_videos = fetch_series_videos(series['id'])  # 영상 정보 가져오기 추가
        print_series_info(series_details, series_images, series_videos)  # 영상 정보 전달
        print()

if __name__ == "__main__":
    main()
# Out:
# id: 2734
# 제목: 로 앤 오더: 성범죄 전담반
# 장르: 범죄, 드라마, 미스터리
# 시즌 수: 25
# 줄거리: 추악한 성범죄를 수사하는 뉴욕 경찰 성범죄전담수사반의 활약을 그린 드라마.
# 등급: 15
# 출연진:
# 마리슈카 하기테이
# Ice-T
# Peter Scanavino
# 제작진:
# Dick Wolf
# 로고 URL: https://image.tmdb.org/t/p/original/AhtQAQVcqWl6b0UZSo9vmHE3skK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/onmSVwYsPMYtO8OjLdjS8FfRNKb.jpg
# 예고편 URL: https://www.youtube.com/watch?v=IRXNVdiqMuU
#
# id: 57243
# 제목: 닥터 후
# 장르: Action & Adventure, 드라마, Sci-Fi & Fantasy
# 시즌 수: 13
# 줄거리: 타임로드라는 종족의 외계인인 닥터가 그의 동료들과 함께 시공간을 누비는 여행을 하며 때때로 지구와 인류 그리고 우주를 구하는 이야기.
# 등급: 15
# 출연진:
# Jodie Whittaker
# Mandip Gill
# John Bishop
# 제작진:
# Claire Pritchard
# 로고 URL: https://image.tmdb.org/t/p/original/r6aeDXC3UE8PfzdorYfQWpPJTho.png
# 포스터 URL: https://image.tmdb.org/t/p/original/4edFyasCrkH4MKs6H4mHqlrxA6b.jpg
# 예고편 URL: https://www.youtube.com/watch?v=8L1kU45poro
#
# id: 4556
# 제목: Scrubs
# 장르: Comedy
# 시즌 수: 9
# 줄거리: In the unreal world of Sacred Heart Hospital, John "J.D." Dorian learns the ways of medicine, friendship and life.
# 등급: 12
# 출연진:
# Zach Braff
# Donald Faison
# John C. McGinley
# 제작진:
# Josh Bycel
# 로고 URL: https://image.tmdb.org/t/p/original/6lCg07nxaLGpEap849catTySkvi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/u1z05trCA7AuSuDhi365grwdos1.jpg
# 예고편 URL: https://www.youtube.com/watch?v=zOgb3KIJDY8
#
# id: 1620
# 제목: CSI: 마이애미
# 장르: 드라마, 미스터리, 범죄
# 시즌 수: 10
# 줄거리: 플로리다 주의 마이애미 데이드 경찰청. 호레이쇼 반장과 CSI 과학 수사 대원들은 논리적인 증거 분석과 본능적인 수사로 마이애미에서 일어나는 위험한 범죄들을 해결해나간다.
# 등급: 15
# 출연진:
# David Caruso
# Emily Procter
# Omar Benson Miller
# 제작진:
# Scott Lautanen
# 로고 URL: https://image.tmdb.org/t/p/original/gnThzFN5qgTW3vKLl5mVlqRBQ5T.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pNW64pjaHvf6purNaFhq4SHYRfl.jpg
# 예고편 URL: https://www.youtube.com/watch?v=x2n-h9E8_ck
#
# id: 4376
# 제목: JAG
# 장르: Drama, Action & Adventure, Crime
# 시즌 수: 10
# 줄거리: Harmon "Harm" Rabb Jr. is a former pilot turned lawyer working for the military's JAG (Judge Advocate General) division, the elite legal wing of officers that prosecutes and defends those accused of military-related crimes. He works closely with Lt. Col. Sarah Mackenzie, and together they do what needs to be done to find the truth.
# 등급: 16
# 출연진:
# David James Elliott
# Catherine Bell
# Patrick Labyorteaux
# 제작진:
# Donald P. Bellisario
# 로고 URL: https://image.tmdb.org/t/p/original/ac4uUoKUD0kTxXHm04dp7u10ksc.png
# 포스터 URL: https://image.tmdb.org/t/p/original/zPyHpkJZ5O08lbgrQQIROXtb3xz.jpg
#
# id: 4604
# 제목: 스몰빌
# 장르: Sci-Fi & Fantasy, Action & Adventure, 드라마
# 시즌 수: 10
# 줄거리: 우리에게 슈퍼맨으로 친숙한 클라크 켄트의 유년기를 새로이 재조명한 워너 브라더스사의 SF시리즈물 드라마
# 등급: 15
# 출연진:
# Tom Welling
# Erica Durance
# Cassidy Freeman
# 제작진:
# Alfredo Septién
# 로고 URL: https://image.tmdb.org/t/p/original/ePZAsSSkT2G0j1F1U13ZE675N6I.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pUhJGETy2sec4vEkiqJ9eGeIywc.jpg
# 예고편 URL: https://www.youtube.com/watch?v=70Y32si4yb8
#
# id: 1412
# 제목: 애로우
# 장르: 범죄, 드라마, Action & Adventure
# 시즌 수: 8
# 줄거리: 스탈링 시티의 잘나가는 재벌 2세 올리버 퀸은 아버지와 보트 여행에 나섰다가 태풍을 만나 난파를 당한다. 그는 5년 동안 외딴 섬에 표류되어 생존을 위한 처절한 사투를 벌이고 마침내 고향으로 돌아온다. 아버지의 유언에 따라 스탈링 시티의 엘리트 범죄자들을 사냥하기위해 스스로 자경단원을 자처하는 올리버퀸. 그러나 그의 앞날에는 그의 상상보다 더 큰 진실과 음모가 기다리고 있는데...
# 등급: 15
# 출연진:
# Stephen Amell
# David Ramsey
# Katie Cassidy
# 제작진:
# Mark Bunting
# 로고 URL: https://image.tmdb.org/t/p/original/jUu02PexmdU5xAeDYsv1huceChE.png
# 포스터 URL: https://image.tmdb.org/t/p/original/gKG5QGz5Ngf8fgWpBsWtlg5L2SF.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qo6hU98dXOc
#
# id: 1416
# 제목: 그레이 아나토미
# 장르: 드라마
# 시즌 수: 20
# 줄거리: 시애틀에 있는 병원 의사들의 삶에 대한 이야기. 의사로서의 감정과 개인적인 감정에 대한 묘사가 적절히 조화를 이루어 그려진다. 인턴이지만 결국 레지던트가 되는 메러디스 그레이는 시애틀 병원의 동료 의사들과 함께 사적, 직업적인 열정에 휩쓸리는 자신을 발견한다.
# 등급: 19
# 출연진:
# 엘렌 폼페오
# Chandra Wilson
# James Pickens Jr.
# 제작진:
# 숀다 라임스
# 로고 URL: https://image.tmdb.org/t/p/original/keAZqhg9lmOHEhmG5njqIsuxf0f.png
# 포스터 URL: https://image.tmdb.org/t/p/original/jcEl8SISNfGdlQFwLzeEtsjDvpw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qbkEtYz9acA
#
# id: 1981
# 제목: Charmed
# 장르: Comedy, Drama, Mystery, Sci-Fi & Fantasy
# 시즌 수: 8
# 줄거리: Three sisters (Prue, Piper and Phoebe) reunite and unlock their powers to become the Charmed Ones, the most powerful good witches of all time, whose prophesied destiny is to protect innocent lives from evil beings such as demons and warlocks. Each sister possesses unique magical powers that grow and evolve, while they attempt to maintain normal lives in modern day San Francisco.
# 등급: 12
# 출연진:
# Holly Marie Combs
# Alyssa Milano
# Brian Krause
# 제작진:
# Holly Marie Combs
# 로고 URL: https://image.tmdb.org/t/p/original/dd7ULvZWBk0EL7PrnfoeE7cpSC7.png
# 포스터 URL: https://image.tmdb.org/t/p/original/z4bPJ1BWU2EtV69NII2GVvsugQ2.jpg
#
# id: 82873
# 제목: The Kelly Clarkson Show
# 장르: Talk
# 시즌 수: 5
# 줄거리: Kelly Clarkson presents the biggest newsmakers and names in film, television and music; as well as emerging new talent and everyday people who are beacons of hope in their communities.
# 등급: None
# 출연진:
# Kelly Clarkson
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/9Gg1oM8Us8gCS5aJA8e0ZRuIHnf.jpg
# 예고편 URL: https://www.youtube.com/watch?v=BhrdON83gqk
#
# id: 59941
# 제목: The Tonight Show Starring Jimmy Fallon
# 장르: Comedy, Talk
# 시즌 수: 11
# 줄거리: After Jay Leno's second retirement from the program, Jimmy Fallon stepped in as his permanent replacement. After 42 years in Los Angeles the program was brought back to New York.
# 등급: 16
# 출연진:
# Jimmy Fallon
# Steve Higgins
# 제작진:
# Mario Martines
# 포스터 URL: https://image.tmdb.org/t/p/original/g4amxJvtpnY79J77xeamnAEUO8r.jpg
#
# id: 1431
# 제목: CSI: 라스베가스
# 장르: 범죄, 드라마, 미스터리
# 시즌 수: 15
# 줄거리: 2000년 10월 CBS에서 방영을 시작한 범죄수사물. 최첨단 장비와 과학적인 분석으로 미궁속의 사건을 해결해 가는 라스베가스 시경 과학수사과 심야근무반. 17년 경력의 베테랑 길 그리섬, 혼자서 키우는 딸과 직장 사이에 균형을 잃지 않으며 항상 최선을 다하는 캐서린 윌로스, 도박의 유혹을 뿌리치지 못하지만 날카로운 분석력을 보유한 워릭 브라운, 하바드 출신의 새라 사이들, 그리고 매력적인 남자 닉 스톡스 등 5명이 한 팀으로 구성된 이들은 사건이 미궁에 빠질 때마다 첨단 기술과 예리한 분석력으로 결정적인 단서와 증거를 확보하여 진범을 가려내기 위해 365일 24시간을 투자한다.
# 등급: 15
# 출연진:
# Ted Danson
# George Eads
# Jorja Fox
# 제작진:
# Andi Brittan
# 로고 URL: https://image.tmdb.org/t/p/original/fLhKSEsurxHq3mwEDvCQhnApxkg.png
# 포스터 URL: https://image.tmdb.org/t/p/original/i5hmoRjHNWady4AtAGICTUXknKH.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ApT1EYvrwuk
#
# id: 1438
# 제목: 더 와이어
# 장르: 범죄, 드라마
# 시즌 수: 5
# 줄거리: 2002년 6월 HBO에서 방영을 시작한 범죄수사물. 볼티모어에서 일어난 살인 사건의 범인으로 지목된 마약 딜러 에이본 박스데일의 조카 디안젤로. 그가 증인의 진술 번복으로 풀려나자 이를 수상하게 여긴 강력계 형사 맥널티는 특별전담팀을 꾸린다.
# 등급: 19
# 출연진:
# Dominic West
# 랜스 레딕
# Sonja Sohn
# 제작진:
# Joe Chappelle
# 로고 URL: https://image.tmdb.org/t/p/original/cP5IrOYxU7qtFl3Gyjtj9iPufCn.png
# 포스터 URL: https://image.tmdb.org/t/p/original/4lbclFySvugI51fwsyxBTOm4DqK.jpg
# 예고편 URL: https://www.youtube.com/watch?v=uDcQbk78CSw
#
# id: 1433
# 제목: 아메리칸 대드!
# 장르: 애니메이션, 코미디
# 시즌 수: 20
# 줄거리: 랭글리 폴즈라는 도시에서 사는 CIA에서 근무하는 수꼴에 과대망상이 매우 심한 아버지(스탠 스미스)와 전형적인 금발백치 어머니(프랜신 스미스), 반항아에 좌빨인 장녀(헤일리 스미스)에 Nerd 아들(스티브 스미스), 변장을 좋아하는 양성애자자웅동체[1] 외계인(로저), 그리고 동독 스키점퍼의 기억을 가지고 있는 금붕어(클라우스 하이슬러)로 이루어진 스미스 가족과 그 주변인물들을 다루고 있다
# 등급: 12
# 출연진:
# 세스 맥팔레인
# Wendy Schaal
# Rachael MacFarlane
# 제작진:
# Chris McKenna
# 로고 URL: https://image.tmdb.org/t/p/original/56e9hx9CwagmWwxdOZFqq7cqORS.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/xnFFz3etm1vftF0ns8RMHA8XdqT.jpg
# 예고편 URL: https://www.youtube.com/watch?v=W9Kf1RUHLxE
#
# id: 1622
# 제목: 수퍼내추럴
# 장르: 드라마, 미스터리, Sci-Fi & Fantasy
# 시즌 수: 15
# 줄거리: 어린 시절, 샘과 딘은 정체를 알 수 없는 악마의 힘의 의해 어머니를 잃는다. 그로 인해, 그들의 아버지는 자식들을 헌터로 키우며, 미국 각지에 흩어져 있는 초자연적인 악과 괴물들을 처치하는 법을 가르친다.
#
# 이제 두 윈체스터 형제들은 67년형 쉐비 임팔라에 몸을 싣고 미전역을 가로지르며 그들과 마주치는 모든 초자연적인 위협들을 처리해나가기 시작하는데...
# 등급: 16
# 출연진:
# Jared Padalecki
# Jensen Ackles
# Misha Collins
# 제작진:
# Talli Buchanan
# 로고 URL: https://image.tmdb.org/t/p/original/jpop1hHSw0Cwm4J1lUcP6KDMbVf.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/KoYWXbnYuS3b0GyQPkbuexlVK9.jpg
# 예고편 URL: https://www.youtube.com/watch?v=yy96yJjkvjo
#
# id: 1421
# 제목: 모던 패밀리
# 장르: 코미디
# 시즌 수: 11
# 줄거리: 에미상을 받은 이 시트콤은 로스앤젤레스에 사는 제이 프리쳇과 각양각색의 가족이 일상에서 수많은 난관을 만나고 해결해 나가는 이야기를 그린다.
# 등급: 15
# 출연진:
# Ed O'Neill
# 소피아 베르가라
# 줄리 보언
# 제작진:
# Jeffrey Richman
# 로고 URL: https://image.tmdb.org/t/p/original/rbKhglYrECjMZNYtT2QyihOQ5F.png
# 포스터 URL: https://image.tmdb.org/t/p/original/klL4yhwiU8aF4AuF5dCfJA9sRnS.jpg
# 예고편 URL: https://www.youtube.com/watch?v=rbpTUPisA78
#
# id: 4620
# 제목: 유레카
# 장르: Sci-Fi & Fantasy, 코미디, 드라마
# 시즌 수: 5
# 줄거리: 미국의 Syfy 채널에서 2006년부터 2012년까지 방영한 SF 드라마이다. 유레카라고 불리는 이 마을은 2차 세계대전이 끝난후에 알베르트 아인슈타인이 해리 S. 트루먼 대통령에게 과학자들의 천국을 만들자고 건의해서 만들어진 마을이며, 현재는 펜타곤이 이 마을을 담당[3]하고 있다. 철통같은 보안으로 51구역이 부러워 한다고 한다...
# 등급: 12
# 출연진:
# Colin Ferguson
# Salli Richardson-Whitfield
# 조 모턴
# 제작진:
# Rick Maguire
# 로고 URL: https://image.tmdb.org/t/p/original/hzfIri2vgVJJhJd7vWnZlUwS9oi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/f2l5hUk63hPqYTucnFy2HmElFV0.jpg
# 예고편 URL: https://www.youtube.com/watch?v=WiPWghJQS3o
#
# id: 2316
# 제목: 오피스
# 장르: 코미디
# 시즌 수: 9
# 줄거리: 팬실베니아 스크랜튼에 위치한 사무용지 판매회사 던더 미플린의 스크랜턴 지점. 무미건조한 사무실에서 깐깐한 지점장과 독특한 캐릭터의 부하들이 벌이는 코믹 해프닝과 가슴 찡한 이야기가 펼쳐진다. BBC에서 방영된 동명 영국 시리즈의 할리우드 리메이크.
# 등급: 15
# 출연진:
# Rainn Wilson
# 존 크래신스키
# 제나 피셔
# 제작진:
# Steve Burgess
# 로고 URL: https://image.tmdb.org/t/p/original/zWozteGoJM0NhHj5lhXSqhu6rUA.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7DJKHzAi83BmQrWLrYYOqcoKfhR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=96ix3P9WaRc
#
# id: 34307
# 제목: 쉐임리스
# 장르: 드라마, 코미디
# 시즌 수: 11
# 줄거리: 미국 시카고 후미진 마을에서 힘겹게 살고 있는 싱글 대디 프랭크와 총명하고 독립적인 그의 여섯 자녀들의 리얼한 이야기
# 등급: 19
# 출연진:
# 윌리엄 H. 메이시
# 제레미 앨런 화이트
# Ethan Cutkosky
# 제작진:
# John Wells
# 로고 URL: https://image.tmdb.org/t/p/original/vmxGfz06Eha0n1UvSckq907wFFz.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9akij7PqZ1g6zl42DQQTtL9CTSb.jpg
# 예고편 URL: https://www.youtube.com/watch?v=9tvkYS5cA58
#
# id: 45854
# 제목: 유희왕 ZEXAL
# 장르: 애니메이션, 코미디, Action & Adventure, Sci-Fi & Fantasy
# 시즌 수: 1
# 줄거리: 근미래의 마을, 하트랜드 시티에서는 어른도 아이도 AR 듀얼에 열중하고 있다.
#
# AR 듀얼이란, 「D-게이저」와 「D-패드」를 사용하는 듀얼로,
#
# 이 2가지를 사용하는 것으로,
#
# 지면에서, 하늘에서, 그리고 건물에서
#
# 몬스터가 현실에
#
# 튀어나와 맞부딪치는,
#
# 무지막지 박력 넘치는 듀얼!
#
# 이 마을에 사는 주인공 츠쿠모 유마도
#
# 이 듀얼에 열중하고 있지만,
#
# 실력은 초심자 레벨의 연전연패 챔피언.
#
# 어느 사건을 계기로, 학교 제일의 불량배 료가와
#
# 듀얼로 승부를 내게 된 유마.
#
# 이 듀얼이, 유마의 운명을 크게 바꿔놓는다...!
#
# 이 결투 중, 항상 유마의 꿈에 나오는 불길한 문이 돌연 나타난다.
#
# 굳게 닫혀 있던 문이 개방된 순간, 무수한 빛이 넘쳐 나와,
#
# 놀라서 옆을 올려다보니...
#
# 거기에는 이세계에서 온 수수께끼의 생명체 아스트랄이 서 있었다!
#
# 아스트랄의 잃어버린 기억, 99장의 넘버즈 카드를 되찾기 위해,
#
# 둘은 함께 행동하기로 한다.
#
# 아스트랄이 나타난 진정한 이유란?
#
# 그리고, 새로운 몬스터 「넘버즈 몬스터」의
#
# 존재는 도대체 무엇이란 말인가?
#
# 계속해서 유마의 앞에 나타나는 강력한 라이벌,
#
# 그리고 밝혀져가는 아스트랄의 수수께끼.
#
# 이 콤비에 의한 새로운 듀얼의 전설이 지금, 막을 연다!!
# 등급: 6
# 출연진:
# 하타나카 타스쿠
# 이리노 미유
# 谷育子
# 제작진:
# Wataru Nakagawa
# 포스터 URL: https://image.tmdb.org/t/p/original/3aZUtzeHQrLgQQdYNqHSbJqj59G.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ajFTuo6LQLc
#
# id: 49009
# 제목: 골드버그 패밀리
# 장르: 가족, 코미디
# 시즌 수: 10
# 줄거리: 육아 블로그가 생기고, 트로피가 등장하고, 땅콩 알레르기가 유행하기 전에는 80년대라는 단순한 시대가 있었다.
#
# 괴짜 11살 아담에게 이 시기는 경이로운 시절이었고, 그는 비디오 카메라로 무장하고 그 모든 신기한 장면을 카메라에 담았다. 골드버그 가족은 다른 가족들과 마찬가지로 사랑스러운 가족이었지만 고성이 끊이지 않는다..
# 등급: 12
# 출연진:
# Wendi McLendon-Covey
# Sean Giambrone
# Troy Gentile
# 제작진:
# Demetrios Katsantonis
# 로고 URL: https://image.tmdb.org/t/p/original/uQ2lw8cFij434Y5ychYUxW8oxUo.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pZyaKyry0V1muunoTt6pZ6cLduR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=Q_BJzU0ulLE
#
# id: 1668
# 제목: 프렌즈
# 장르: 코미디
# 시즌 수: 10
# 줄거리: 1994년 5월 NBC에서 방영을 시작한 시트콤. 미국 뉴욕 시 맨해튼의 그리니치 빌리지의 아파트와 까페 센트럴 퍼크를 중심으로 2-30대의 세 명의 남자와 세 명의 여자의 우정과 사랑, 삶을 그렸다. 부잣집 맏딸이자 응석받이로 자라 온 레이첼은 결혼식을 앞두고 결혼 선물들을 쳐다보던 중 자신이 남편보다 결혼선물을 더 사랑한다는 사실을 깨닫고 회의감을 느끼게 된다. 이를 계기로 불현듯 결혼식에서 도망쳐 나오게 되고, 뉴욕에 아버지의 그늘을 피할 곳을 찾다가 결혼식 전 우연히 만난 고등학교 동창 모니카와 재회하게 된다.
# 등급: 15
# 출연진:
# 제니퍼 애니스턴
# 코트니 콕스
# 리사 쿠드로
# 제작진:
# Richard Choi
# 로고 URL: https://image.tmdb.org/t/p/original/a4qZkvpdqCSS60vppgL5xCBsMwi.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/2koX1xLkpTQM4IZebYvKysFW1Nh.jpg
# 예고편 URL: https://www.youtube.com/watch?v=s2TyVQGoCYo
#
# id: 1911
# 제목: 본즈
# 장르: 범죄, 드라마
# 시즌 수: 12
# 줄거리: 워싱턴 D.C.의 제퍼소니안 재단의 연구소 소속 법인류학자인 템퍼런스 브레넌 박사와 FBI 워싱턴 지국 요원인 실리 부스, 그리고 브레넌 박사의 팀이 뼈만 남다시피한 시신을 조사해 해결하는 내용으로 실제 법인류학자인 '캐시 라익스'의 소설을 각색해 제작되었으며 국내에도 '본즈'라는 제목으로 원작 소설 시리즈가 발매되었다.
# 등급: 15
# 출연진:
# Emily Deschanel
# David Boreanaz
# John Boyd
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/xSguBiLk5wgeDqkye3MgIoQ5gCH.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/eyTu5c8LniVciRZIOSHTvvkkgJa.jpg
# 예고편 URL: https://www.youtube.com/watch?v=idiNjlYU7Cs
#
# id: 204746
# 제목: The Jennifer Hudson Show
# 장르: Talk
# 시즌 수: 2
# 줄거리: Talented entertainer and newly-minted EGOT Jennifer Hudson takes on the daytime talk show landscape.
# 등급: None
# 출연진:
# Jennifer Hudson
# 제작진:
# Jennifer Hudson
# 포스터 URL: https://image.tmdb.org/t/p/original/6VBNeo8XG90sNKWYQ0yTEmVBXHJ.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ZMPpLofgSTM
#
# id: 764
# 제목: Midsomer Murders
# 장르: Crime, Drama, Mystery
# 시즌 수: 24
# 줄거리: The peacefulness of the Midsomer community is shattered by violent crimes, suspects are placed under suspicion, and it is up to a veteran DCI and his young sergeant to calmly and diligently eliminate the innocent and ruthlessly pursue the guilty.
# 등급: 12
# 출연진:
# Neil Dudgeon
# Nick Hendrix
# Fiona Dolman
# 제작진:
# Kirsten Gair
# 로고 URL: https://image.tmdb.org/t/p/original/m2Jiqj8b4OjkjBHfp2px8gucB4h.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pz7tsWxe0TTdfJnWPjZAEnrSl5M.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ym8b4UJDqcw
#
# id: 4586
# 제목: 길모어 걸스
# 장르: 코미디, 드라마
# 시즌 수: 7
# 줄거리: 독립심이 강한 싱글맘 로렐라이는 아이비리그 진학은 문제없을 정도로 명석한 두뇌를 가진 딸 로리를 키운다. 이 모녀 사이에는 항상 재치 넘치는 대화가 끊이지 않는다.
# 등급: 12
# 출연진:
# Lauren Graham
# 알렉시스 블레델
# Scott Patterson
# 제작진:
# Chris Long
# 로고 URL: https://image.tmdb.org/t/p/original/knLz8N6ADgqfRyfgFTFJIEYG3jM.png
# 포스터 URL: https://image.tmdb.org/t/p/original/8hWwBpB1mLUKqzjdGrcvJcIklp4.jpg
# 예고편 URL: https://www.youtube.com/watch?v=Ac47mma8XRA
#
# id: 61733
# 제목: 엠파이어
# 장르: 드라마
# 시즌 수: 6
# 줄거리: 힙합 가수이자 엠파이어 엔터테인먼트의 CEO인 루시어스 라이언. 늘 어려움 없이 권력을 휘두르던 3년 내로 몸을 쓰지 못하게 될 거라는 의사의 진단을 받으면서 굶주린 상어 떼가 몰려드는데. 그는 가족 사이가 더 틀어지지 않게 지키면서도, 세 아들 중 누구에게 자신의 자리를 물려줄지 결정해야 한다. 루시어스가 가장 사랑하는 막내 하킴은 타고난 음악가지만 노력보다 명성을 중시한다. 둘째 자말은 재능이 있지만 쑥스러움을 타는 성격인 데다 동성애자라는 점이 라이언에게는 낯부끄럽다. 장남 안드레는 사업 수완이 있지만 카리스마가 부족하다. 한편, 라이언의 전 아내 쿠키가 다시 나타나면서 상황은 더 복잡해진다. 라이언의 무명 시절에 마약 거래로 생활비를 마련했던 그녀는 고생에 대한 보상을 요구하는데...
# 등급: 16
# 출연진:
# 테런스 하워드
# 터라지 P. 헨슨
# Bryshere Y. Gray
# 제작진:
# Lee Daniels
# 로고 URL: https://image.tmdb.org/t/p/original/tCxJHzyFPHB5OIHdbk0wQCuEnRm.png
# 포스터 URL: https://image.tmdb.org/t/p/original/gTrzYR6gWMhQ8yINW9JCLeoJHvf.jpg
# 예고편 URL: https://www.youtube.com/watch?v=3IpVV7xDMIo
#
# id: 61818
# 제목: Late Night with Seth Meyers
# 장르: Talk, Comedy
# 시즌 수: 11
# 줄거리: Seth Meyers, who is "Saturday Night Live’s" longest serving anchor on the show’s wildly popular "Weekend Update," takes over as host of NBC’s "Late Night" — home to A-list celebrity guests, memorable comedy and the best in musical talent. As the Emmy Award-winning head writer for "SNL," Meyers has established a reputation for sharp wit and perfectly timed comedy, and has gained fame for his spot-on jokes and satire. Meyers takes his departure from "SNL" to his new post at "Late Night," as Jimmy Fallon moves to "The Tonight Show".
# 등급: None
# 출연진:
# Seth Meyers
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/g6MrJxNaHYGYU7Sxo72e5B8gKOV.jpg
# 예고편 URL: https://www.youtube.com/watch?v=rLwbzGyC6t4
#
# id: 8514
# 제목: 루폴의 드래그 레이스
# 장르: Reality
# 시즌 수: 16
# 줄거리: 독보적인 무대 장악력을 뽐내는 퀸들이 무한 경쟁에 나섰다. 이들의 목표는 10만 달러 상금과 '미국의 차세대 드래그 슈퍼스타'라는 명예. 드래그 퀸의 대모 격인 루폴이 이들의 화려한 무대를 이끈다. 에미상 수상에 빛나는 리얼리티 쇼.
# 등급: 19
# 출연진:
# RuPaul
# Michelle Visage
# Carson Kressley
# 제작진:
# Tori Himes
# 로고 URL: https://image.tmdb.org/t/p/original/y2wUAB4og8Pi6ocOag3LSkKqVHz.png
# 포스터 URL: https://image.tmdb.org/t/p/original/6LThfVcGWSLswQaQh2vvk1Q2IoH.jpg
#
# id: 4482
# 제목: Bewitched
# 장르: Sci-Fi & Fantasy, Comedy, Family, Drama
# 시즌 수: 8
# 줄거리: Samantha Stephens is a seemingly normal suburban housewife who also happens to be a genuine witch, with all the requisite magical powers. Her husband Darrin insists that Samantha keep her witchcraft under wraps, but situations invariably require her to indulge her powers while keeping her bothersome mother Endora at bay.
# 등급: 6
# 출연진:
# Elizabeth Montgomery
# Dick Sargent
# Agnes Moorehead
# 제작진:
# Harry Ackerman
# 로고 URL: https://image.tmdb.org/t/p/original/1RksPe8I9h1Ts24gybDsy2L36Ce.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7UZVO1SclbgVWM2ELrwWGaS7i94.jpg
# 예고편 URL: https://www.youtube.com/watch?v=0oT208N0Xd4
#
# id: 60625
# 제목: 릭 앤 모티
# 장르: 애니메이션, 코미디, Sci-Fi & Fantasy, Action & Adventure
# 시즌 수: 7
# 줄거리: 술에 절어 사는 천재 과학자 릭은 투정이 심한 10대 손자 모티를 데리고 외계와 대체 현실로 아슬아슬한 모험을 떠난다.
# 등급: 19
# 출연진:
# Chris Parnell
# Spencer Grammer
# Sarah Chalke
# 제작진:
# Anthony Alfonso
# 로고 URL: https://image.tmdb.org/t/p/original/wq3wqFLwwqnhG6DxmSji9ehLcx6.png
# 포스터 URL: https://image.tmdb.org/t/p/original/gdIrmf2DdY5mgN6ycVP0XlzKzbE.jpg
# 예고편 URL: https://www.youtube.com/watch?v=p_bH42OiUo4
#
# id: 4601
# 제목: Law & Order: Criminal Intent
# 장르: Drama
# 시즌 수: 10
# 줄거리: The third installment of the “Law & Order” franchise takes viewers deep into the minds of its criminals while following the intense psychological approaches the Major Case Squad uses to solve its crimes.
# 등급: 16
# 출연진:
# Vincent D'Onofrio
# Kathryn Erbe
# Julia Ormond
# 제작진:
# Dick Wolf
# 로고 URL: https://image.tmdb.org/t/p/original/zzNoDbK0vvAOdZIzUiwKUjbwyyO.png
# 포스터 URL: https://image.tmdb.org/t/p/original/68MUdrxeokhmd8pvlAjkD6yIfHR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=75IXY062Iqw
#
# id: 39351
# 제목: 그림형제
# 장르: 드라마, 미스터리, Sci-Fi & Fantasy
# 시즌 수: 6
# 줄거리: 훈훈한 외모의, 미모의 약혼녀까지 겸비한 형사 '닉'은 어느날 괴이한 경험을 하게 된다. 다른 사람들 눈에 보이지 않는 사람들의 숨겨진 얼굴이 보이고, 동화 속 인물들이 현실에 존재한다는 사실을 알게 된다. '그림'의 마지막 후손 닉! 인간들을 공격하는 그들로부터 현실세계를 지키기 위해 그의 특별한 수사가 시작된다.
# 등급: 15
# 출연진:
# David Giuntoli
# Silas Weir Mitchell
# Russell Hornsby
# 제작진:
# Neal Sopata
# 로고 URL: https://image.tmdb.org/t/p/original/nOPg4FutzDnPdwlXMDy8hVRuJAr.png
# 포스터 URL: https://image.tmdb.org/t/p/original/iOptnt1QHi6bIHmOq6adnZTV0bU.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ElSANtJSrWQ
#
# id: 1396
# 제목: 브레이킹 배드
# 장르: 드라마, 범죄
# 시즌 수: 5
# 줄거리: 2008년 1월 AMC에서 방영을 시작한 범죄 스릴러. Breaking Bad는 막가기를 뜻하는 미국 남부 지방의 속어이다. 한때 노벨화학상까지 바라 볼 정도로 뛰어난 과학자였던 고등학교 화학 교사 월터 화이트는 자신의 50세 생일 날에 폐암 3기 진단을 받는다. 어느 날 동서와 함께 마약 단속 현장을 참관한 그는 현장에서 달아나는 옛 제자 제시를 발견한다. 뇌성마비에 걸린 고등학생 아들과 임신한 아내를 위해 제시에게 동업을 제의한 월터는 자신의 화학지식을 이용해 전례없는 고순도 고품질의 메스암페타민을 제조한다.
# 등급: 19
# 출연진:
# 브라이언 크랜스턴
# 아론 폴
# 애나 건
# 제작진:
# Jennifer Bryan
# 로고 URL: https://image.tmdb.org/t/p/original/chw44B2VnLha8iiTdyZcIW0ZELC.png
# 포스터 URL: https://image.tmdb.org/t/p/original/ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg
# 예고편 URL: https://www.youtube.com/watch?v=XZ8daibM3AE
#
# id: 1950
# 제목: 에버우드
# 장르: 드라마, 가족
# 시즌 수: 4
# 줄거리: 아내의 갑작스러운 죽음으로 뉴욕에서 전문의로서 명성을 누리던 주인공이 자신의 아이들에게 진정한 아버지가 되고자 시골 소도시 에버우드로 이사를 오게 되면서 벌어지는 마을의 사건들과 주민들의 융화와 갈등을 조명하는 드라마
# 등급: 12
# 출연진:
# Treat Williams
# Gregory Smith
# Emily VanCamp
# 제작진:
# Greg Berlanti
# 포스터 URL: https://image.tmdb.org/t/p/original/4zmuA2Ql1QdUtw9OM6MdmtXnZEF.jpg
#
# id: 4357
# 제목: Mission: Impossible
# 장르: Action & Adventure, Crime, Drama, Mystery
# 시즌 수: 7
# 줄거리: Mission: Impossible is an American television series that was created and initially produced by Bruce Geller. It chronicles the missions of a team of secret government agents known as the Impossible Missions Force. In the first season, the team is led by Dan Briggs, played by Steven Hill; Jim Phelps, played by Peter Graves, takes charge for the remaining seasons. A hallmark of the series shows Briggs or Phelps receiving his instructions on a recording that then self-destructs, followed by the theme music composed by Lalo Schifrin.
#
# The series aired on the CBS network from September 1966 to March 1973, then returned to television for two seasons on ABC, from 1988 to 1990, retaining only Graves in the cast. It later inspired a popular series of theatrical motion pictures starring Tom Cruise, beginning in 1996.
# 등급: 12
# 출연진:
# Peter Graves
# Greg Morris
# Peter Lupus
# 제작진:
# Bruce Geller
# 로고 URL: https://image.tmdb.org/t/p/original/5dTv8RjhPOln3Y5hANqdfxm7B59.png
# 포스터 URL: https://image.tmdb.org/t/p/original/bAnCcwe70IXHRwUgsRJT4ZlQ47o.jpg
#
# id: 14929
# 제목: 하트랜드
# 장르: 가족, 드라마, 코미디
# 시즌 수: 17
# 줄거리: 야무진 소녀 에이미는 어머니의 갑작스럽게 죽은 충격에서 헤어나지 못 한다. 한편 에이미와 그녀의 할아버지는 목장을 잃을 수 있는 위기에 봉착한다.
# 등급: 12
# 출연진:
# Amber Marshall
# Graham Wardle
# Shaun Johnston
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/1bVQuM21SMsCAIkSe61HvBdKlfi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/uc2gtWczT58BiAUJWFz9P5aZmNF.jpg
# 예고편 URL: https://www.youtube.com/watch?v=gnLKnXN6VQc
#
# id: 66465
# 제목: The Kapil Sharma Show
# 장르: Comedy, Talk
# 시즌 수: 3
# 줄거리:
# 등급: None
# 출연진:
# Kapil Sharma
# Archana Puran Singh
# Krishna Abhishek
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/fBPNBNFmcwhYXUpkW2Kb6jbeJOR.jpg
#
# id: 4419
# 제목: Real Time with Bill Maher
# 장르: Comedy, Talk
# 시즌 수: 22
# 줄거리: Each week Bill Maher surrounds himself with a panel of guests which include politicians, actors, comedians, musicians and the like to discuss what's going on in the world.
# 등급: 18
# 출연진:
# Bill Maher
# 제작진:
# Alessio Pollacci
# 포스터 URL: https://image.tmdb.org/t/p/original/pbpoLLp4kvnYVfnEGiEhagpJuVZ.jpg
#
# id: 21762
# 제목: Parenthood
# 장르: Drama
# 시즌 수: 6
# 줄거리: The trials and tribulations of the very large, colorful and imperfect Braverman family.
# 등급: None
# 출연진:
# Peter Krause
# Monica Potter
# Lauren Graham
# 제작진:
# Debra James
# 로고 URL: https://image.tmdb.org/t/p/original/sugCFBeGOxmIXp0bC0iPMrM7pBW.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9KjKLJrrUI1sU9bNsQaQ5H8kTyY.jpg
# 예고편 URL: https://www.youtube.com/watch?v=o_cblVvo5bg
#
# id: 56296
# 제목: 오펀 블랙
# 장르: 드라마, Sci-Fi & Fantasy
# 시즌 수: 5
# 줄거리: 세라는 자신과 똑 닮은 여성이 자살하는 충격적인 장면을 목격하고, 죽은 이의 신분으로 위장한 채 새로운 인생을 살려고 한다.
# 등급: 19
# 출연진:
# Tatiana Maslany
# Jordan Gavaris
# Josh Vokey
# 제작진:
# Jessica Stein
# 로고 URL: https://image.tmdb.org/t/p/original/b9LYnRp4eEX2280BOCPBALI5Via.png
# 포스터 URL: https://image.tmdb.org/t/p/original/xKo79AxtabAFoJTqz4RuC3APND4.jpg
# 예고편 URL: https://www.youtube.com/watch?v=OcnIQeWY6MA
#
# id: 4313
# 제목: 풀 하우스
# 장르: 코미디, 가족
# 시즌 수: 8
# 줄거리: 1987년부터 1995년 사이 미국에서 많은 사랑을 받았던 시트콤
# 등급: 0
# 출연진:
# John Stamos
# Bob Saget
# Dave Coulier
# 제작진:
# Tom Amundsen
# 로고 URL: https://image.tmdb.org/t/p/original/uMFvvQYCYaDD4j6GMiobUj0y4Ws.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7g0EyKsIaYjYw3gCIBKMHHE0Kcu.jpg
# 예고편 URL: https://www.youtube.com/watch?v=SDP7__2F1YE
#
# id: 71712
# 제목: 굿 닥터
# 장르: 드라마
# 시즌 수: 7
# 줄거리: 자폐증을 가진 젊은 외과 의사가 명문 병원에 들어가게된다. 이에 사람들과 소통하지 못하는 의사가 사람의 목숨을 구할 수 있을 까 하는 의문이 제기되는데...
# 등급: 15
# 출연진:
# 프레디 하이모어
# Fiona Gubelmann
# Will Yun Lee
# 제작진:
# 박재범
# 로고 URL: https://image.tmdb.org/t/p/original/zhHSO2xwslKy1PsDltKslEh0rjj.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/pFqzXacKsi9or1GVdxTLutXD9zM.jpg
# 예고편 URL: https://www.youtube.com/watch?v=lnY9FWUTY84
#
# id: 1695
# 제목: 몽크
# 장르: 코미디, 범죄, 드라마, 미스터리
# 시즌 수: 8
# 줄거리: 현대 샌프란시스코를 배경으로 하는 코미디 수사물 미드. 3년 전 자동차 폭발 사건으로 아내를 잃은이후 큰 충격에서 빠져나오지 못한 채, 독특한 강박관념에 사로잡혀 많은 사람들이 모인 군중과 높은 곳, 그리고 어둠을 두려워하는 증세를 보이는 전직 경찰 에이드리언 몽크가 샌프란시스코 경찰을 도와 복잡한 사건들을 해결한다.
# 등급: 15
# 출연진:
# 토니 샬호브
# 테드 러바인
# Jason Gray-Stanford
# 제작진:
# Josh Siegal
# 로고 URL: https://image.tmdb.org/t/p/original/pIOqR6IchhSOmaIZIyDGW9QB982.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/3axGMbUecXXOPSeG47v2i9wK5y5.jpg
# 예고편 URL: https://www.youtube.com/watch?v=mftbaaU82Uc
#
# id: 3769
# 제목: Dynasty
# 장르: Soap, Drama
# 시즌 수: 9
# 줄거리: The saga of a wealthy Denver family in the oil business: Blake Carrington, the patriarch; Krystle, his former secretary and wife; his children: Adam, lost in childhood after a kidnapping; Fallon, pampered and spoiled; Steven, openly gay; and Amanda, hidden from him by his ex-wife, the conniving Alexis. Most of the show features the conflict between 2 large corporations, Blake's Denver Carrington and Alexis' ColbyCo.
# 등급: 12
# 출연진:
# John Forsythe
# Linda Evans
# Joan Collins
# 제작진:
# Elaine Rich
# 로고 URL: https://image.tmdb.org/t/p/original/wFLfnNQjGnO0Dvg7f07mnTZ9Y5K.png
# 포스터 URL: https://image.tmdb.org/t/p/original/bKBTf22IDwD39GbpQ6clYQ2WCtA.jpg
# 예고편 URL: https://www.youtube.com/watch?v=oftDrdDBTkw
#
# id: 62688
# 제목: 슈퍼걸
# 장르: 드라마, Sci-Fi & Fantasy, Action & Adventure
# 시즌 수: 6
# 줄거리: 재난을 막기 위해 자신의 초능력과 정체를 드러낸 카라 댄버스. 슈퍼맨의 사촌이자 슈퍼걸로 알려진 그녀가 내셔널 시티의 수호자로 나선다.
# 등급: 15
# 출연진:
# 멜리사 베노이스트
# Chyler Leigh
# David Harewood
# 제작진:
# Karen Maser
# 로고 URL: https://image.tmdb.org/t/p/original/uN3wd0a3QEpIIKEmXVGmIa1Gw22.png
# 포스터 URL: https://image.tmdb.org/t/p/original/vqBsgL9nd2v04ZvCqPzwtckDdFD.jpg
# 예고편 URL: https://www.youtube.com/watch?v=Mh8MYFadTmQ
#
# id: 2691
# 제목: 두 남자와 1/2
# 장르: 코미디
# 시즌 수: 12
# 줄거리: 자유로운 영혼이었던 찰리가 떠나간 이후, 앨런과 그의 아들 제이크에게 찾아온 앨런의 친구 월든이 다시금 새로운 가족으로 생활하게 되면서 벌어지는 코믹한 일상을 담은 시트콤
# 등급: 15
# 출연진:
# 애쉬튼 커쳐
# Jon Cryer
# Conchata Ferrell
# 제작진:
# Jim Patterson
# 로고 URL: https://image.tmdb.org/t/p/original/ivAjR58o2LaAHDThE923k7VOV37.png
# 포스터 URL: https://image.tmdb.org/t/p/original/xgfjxyV3g1S68opzuvG6G87muDp.jpg
# 예고편 URL: https://www.youtube.com/watch?v=h1YadOPGL-0
#
# id: 72002
# 제목: 다이너스티: 1%의 1%
# 장르: 드라마, Soap
# 시즌 수: 5
# 줄거리: 모든 것을 가진 두 가문 캐링턴과 콜비. 그들이 격돌한다. 막대한 부를 차지하고 자식들을 길들이기 위해. 새로운 모습으로 돌아온 80년대 미국 드라마의 전설.
# 등급: 15
# 출연진:
# Elizabeth Gillies
# Grant Show
# Daniella Alonso
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/pFjglX2YwbbfogHh32VakoffjRr.png
# 포스터 URL: https://image.tmdb.org/t/p/original/rVQ35erLIoV8hyh7lIKAMiChmOO.jpg
# 예고편 URL: https://www.youtube.com/watch?v=PzBX_c-F6sk
#
# id: 223365
# 제목: Rebirth
# 장르: Soap, Drama
# 시즌 수: 1
# 줄거리: After making a pact with Jequitibá, José Inocêncio becomes a mythical figure, known as the most successful cocoa farmer in the region. While still young, he wins the heart of Maria Santa. Their intense passion results in four children: José Augusto, José Bento, José Venâncio, and the youngest, João Pedro, who never had the opportunity to know his mother, as she dies while giving birth to him. This tragedy fuels José Inocêncio’s anger, blaming João Pedro for the loss of his great love. Throughout their lives, indifference and resentment mark the relationship between the father and his youngest son. As if the past weren’t enough, years later, the arrival of the mysterious Mariana puts all these emotions to the test when both father and son fall in love with the same woman. This situation reawakens feelings that were either dormant or previously unknown to them.
# 등급: None
# 출연진:
# Marcos Palmeira
# Theresa Fonseca
# Juan Paiva
# 제작진:
# Bruno Luperi
#
# id: 61378
# 제목: 마담 세크리터리
# 장르: 드라마, War & Politics
# 시즌 수: 6
# 줄거리: 전임자의 갑작스러운 사망으로 국무장관에 임명된 전직 CIA 요원 엘리자베스. 국내외 현안을 책임지는 동시에 아내와 엄마의 역할도 소홀하지 않고자 동분서주한다.
# 등급: 15
# 출연진:
# 테아 레오니
# Tim Daly
# Zeljko Ivanek
# 제작진:
# Eric Stoltz
# 로고 URL: https://image.tmdb.org/t/p/original/v2lhWorIskFunq2vwzBrtbeWuWR.png
# 포스터 URL: https://image.tmdb.org/t/p/original/6Nl1ablo4DNTLb4ZH7Mycz81AEt.jpg
# 예고편 URL: https://www.youtube.com/watch?v=dR9dEhaCnhA
#
# id: 31911
# 제목: 강철의 연금술사 BROTHERHOOD
# 장르: Action & Adventure, 애니메이션, Sci-Fi & Fantasy, 코미디, 드라마
# 시즌 수: 1
# 줄거리: 죽은 어머니를 살리기 위해 시도한 금단의 연금술로 인해 신체의 일부와 전부를 빼앗긴 에드워드와 알폰스 형제. 동생 알폰스의 신체를 되찾기 위해 현자의 돌을 찾아나선다. 강철의 연금술사 오리지널판 이후 제작되어 원작 만화를 더욱 충실히 반영한 리메이크 버전이다.
# 등급: 15
# 출연진:
# 박로미
# 쿠기미야 리에
# 미키 신이치로
# 제작진:
# Akira Senju
# 로고 URL: https://image.tmdb.org/t/p/original/gMIqyAOrFP1E6lQ9S093KcNgoHK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/5ZFUEOULaVml7pQuXxhpR2SmVUw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=8nm-Qd0zwJM
#
# id: 22980
# 제목: Watch What Happens Live with Andy Cohen
# 장르: Talk, Comedy
# 시즌 수: 21
# 줄거리: Bravo network executive Andy Cohen discusses pop culture topics with celebrities and reality show personalities.
# 등급: None
# 출연진:
# Andy Cohen
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/oYB3zGjXNrmmznTUAxORfReWzhw.png
# 포스터 URL: https://image.tmdb.org/t/p/original/onSD9UXfJwrMXWhq7UY7hGF2S1h.jpg
#
# id: 58841
# 제목: 시카고 PD
# 장르: 범죄, 드라마
# 시즌 수: 11
# 줄거리: 시카고 경찰들의 이야기. 일선에서 직접 범죄자들과 싸우는 제복 경찰들과, 조직범죄나 마약밀매 등의 범죄를 조사하는 정보팀 소속 대원들의 활약을 그린다.
# 등급: 15
# 출연진:
# Jason Beghe
# Tracy Spiridakos
# Marina Squerciati
# 제작진:
# Dick Wolf
# 로고 URL: https://image.tmdb.org/t/p/original/mcwj8Di0nBdaraQrMji6VauMBeZ.png
# 포스터 URL: https://image.tmdb.org/t/p/original/mZObarMPF76PGVmwywQ7Ks4UFpR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=NZcr9IFS9R0
#
# id: 65701
# 제목: Good Mythical Morning
# 장르: Comedy
# 시즌 수: 25
# 줄거리: Two "Internetainers" (Rhett & Link) go far out and do the weirdest  things, giving you a daily dose of casual comedy every Monday-Friday.
# 등급: None
# 출연진:
# Link Neal
# Rhett McLaughlin
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/2Fja87aTeuXxTEI1MH2IuHHSsLq.jpg
# 예고편 URL: https://www.youtube.com/watch?v=1iLbfGIygO0
#
# id: 237480
# 제목: No Rancho Fundo
# 장르: Soap, Drama, Comedy
# 시즌 수: 1
# 줄거리:
# 등급: None
# 출연진:
# Larissa Bocchino
# Andréa Beltrão
# Alexandre Nero
# 제작진:
# Mário Teixeira
#
# id: 3172
# 제목: 프라이빗 프랙티스
# 장르: 드라마
# 시즌 수: 6
# 줄거리: 스핀오프 시리즈. 시애틀의 그레이스 병원을 떠나, LA의 작은 병원 씨사이드 웰니스(Seaside Wellness)로 근무지를 옮긴 애디슨 몽고메리 박사와 그 동료들의 이야기.
# 등급: 12
# 출연진:
# 케이트 월시
# Paul Adelstein
# KaDee Strickland
# 제작진:
# Mark Gordon
# 로고 URL: https://image.tmdb.org/t/p/original/s7sVPIHXsWPEaHR17ag3MXp0bQR.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pW20ANAGdrgreYJExduUVaWos6H.jpg
#
# id: 1778
# 제목: Zoey 101
# 장르: Comedy
# 시즌 수: 4
# 줄거리: Zoey 101 is an American television series which originally aired on Nickelodeon from January 9, 2005 until May 2, 2008. It focuses on the lives of teenager Zoey Brooks and her friends as they attend Pacific Coast Academy, a fictional boarding school in Southern California. It was created by Dan Schneider. It was initially filmed at Pepperdine University in Malibu, California, then at stages in Valencia, California beginning in season 3. It was nominated for an "Outstanding Children's Program" Emmy in 2005. Zoey 101 was the most expensive production ever for Nickelodeon series, as it was shot completely on location in Malibu. It was also Nickelodeon's best performance for a series premiere in almost eight years. Despite this, many critics have made negative comments about the show, its setting, and its characters.
# 등급: 6
# 출연진:
# Jamie Lynn Spears
# Paul Butcher
# Victoria Justice
# 제작진:
# Bill O'Dowd
# 로고 URL: https://image.tmdb.org/t/p/original/x8GvXInGjxOgGQZ3eryFm4ADtZW.png
# 포스터 URL: https://image.tmdb.org/t/p/original/A3O2B4cHEyMpvknrdG4bcV4eaYh.jpg
# 예고편 URL: https://www.youtube.com/watch?v=RX6YeYT3ed8
#
# id: 78191
# 제목: 너의 모든 것
# 장르: 드라마
# 시즌 수: 5
# 줄거리: 지적이고 영리한 서점 직원. 하지만 위험한 내면을 지닌 그가 작가 지망생에게 반한다. 마음이 끌리는 사람에게 다가가기 위해서라면, 무슨 짓이든 할 수 있다. 위험한 매력의 소유자, 집착의 끝을 보여주는 남자. 그의 소름 끼치는 로맨스가 시작된다.
# 등급: 19
# 출연진:
# Penn Badgley
# Charlotte Ritchie
# Tilly Keeper
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/VeNCc4i7LbRQpwC1mYl5jtBzFM.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7bEYwjUvlJW7GerM8GYmqwl4oS3.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ga1m0wjzscU
#
# id: 206559
# 제목: Binnelanders
# 장르: Soap
# 시즌 수: 19
# 줄거리: A South African Afrikaans soap opera. It is set in and around the fictional private hospital, Binneland Kliniek, in Pretoria, and the storyline follows the trials, trauma and tribulations of the staff and patients of the hospital.
# 등급: None
# 출연진:
# Hans Strydom
# Reynardt Hugo
# Hykie Berg
# 제작진:
# Jak de Priester
# 예고편 URL: https://www.youtube.com/watch?v=Uegxh8K8g3E
#
# id: 1532
# 제목: Starsky & Hutch
# 장르: Action & Adventure, Drama, Crime
# 시즌 수: 4
# 줄거리: Streetwise Detective David Starsky partners up with a more intellectual partner, Kenneth 'Hutch' Hutchinson, to protect citizens and patrol the streets of Bay City.
# 등급: 12
# 출연진:
# David Soul
# Paul Michael Glaser
# Antonio Fargas
# 제작진:
# Aaron Spelling
# 포스터 URL: https://image.tmdb.org/t/p/original/aBj5oTi1uibVcXDoCJeKseJNY2d.jpg
# 예고편 URL: https://www.youtube.com/watch?v=8WHQ2UWB2ko
#
# id: 94722
# 제목: Tagesschau
# 장르: News
# 시즌 수: 73
# 줄거리: German daily news program, the oldest still existing program on German television.
# 등급: None
# 출연진:
# 제작진:
#
# id: 39852
# 제목: 죄인
# 장르: 범죄, 드라마
# 시즌 수: 4
# 줄거리: 평범한 젊은 엄마가 처음 보는 남자를 칼로 찔러 죽인다. 그녀 자신마저 알 수 없는 이유로. 그녀를 동정하는 형사는 진실을 찾아 사라진 기억의 미궁 속으로 발을 들인다.
# 등급: 16
# 출연진:
# 빌 풀먼
# 프랜시스 피셔
# Alice Kremelberg
# 제작진:
# David DeMarinis
# 로고 URL: https://image.tmdb.org/t/p/original/xbOpER6gqANjw7GpQz3wfMzasRK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/rmibFGdqOe0kKKhPls0jVOdZCWw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ZEfnpFuzxnE
#
# id: 269
# 제목: One Tree Hill
# 장르: Drama
# 시즌 수: 9
# 줄거리: In Tree Hill, North Carolina two half brothers share a last name and nothing else. Brooding, blue-collar Lucas is a talented street-side basketball player, but his skills are appreciated only by his friends at the river court. Popular, affluent Nathan basks in the hero-worship of the town, as the star of his high school team. And both boys are the son of former college ball player Dan Scott whose long ago choice to abandon Lucas and his mother Karen, will haunt him long into his life with wife Deb and their son Nathan.
# 등급: 16
# 출연진:
# James Lafferty
# Bethany Joy Lenz
# Sophia Bush
# 제작진:
# Michael Tollin
# 로고 URL: https://image.tmdb.org/t/p/original/oEcHVvhnD4XHwdbR7Bg2F7y2vZB.png
# 포스터 URL: https://image.tmdb.org/t/p/original/sOrelBaAhp7DZbPTivDwKEyPslC.jpg
# 예고편 URL: https://www.youtube.com/watch?v=GIFbz7uTOKI
#
# id: 63770
# 제목: The Late Show with Stephen Colbert
# 장르: Comedy, Talk
# 시즌 수: 9
# 줄거리: Stephen Colbert brings his signature satire and comedy to The Late Show with Stephen Colbert, the #1 show in late night, where he talks with an eclectic mix of guests about what is new and relevant in the worlds of politics, entertainment, business, music, technology, and more. Featuring bandleader Jon Batiste with his band Stay Human, the Emmy Award-nominated show is broadcast from the historic Ed Sullivan Theater. Stephen Colbert, Chris Licht, Tom Purcell, and Jon Stewart are executive producers. Barry Julien and Denise Rehrig serve as co-executive producers.must watch
# 등급: None
# 출연진:
# Stephen Colbert
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/wdjsrCJWXtwNpW9NmtpcTJqOCNY.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9jkThAGYj2yp8jsS6Nriy5mzKFT.jpg
# 예고편 URL: https://www.youtube.com/watch?v=nWufb0qL1xU
#
# id: 31248
# 제목: It's Showtime
# 장르: Comedy, Reality
# 시즌 수: 4
# 줄거리: A Philippine noontime musical and party variety show. What began as a search for the country’s most entertaining acts evolves into a hit variety program thriving on spontaneity and animated conversations while drawing talents from all walks of life.
# 등급: None
# 출연진:
# Vice Ganda
# Anne Curtis
# Vhong Navarro
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/nKxXaAIO2ljugKhKFYQ8LmIJ1x7.jpg
#
# id: 41149
# 제목: Die Rosenheim-Cops
# 장르: Crime
# 시즌 수: 23
# 줄거리:
# 등급: 12
# 출연진:
# Max Müller
# Marisa Burger
# Igor Jeftic
# 제작진:
#
# id: 71790
# 제목: 스와트
# 장르: 범죄, Action & Adventure, 드라마
# 시즌 수: 7
# 줄거리: 로스앤젤레스에서 발생하는 특수임무를 수행하는 특수 기동대, S.W.A.T.은 리더 혼도의 지휘 아래, 팀원들은 꼬리에 꼬리를 무는 사건과 그 뒤에 숨은 거대한 세력에 맞서 도시를 지킨다.
# 등급: 12
# 출연진:
# Shemar Moore
# Jay Harrington
# David Lim
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/uBxIeTKeYhtdI8TtWYqIrAgFvSt.png
# 포스터 URL: https://image.tmdb.org/t/p/original/1l7vsAIkqOzrqiPwjO27Cb5QdfJ.jpg
# 예고편 URL: https://www.youtube.com/watch?v=HHVae76dbqI
#
# id: 1667
# 제목: Saturday Night Live
# 장르: Comedy, News
# 시즌 수: 49
# 줄거리: A late-night live television sketch comedy and variety show created by Lorne Michaels. The show's comedy sketches, which parody contemporary culture and politics, are performed by a large and varying cast of repertory and newer cast members. Each episode is hosted by a celebrity guest, who usually delivers an opening monologue and performs in sketches with the cast, and features performances by a musical guest.
# 등급: 16
# 출연진:
# Michael Che
# Mikey Day
# Andrew Dismukes
# 제작진:
# Lorne Michaels
# 로고 URL: https://image.tmdb.org/t/p/original/p7y5gW1JqePKQTrpmkiRFnH6fUX.png
# 포스터 URL: https://image.tmdb.org/t/p/original/sHGuKFjIBisPk8cvtCZTDVktYfs.jpg
# 예고편 URL: https://www.youtube.com/watch?v=_Np6fu-0OoY
#
# id: 30984
# 제목: 블리치
# 장르: Action & Adventure, 애니메이션, Sci-Fi & Fantasy
# 시즌 수: 2
# 줄거리: '쿠로사키 이치고'는 유령을 볼 수 있는 15세의 남자다. 특수한 체질을 가지고도 평범한 생활을 하던 이치고에게 갑자기 스스로를 사신이라고 소개하는 소녀 '쿠치키 루키아'가 나타난다. 유아울러 산 사람, 죽은 사람 안 가리고 공격해서 영혼을 먹어치우는 나쁜 혼령 '호로'도 모습을 드러낸다. 그런데 호로로 인해 이치고의 가족이 쓰러져가는데...
# 등급: 15
# 출연진:
# Masakazu Morita
# 折笠富美子
# 安元洋貴
# 제작진:
# Haruo Miyagawa
# 로고 URL: https://image.tmdb.org/t/p/original/21zm3sP3j6rmpbZR3j0quusRe6h.png
# 포스터 URL: https://image.tmdb.org/t/p/original/2EewmxXe72ogD0EaWM8gqa0ccIw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=T6wo7bfYYu4
#
# id: 231418
# 제목: Salón de té La Moderna
# 장르: Soap, Drama
# 시즌 수: 2
# 줄거리:
# 등급: 12
# 출연진:
# 제작진:
#
# id: 46298
# 제목: 헌터x헌터
# 장르: 애니메이션, Action & Adventure, Sci-Fi & Fantasy
# 시즌 수: 3
# 줄거리: 주인공 곤 프릭스는 아버지 진 프릭스를 찾기 위해 헌터 시험에 응시한다. 그리고 그곳에서 새로운 친구들과 만나 모험을 떠난다.
# 등급: 12
# 출연진:
# 한 메구미
# 이세 마리야
# 二又一成
# 제작진:
# Hiroshi Koujina
# 로고 URL: https://image.tmdb.org/t/p/original/aPCnfL0Tt4CxUXQLBIRmsbrF02X.png
# 포스터 URL: https://image.tmdb.org/t/p/original/ucpgmUR1h5Te1BYegKItoPjOeF7.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qibSkLoSVAA
#
# id: 10545
# 제목: 트루 블러드
# 장르: Sci-Fi & Fantasy, 드라마, 미스터리
# 시즌 수: 7
# 줄거리: 샬레인 해리스의 베스트셀러 소설을 바탕으로 한다. 루이지애나의 한 바에서 웨이트리스 일하는 수키. 조용하고 총명하며 아름다운 그녀에게는 다른 사람의 마음을 읽을 수 있는 능력이 있다. 그러던 어느 날, 매력적인 뱀파이어 빌이 나타나는데, 그녀는 그의 마음을 읽어낼 수가 없다. 그러면서 수키는 빌에게 빠져들기 시작한다. 하지만 뱀파이어들은 살인을 저질렀다는 의심을 받고 자꾸 무서운 일들이 일어나는데..
# 등급: 19
# 출연진:
# 안나 패퀸
# Stephen Moyer
# 알렉산더 스카스가드
# 제작진:
# Alan Ball
# 로고 URL: https://image.tmdb.org/t/p/original/mETkvJgly1edlc6gOyqwrXYrppi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/ktEp6fzL4xzCWsSVtrcH8JaQNQy.jpg
# 예고편 URL: https://www.youtube.com/watch?v=3Wk3HSiX-vQ
#
# id: 17610
# 제목: NCIS: 로스앤젤레스
# 장르: Action & Adventure, 드라마, 범죄, 미스터리
# 시즌 수: 14
# 줄거리: LA 지역에서 활동하는 NCIS 특수작전부 소속 위장잡입수사 전문요원들의 활약을 그린다. NCIS의 첫번째 스핀오프 시리즈.
# 등급: 15
# 출연진:
# Chris O'Donnell
# Daniela Ruah
# Eric Christian Olsen
# 제작진:
# Shane Brennan
# 로고 URL: https://image.tmdb.org/t/p/original/4WlxwU0nXG1W0hJqT58w2AWHPQM.png
# 포스터 URL: https://image.tmdb.org/t/p/original/TIIgcznwNfNr3KOZvxn26eKV99.jpg
# 예고편 URL: https://www.youtube.com/watch?v=Or5YChRcVAM
#
# id: 206679
# 제목: Na lovu
# 장르: Reality, Family
# 시즌 수: 5
# 줄거리: Na Lovu is a Czech game-show, based on the license of the popular global format The Chase. A heart-racing quiz show where four competitors must pit their wits and face off against Lovec (the Chaser), a ruthless quiz genius determined to stop them from winning cash prizes.
# 등급: None
# 출연진:
# Dagmar Jandová
# Jakub Kvašovský
# Václav Slabyhoudek
# 제작진:
# Michael Čech
# 예고편 URL: https://www.youtube.com/watch?v=3qMx-Sdsc_8
#
# id: 4660
# 제목: Adam-12
# 장르: Crime, Drama
# 시즌 수: 7
# 줄거리: Adam-12 is a television police drama that followed two police officers of the Los Angeles Police Department, Pete Malloy and Jim Reed, as they patrolled the streets of Los Angeles in their patrol unit, 1-Adam-12.
# 등급: 12
# 출연진:
# Martin Milner
# Kent McCord
# William Boyett
# 제작진:
# Jack Webb
# 로고 URL: https://image.tmdb.org/t/p/original/lBlwuCkIYAkts9bFM3IU5eKFQaz.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9hY1H8A6sPghNNHPQJYMgJYpemZ.jpg
#
# id: 3750
# 제목: 닙턱
# 장르: 드라마
# 시즌 수: 7
# 줄거리: 크리스찬 트로이와 션 맥나마라는 성격과 라이프스타일은 완전히 다르지만 절친한 친구. 둘 다 성형외과 의사지만, 성격과 라이프 스타일은 완전히 다른 두 친구의 이야기가 그려진다.
# 등급: 16
# 출연진:
# Dylan Walsh
# Julian McMahon
# 조엘리 리처드슨
# 제작진:
# Jennifer Salt
# 로고 URL: https://image.tmdb.org/t/p/original/kkmindhb8tJLA8Z1tM4ttUF53tO.png
# 포스터 URL: https://image.tmdb.org/t/p/original/b8wq87RBCman73pxQzWWK93Eicu.jpg
# 예고편 URL: https://www.youtube.com/watch?v=v6JdfGMQK98
#
# id: 4349
# 제목: Melrose Place
# 장르: Drama, Soap
# 시즌 수: 7
# 줄거리: Follow the lives of a group of young adults living in a brownstone apartment complex on Melrose Place, in Los Angeles, California.
# 등급: 16
# 출연진:
# Thomas Calabro
# Heather Locklear
# Josie Bissett
# 제작진:
# Charles Pratt, Jr.
# 로고 URL: https://image.tmdb.org/t/p/original/zYHVxWvhYORA90tbH035tro2337.png
# 포스터 URL: https://image.tmdb.org/t/p/original/kIc03DwT3DPd48lKlbpyPxx3O1S.jpg
# 예고편 URL: https://www.youtube.com/watch?v=NVPKdTenbAY
#
# id: 121
# 제목: 닥터 후
# 장르: 드라마, Action & Adventure, Sci-Fi & Fantasy
# 시즌 수: 26
# 줄거리: '타디스'를 타고 미래와 과거를 넘나들며 외계로부터 지구를 지키기 위해 싸우는 닥터의 시간 여행 이야기
# 등급: 12
# 출연진:
# Sylvester McCoy
# 제작진:
# John Nathan-Turner
# 로고 URL: https://image.tmdb.org/t/p/original/ravZWAkRX4EMAfGlR9BtMXdvurO.png
# 포스터 URL: https://image.tmdb.org/t/p/original/xinqAmYrZ1TEwowcQhgTkZVtVE0.jpg
# 예고편 URL: https://www.youtube.com/watch?v=_iSzCV3C-50
#
# id: 240909
# 제목: La Casa de los Famosos Colombia
# 장르: Reality
# 시즌 수: 1
# 줄거리:
# 등급: None
# 출연진:
# Carla Giraldo
# Cristina Hurtado
# Martha Isabel Bolaños
# 제작진:
#
# id: 71728
# 제목: 영 셸든
# 장르: 코미디, 가족
# 시즌 수: 7
# 줄거리: '빅뱅이론'의 주인공 셸든 쿠퍼의 어린 시절을 다룬 이야기.
# 등급: 12
# 출연진:
# Iain Armitage
# Zoe Perry
# Lance Barber
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/phbaDwOu5BKrWpN3FiKgFRxhkn4.png
# 포스터 URL: https://image.tmdb.org/t/p/original/tKwjkqTSq5fJdSxIk4yOh61tOKD.jpg
# 예고편 URL: https://www.youtube.com/watch?v=FStMMcj-RiA
#
# id: 112470
# 제목: Here it all begins
# 장르: Soap, Drama
# 시즌 수: 4
# 줄거리:
# 등급: None
# 출연진:
# Aurélie Pons
# Julie Sassoust
# Rébecca Benhamour
# 제작진:
# Eric Fuhrer
#
# id: 45854
# 제목: 유희왕 ZEXAL
# 장르: 애니메이션, 코미디, Action & Adventure, Sci-Fi & Fantasy
# 시즌 수: 1
# 줄거리: 근미래의 마을, 하트랜드 시티에서는 어른도 아이도 AR 듀얼에 열중하고 있다.
#
# AR 듀얼이란, 「D-게이저」와 「D-패드」를 사용하는 듀얼로,
#
# 이 2가지를 사용하는 것으로,
#
# 지면에서, 하늘에서, 그리고 건물에서
#
# 몬스터가 현실에
#
# 튀어나와 맞부딪치는,
#
# 무지막지 박력 넘치는 듀얼!
#
# 이 마을에 사는 주인공 츠쿠모 유마도
#
# 이 듀얼에 열중하고 있지만,
#
# 실력은 초심자 레벨의 연전연패 챔피언.
#
# 어느 사건을 계기로, 학교 제일의 불량배 료가와
#
# 듀얼로 승부를 내게 된 유마.
#
# 이 듀얼이, 유마의 운명을 크게 바꿔놓는다...!
#
# 이 결투 중, 항상 유마의 꿈에 나오는 불길한 문이 돌연 나타난다.
#
# 굳게 닫혀 있던 문이 개방된 순간, 무수한 빛이 넘쳐 나와,
#
# 놀라서 옆을 올려다보니...
#
# 거기에는 이세계에서 온 수수께끼의 생명체 아스트랄이 서 있었다!
#
# 아스트랄의 잃어버린 기억, 99장의 넘버즈 카드를 되찾기 위해,
#
# 둘은 함께 행동하기로 한다.
#
# 아스트랄이 나타난 진정한 이유란?
#
# 그리고, 새로운 몬스터 「넘버즈 몬스터」의
#
# 존재는 도대체 무엇이란 말인가?
#
# 계속해서 유마의 앞에 나타나는 강력한 라이벌,
#
# 그리고 밝혀져가는 아스트랄의 수수께끼.
#
# 이 콤비에 의한 새로운 듀얼의 전설이 지금, 막을 연다!!
# 등급: 6
# 출연진:
# 하타나카 타스쿠
# 이리노 미유
# 谷育子
# 제작진:
# Wataru Nakagawa
# 포스터 URL: https://image.tmdb.org/t/p/original/3aZUtzeHQrLgQQdYNqHSbJqj59G.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ajFTuo6LQLc
#
# id: 95
# 제목: 버피와 뱀파이어
# 장르: Sci-Fi & Fantasy, 코미디, 드라마, Action & Adventure
# 시즌 수: 7
# 줄거리: 전설로만 내려오고 있는 뱀파이어 슬레이어의 숙명을 지니고 살아가는 평범한 여학생이 친구들과 많은 조력자들과 함께 뱀파이어 및 괴물들을 퇴치해나가는 이야기
# 등급: 15
# 출연진:
# 사라 미셸 갤러
# Nicholas Brendon
# 앨리슨 해니건
# 제작진:
# 드류 고다드
# 로고 URL: https://image.tmdb.org/t/p/original/5l2r7nv4dGWq1YQWaqBRe0FkQhi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/41jsOEYsh9lJBc6AZqGpR1ETpx5.jpg
# 예고편 URL: https://www.youtube.com/watch?v=-1v_q6TWAL4
#
# id: 10536
# 제목: The Mike Douglas Show
# 장르: Comedy, Talk
# 시즌 수: 21
# 줄거리: The Mike Douglas Show is an American daytime television talk show hosted by Mike Douglas that originally aired only in the Cleveland area during much of its first two years on the air. It then went into syndication in 1963 and remained on television until 1982. It was distributed by Westinghouse Broadcasting and for much of its run, originated from studios of two of the company's TV stations in Cleveland and Philadelphia.
# 등급: None
# 출연진:
# Mike Douglas
# 제작진:
# Jack Reilly
#
# id: 22980
# 제목: Watch What Happens Live with Andy Cohen
# 장르: Talk, Comedy
# 시즌 수: 21
# 줄거리: Bravo network executive Andy Cohen discusses pop culture topics with celebrities and reality show personalities.
# 등급: None
# 출연진:
# Andy Cohen
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/oYB3zGjXNrmmznTUAxORfReWzhw.png
# 포스터 URL: https://image.tmdb.org/t/p/original/onSD9UXfJwrMXWhq7UY7hGF2S1h.jpg
#
# id: 32798
# 제목: 하와이 파이브 오
# 장르: 범죄, 드라마, Action & Adventure
# 시즌 수: 10
# 줄거리: 하와이를 배경으로 범죄 조직에 맞서 싸우는 블록버스터 액션 드라마
# 등급: 16
# 출연진:
# Alex O'Loughlin
# Scott Caan
# Ian Anthony Dale
# 제작진:
# Andie Neumann
# 로고 URL: https://image.tmdb.org/t/p/original/7jdKgmCQK5eNoxB44ptJnM5FCxq.png
# 포스터 URL: https://image.tmdb.org/t/p/original/sIdCKlmM2nU4akIvFQaAIiU8YES.jpg
# 예고편 URL: https://www.youtube.com/watch?v=xy30TGdaEAE
#
# id: 31911
# 제목: 강철의 연금술사 BROTHERHOOD
# 장르: Action & Adventure, 애니메이션, Sci-Fi & Fantasy, 코미디, 드라마
# 시즌 수: 1
# 줄거리: 죽은 어머니를 살리기 위해 시도한 금단의 연금술로 인해 신체의 일부와 전부를 빼앗긴 에드워드와 알폰스 형제. 동생 알폰스의 신체를 되찾기 위해 현자의 돌을 찾아나선다. 강철의 연금술사 오리지널판 이후 제작되어 원작 만화를 더욱 충실히 반영한 리메이크 버전이다.
# 등급: 15
# 출연진:
# 박로미
# 쿠기미야 리에
# 미키 신이치로
# 제작진:
# Akira Senju
# 로고 URL: https://image.tmdb.org/t/p/original/gMIqyAOrFP1E6lQ9S093KcNgoHK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/5ZFUEOULaVml7pQuXxhpR2SmVUw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=8nm-Qd0zwJM
#
# id: 1486
# 제목: 21 Jump Street
# 장르: Crime, Mystery, Drama
# 시즌 수: 5
# 줄거리: 21 Jump Street revolves around a group of young cops who would use their youthful appearance to go undercover and solve crimes involving teenagers and young adults.
# 등급: 16
# 출연진:
# Holly Robinson Peete
# Michael Bendetti
# Peter DeLuise
# 제작진:
# Stephen J. Cannell
# 로고 URL: https://image.tmdb.org/t/p/original/iDdGGwmrCMZcfubJfSiuJ4MI9hK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9w2y0146P5EjLw63FHGWRRpqQ6v.jpg
# 예고편 URL: https://www.youtube.com/watch?v=VwieJWDCUTw
#
# id: 954
# 제목: The Rockford Files
# 장르: Crime, Drama, Mystery
# 시즌 수: 6
# 줄거리: Cranky but likable L.A. PI Jim Rockford pulls no punches (but takes plenty of them). An ex-con sent to the slammer for a crime he didn't commit, Rockford takes on cases others don't want, aided by his tough old man, his lawyer girlfriend and some shady associates from his past.
# 등급: 12
# 출연진:
# James Garner
# Noah Beery Jr.
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/fniHEsTeqHMg41GlCYJxZVgtn7H.jpg
# 예고편 URL: https://www.youtube.com/watch?v=W1zYNrsx9Pw
#
# id: 41149
# 제목: Die Rosenheim-Cops
# 장르: Crime
# 시즌 수: 23
# 줄거리:
# 등급: 12
# 출연진:
# Max Müller
# Marisa Burger
# Igor Jeftic
# 제작진:
#
# id: 4660
# 제목: Adam-12
# 장르: Crime, Drama
# 시즌 수: 7
# 줄거리: Adam-12 is a television police drama that followed two police officers of the Los Angeles Police Department, Pete Malloy and Jim Reed, as they patrolled the streets of Los Angeles in their patrol unit, 1-Adam-12.
# 등급: 12
# 출연진:
# Martin Milner
# Kent McCord
# William Boyett
# 제작진:
# Jack Webb
# 로고 URL: https://image.tmdb.org/t/p/original/lBlwuCkIYAkts9bFM3IU5eKFQaz.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9hY1H8A6sPghNNHPQJYMgJYpemZ.jpg
#
# id: 246023
# 제목: Marea de pasiones
# 장르: Drama
# 시즌 수: 1
# 줄거리:
# 등급: None
# 출연진:
# Oka Giner
# Matías Novoa
# Alejandro de la Madrid
# 제작진:
# Rodrigo Cachero
# 예고편 URL: https://www.youtube.com/watch?v=CE5O6efGuPY
#
# id: 78191
# 제목: 너의 모든 것
# 장르: 드라마
# 시즌 수: 5
# 줄거리: 지적이고 영리한 서점 직원. 하지만 위험한 내면을 지닌 그가 작가 지망생에게 반한다. 마음이 끌리는 사람에게 다가가기 위해서라면, 무슨 짓이든 할 수 있다. 위험한 매력의 소유자, 집착의 끝을 보여주는 남자. 그의 소름 끼치는 로맨스가 시작된다.
# 등급: 19
# 출연진:
# Penn Badgley
# Charlotte Ritchie
# Tilly Keeper
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/VeNCc4i7LbRQpwC1mYl5jtBzFM.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7bEYwjUvlJW7GerM8GYmqwl4oS3.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ga1m0wjzscU
#
# id: 62223
# 제목: The Late Late Show with James Corden
# 장르: Talk
# 시즌 수: 8
# 줄거리: Once Craig Ferguson retires, James Corden will be taking over The Late Late Show. The show is a late night talk show that interviews celebrities and has its own bits. And of course, it's all hosted by James Corden.
# 등급: None
# 출연진:
# James Corden
# Reggie Watts
# 제작진:
# Michelle Basterrechea
# 로고 URL: https://image.tmdb.org/t/p/original/kbzQZcqqjlP1C2WqfZhC0OIp1vE.png
# 포스터 URL: https://image.tmdb.org/t/p/original/qPmVoG8G9tc1nN8ZwGV2zYcknit.jpg
# 예고편 URL: https://www.youtube.com/watch?v=32vP1xZbJSU
#
# id: 223365
# 제목: Rebirth
# 장르: Soap, Drama
# 시즌 수: 1
# 줄거리: After making a pact with Jequitibá, José Inocêncio becomes a mythical figure, known as the most successful cocoa farmer in the region. While still young, he wins the heart of Maria Santa. Their intense passion results in four children: José Augusto, José Bento, José Venâncio, and the youngest, João Pedro, who never had the opportunity to know his mother, as she dies while giving birth to him. This tragedy fuels José Inocêncio’s anger, blaming João Pedro for the loss of his great love. Throughout their lives, indifference and resentment mark the relationship between the father and his youngest son. As if the past weren’t enough, years later, the arrival of the mysterious Mariana puts all these emotions to the test when both father and son fall in love with the same woman. This situation reawakens feelings that were either dormant or previously unknown to them.
# 등급: None
# 출연진:
# Marcos Palmeira
# Theresa Fonseca
# Juan Paiva
# 제작진:
# Bruno Luperi
#
# id: 245830
# 제목: Hidden in paradise
# 장르:
# 시즌 수: 1
# 줄거리: This takes us to the Istrian camp Paradiso, where vacationers recharge their batteries away from the hustle and bustle of the capital city. The main characters, fall in love at first sight, but face a series of complications.
# 등급: None
# 출연진:
# Gaja Filač
# Matej Zemljič
# Sabina Kogovšek
# 제작진:
# 예고편 URL: https://www.youtube.com/watch?v=DZyRMVeCkZc
#
# id: 246331
# 제목: 수지맞은 우리
# 장르: 가족, 드라마
# 시즌 수: 1
# 줄거리: 추락한 스타 의사 진수지와 무대뽀 초짜 의사 채우리의 쌍방 치유, 정신 승리, 공감 로맨스 & 핏줄 노노! 호적 타파, 신개념 가족 만들기에 대한 이야기
# 등급: 15
# 출연진:
# 함은정
# 백성현
# 오현경
# 제작진:
# Park Ki-hyun
# 포스터 URL: https://image.tmdb.org/t/p/original/bGVdZ8nc99GIwCDxmXpGP0oCSzT.jpg
# 예고편 URL: https://www.youtube.com/watch?v=Bub9mJwWQuo
#
# id: 222289
# 제목: Família é Tudo
# 장르: Comedy, Soap, Action & Adventure
# 시즌 수: 1
# 줄거리:
# 등급: None
# 출연진:
# Arlete Salles
# Juliana Paiva
# Nathalia Dill
# 제작진:
# Fred Mayrink
#
# id: 1100
# 제목: 내가 그녀를 만났을 때
# 장르: 코미디
# 시즌 수: 9
# 줄거리: 《내가 그녀를 만났을 때》는 미국 CBS에서 방영되었던 시트콤이다. 소울메이트를 찾기 위한 테드의 기나긴 여정. 어른이 된 테드가 아이들에게 아빠와 엄마가 만난 이야기를 들려주며 회상하는 장면들로 이뤄진다.
# 등급: 15
# 출연진:
# Josh Radnor
# 닐 패트릭 해리스
# Jason Segel
# 제작진:
# Rachel Axler
# 로고 URL: https://image.tmdb.org/t/p/original/1bYJhHks9QBfsLXmbdkwlSMSaBC.png
# 포스터 URL: https://image.tmdb.org/t/p/original/b34jPzmB0wZy7EjUZoleXOl2RRI.jpg
# 예고편 URL: https://www.youtube.com/watch?v=cjJLEYMzpjc
#
# id: 14929
# 제목: 하트랜드
# 장르: 가족, 드라마, 코미디
# 시즌 수: 17
# 줄거리: 야무진 소녀 에이미는 어머니의 갑작스럽게 죽은 충격에서 헤어나지 못 한다. 한편 에이미와 그녀의 할아버지는 목장을 잃을 수 있는 위기에 봉착한다.
# 등급: 12
# 출연진:
# Amber Marshall
# Graham Wardle
# Shaun Johnston
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/1bVQuM21SMsCAIkSe61HvBdKlfi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/uc2gtWczT58BiAUJWFz9P5aZmNF.jpg
# 예고편 URL: https://www.youtube.com/watch?v=gnLKnXN6VQc
#
# id: 918
# 제목: M*A*S*H
# ...
# 등급: ALL
# 출연진:
# Dave McCormack
# Melanie Zanetti
# 제작진:
# Libbie Doherty
# 로고 URL: https://image.tmdb.org/t/p/original/mSajMzX7C0gHys7T2bCx09Mj3Tc.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/b9mY0X5T20ZM073hoa5n0dgmbfN.jpg
# 예고편 URL: https://www.youtube.com/watch?v=2ZtG5Ba6iT0
#
# id: 799
# 제목: 셜록 홈즈
# 장르: 범죄, 드라마, 미스터리
# 시즌 수: 7
# 줄거리: 《셜록 홈즈》(영어: Sherlock Holmes)는 영국 그라나다 TV가 제작한 텔레비전 드라마이다. 1984년부터 1994년까지 10년 동안 방영됐다. 원작자 아서 코난 도일은 셜록 홈즈 시리즈를 60편 썼는데 이중 42편이 드라마로 제작됐다. 주인공 셜록 홈즈는 배우 제레미 브렛이 맡았고, 셜록의 파트너 닥터 왓슨은 데이비드 버크가 맡았다가 에드워드 하드위크로 교체됐다.
# 등급: None
# 출연진:
# Jeremy Brett
# Edward Hardwicke
# Rosalie Williams
# 제작진:
# Michael Cox
# 로고 URL: https://image.tmdb.org/t/p/original/wLYUSvuk295W3jE1yAJPtcdp6Gx.png
# 포스터 URL: https://image.tmdb.org/t/p/original/thC0OuUvfGbOcoJ3aY5L4vlO6lA.jpg
# 예고편 URL: https://www.youtube.com/watch?v=LMAroBYfJxs
#
# id: 222490
# 제목: Young Babylon
# 장르: Drama
# 시즌 수: 1
# 줄거리: It follows a group of vibrant teenagers in the early 1990s in Fucheng, a small coastal town in Southeast China. They passionately chase after their youth on the era's train, experiencing uninhibited growth and seeking an extraordinary transformation. In this radiant period of youth, they strive towards a brilliant era of personal growth and love.
# 등급: None
# 출연진:
# Hou Minghao
# Yang Caiyu
# Xiang Hanzhi
# 제작진:
# Lin Yu-hsien
# 포스터 URL: https://image.tmdb.org/t/p/original/egTFS7vinNVJ0tQcu1y956I780m.jpg
# 예고편 URL: https://www.youtube.com/watch?v=yd8AYWKIVvU
#
# id: 4477
# 제목: Becker
# 장르: Comedy
# 시즌 수: 6
# 줄거리: Becker is a dedicated, outspoken and talented doctor with a gruff exterior. While he tends to offend those who try to get close to him, he is extremely dedicated to his medical practice in the Bronx, N.Y., where he always goes the extra mile to help those in need. But Dr. John Becker looks at the world around him and sees a society gone mad, full of incongruities and just plain wrong thinking. And he has no qualms about saying anything that comes to mind – anything.
# 등급: None
# 출연진:
# Ted Danson
# Hattie Winston
# Shawnee Smith
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/m8ZRWJMXFXNBGhqp4RkeGwIaFPq.png
# 포스터 URL: https://image.tmdb.org/t/p/original/w8qCJKotfqh5M2oMsbFNt5xuWP7.jpg
# 예고편 URL: https://www.youtube.com/watch?v=eUYfmXGWmTs
#
# id: 96580
# 제목: 레지던트 에이리언
# 장르: Sci-Fi & Fantasy
# 시즌 수: 3
# 줄거리: 지구로 불시착한 외계인이 콜로라도 작은 마을의 의사로 살아가며 비밀 임무와 함께 마을의 살인 사건을 수사하는 이야기
# 등급: 12
# 출연진:
# 앨런 튜딕
# Sara Tomko
# Corey Reynolds
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/kBCKosmxeoi9OnmjUl0eBrmpZRU.png
# 포스터 URL: https://image.tmdb.org/t/p/original/6sNfBnagv9CIyRs4zp4Nvo9LrWr.jpg
# 예고편 URL: https://www.youtube.com/watch?v=izz0zCDaS2w
#
# id: 5920
# 제목: 멘탈리스트
# 장르: 범죄, 드라마, 미스터리
# 시즌 수: 7
# 줄거리: 2008년 9월 CBS에서 방영을 시작한 범죄심리수사물. 예리한 관찰력과 날카로운 추리력을 가진 패트릭 제인은 사람들의 행동을 관찰해서 그 마음을 읽는 능력을 이용하여 돈벌이를 하며 살아가고 있었다. 그러다가 한 방송에서 연쇄살인범 레드존에 대한 언급을 하게 되고, 그로 인해 아내와 딸이 레드존에게 죽임을 당한다. 그 후 제인은 레드존에 대한 정보를 얻기 위해 CBI(캘리포니아 연방수사대)를 찾아가게 되고, 우연히 그들의 수사를 돕게 되면서 수사대의 자문위원이 되고 각종 범죄를 해결하며 레드존을 잡기 위한 정보도 취합해 간다.
# 등급: 15
# 출연진:
# Simon Baker
# 로빈 터니
# Tim Kang
# 제작진:
# Jordan Harper
# 로고 URL: https://image.tmdb.org/t/p/original/aB5jf4O14dykrksrPgtOlvVk0pi.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/acYXu4KaDj1NIkMgObnhe4C4a0T.jpg
# 예고편 URL: https://www.youtube.com/watch?v=nn2Q69pSC_M
#
# id: 2637
# 제목: Come Dine with Me
# 장르: Reality
# 시즌 수: 33
# 줄거리: Amateur chefs compete against each other by hosting a dinner party for the other contestants. Each competitor then rates the host's performance with the winner winning a £1,000 cash prize. An element of comedy is added to the show through comedian Dave Lamb, who provides a dry and "bitingly sarcastic" narration.
# 등급: None
# 출연진:
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/enFfviWZwnIKn9DhyMa7cXqKx6Q.jpg
#
# id: 242099
# 제목: Senhora do Mar
# 장르: Drama
# 시즌 수: 1
# 줄거리:
# 등급: None
# 출연진:
# Sofia Ribeiro
# Afonso Pimentel
# Júlia Palha
# 제작진:
# Manuel Amaro da Costa
#
# id: 242101
# 제목: Cacau
# 장르: Drama
# 시즌 수: 1
# 줄거리: Cacau is an engaging saga of family secrets, clandestine loves and sacrifices, all sweetened by the irresistible taste of chocolate and the magic of cocoa plantations.
# 등급: None
# 출연진:
# Matilde Reymão
# José Condessa
# Alexandra Lencastre
# 제작진:
# Ricardo Carreira
#
# id: 4454
# 제목: 윌 앤 그레이스
# 장르: 코미디
# 시즌 수: 8
# 줄거리: 뉴욕에 사는 인테리어 디자이너이자 식탐 여왕인 그레이스, 그녀의 룸메이트이자 게이 절친인 변호사 윌. 부자집 마나님이지만 심심해서 그레이스의 비서로 일하는 카렌, 쇼 비즈니스 업계의 스타를 꿈꾸는 철딱서니 없는 잭까지... 이들 4인방의 우정과 사랑, 코믹한 일상을 그려낸 레전드 시트콤.
# 등급: 16
# 출연진:
# Eric McCormack
# 데브라 메싱
# Sean Hayes
# 제작진:
# Bruce Alden
# 로고 URL: https://image.tmdb.org/t/p/original/smG3Y5aiG1CitqDY00TbxMEXwZs.png
# 포스터 URL: https://image.tmdb.org/t/p/original/m2AWZDAHesXDmLwVm73BpGlP55a.jpg
# 예고편 URL: https://www.youtube.com/watch?v=PbmZ39kEwGM
#
# id: 60866
# 제목: 아이 좀비
# 장르: 드라마, 범죄, Sci-Fi & Fantasy
# 시즌 수: 5
# 줄거리: 어느 날 갑자기 좀비가 되고 만 전도유망한 의과 레지던트 리브가 생존을 위해 검시소에 취직해 신원미상 시체들의 뇌를 먹으며 살아가기 시작하는 이야기
# 등급: 19
# 출연진:
# 로즈 맥아이버
# David Anders
# Robert Buckley
# 제작진:
# Rob Thomas
# 로고 URL: https://image.tmdb.org/t/p/original/yZQViyCESTineuSQ6XsP4GhJdZ8.png
# 포스터 URL: https://image.tmdb.org/t/p/original/q4nqNwAhzVR7JuYctrWJvUWz3xR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=uX8CLrTXxyo
#
# id: 1408
# 제목: 하우스
# 장르: 드라마, 미스터리
# 시즌 수: 8
# 줄거리: 2004년 11월 FOX에서 방영을 시작한 미스터리 의학 시리즈. 프린스턴 플레인즈보로 대학병원의 진단의학과 과장인 그레고리 하우스는 환자들을 성심성의껏 돌보는 데는 영 꽝인 의사. 사사건건 병원 원장인 리사 커디와 부딪히는 그는 못된 매너와 그 매너를 더욱 돋보이게 하는 외모로 유명하지만, 또한 창조적인 생각과 결점없는 의학적 본능을 유감없이 발휘하는 최고의 의사이기도 하다. 천재적인 분석능력을 갖춘 전염병 전문의로서 그가 이제 인명을 살리기 위한 흥미롭고 미스터리한 의학의 퍼즐을 풀어간다.
# 등급: 15
# 출연진:
# 휴 로리
# Robert Sean Leonard
# Omar Epps
# 제작진:
# Peter Blake
# 로고 URL: https://image.tmdb.org/t/p/original/70mU0MFs8DK1TXCu2Q62YkO6C2D.png
# 포스터 URL: https://image.tmdb.org/t/p/original/3Cz7ySOQJmqiuTdrc6CY0r65yDI.jpg
# 예고편 URL: https://www.youtube.com/watch?v=MczMB8nU1sY
#
# id: 243117
# 제목: Plus belle la vie, encore plus belle
# 장르: Soap, Drama
# 시즌 수: 1
# 줄거리:
# 등급: None
# 출연진:
# Laurent Kerusoré
# Sylvie Flepp
# Cécilia Hornus
# 제작진:
# Clémentine Planchon
#
# id: 790
# 제목: 아가사 크리스티 - 명탐정 포와로
# 장르: 범죄, 드라마, 미스터리
# 시즌 수: 13
# 줄거리: 미스터리 추리 소설의 여왕, 아가사 크리스티의 작품을 영상화한 시리즈. 멋진 콧수염이 트레이드 마크인 벨기에 출신의 명탐정 에르큘 포와로가 미궁에 빠진 사건들을 해결한다.
# 등급: 15
# 출연진:
# David Suchet
# 제작진:
# Brian Eastman
# 로고 URL: https://image.tmdb.org/t/p/original/g3gtnZthA2Pg3wAASsNcMn5HivZ.png
# 포스터 URL: https://image.tmdb.org/t/p/original/6f4IVfbn8knb7RjdZlGLuW5guDc.jpg
# 예고편 URL: https://www.youtube.com/watch?v=_4ypEmJlfn8
#
# id: 32726
# 제목: 밥스 버거스
# 장르: 애니메이션, 코미디
# 시즌 수: 15
# 줄거리: 햄버거집을 하는 가족들의 이야기
# 등급: 12
# 출연진:
# H. Jon Benjamin
# John Roberts
# Kristen Schaal
# 제작진:
# Jim Dauterive
# 로고 URL: https://image.tmdb.org/t/p/original/h8hQS8Y37efmzNlW6EzVnsaKff5.png
# 포스터 URL: https://image.tmdb.org/t/p/original/couFnWryh9JRmmfDyPU6hUyTKIa.jpg
# 예고편 URL: https://www.youtube.com/watch?v=cCrZfBME9Gc
#
# id: 10083
# 제목: The Fugitive
# 장르: Action & Adventure, Drama, Mystery
# 시즌 수: 4
# 줄거리: Richard Kimble is falsely convicted of his wife's murder and given the death penalty. En route to death row, Kimble's train derails and crashes, allowing him to escape and begin a cross-country search for the real killer, a "one-armed man". At the same time, Dr. Kimble is hounded by the authorities, most notably dogged by Police Lieutenant Philip Gerard.
# 등급: None
# 출연진:
# David Janssen
# Barry Morse
# William Conrad
# 제작진:
# George Eckstein
# 포스터 URL: https://image.tmdb.org/t/p/original/gJpLOIYGYn0TyXeqnEhugd8RNd3.jpg
# 예고편 URL: https://www.youtube.com/watch?v=S5YAg-oVpE0
#
# id: 32726
# 제목: 밥스 버거스
# 장르: 애니메이션, 코미디
# 시즌 수: 15
# 줄거리: 햄버거집을 하는 가족들의 이야기
# 등급: 12
# 출연진:
# H. Jon Benjamin
# John Roberts
# Kristen Schaal
# 제작진:
# Jim Dauterive
# 로고 URL: https://image.tmdb.org/t/p/original/h8hQS8Y37efmzNlW6EzVnsaKff5.png
# 포스터 URL: https://image.tmdb.org/t/p/original/couFnWryh9JRmmfDyPU6hUyTKIa.jpg
# 예고편 URL: https://www.youtube.com/watch?v=cCrZfBME9Gc
#
# id: 136450
# 제목: Les Rendez-vous du dimanche
# 장르: Talk
# 시즌 수: 6
# 줄거리: A talk show presented by Michel Drucker
# 등급: None
# 출연진:
# Michel Drucker
# 제작진:
#
# id: 31917
# 제목: 프리티 리틀 라이어스
# 장르: 드라마, 미스터리
# 시즌 수: 7
# 줄거리: 친구가 실종된 후에 서로 멀어진 4명의 소녀들이 1년 후 갑자기 사라졌던 친구로부터 이상한 문자를 받으면서 이야기가 시작되는 드라마로, 인기 소설을 바탕으로 했다.
# 등급: 15
# 출연진:
# 루시 헤일
# Troian Bellisario
# 애슐리 벤슨
# 제작진:
# Charles Grant Craig
# 로고 URL: https://image.tmdb.org/t/p/original/yOulcOG0UBAE9jabKk3zkhPc7jU.png
# 포스터 URL: https://image.tmdb.org/t/p/original/yrObh12XoSzRtHRAfHbcVDtkxjn.jpg
# 예고편 URL: https://www.youtube.com/watch?v=I6Y7Dqzu990
#
# id: 89139
# 제목: Goldene Kamera Verleihung
# 장르: News
# 시즌 수: 1
# 줄거리:
# 등급: None
# 출연진:
# 제작진:
#
# id: 10545
# 제목: 트루 블러드
# 장르: Sci-Fi & Fantasy, 드라마, 미스터리
# 시즌 수: 7
# 줄거리: 샬레인 해리스의 베스트셀러 소설을 바탕으로 한다. 루이지애나의 한 바에서 웨이트리스 일하는 수키. 조용하고 총명하며 아름다운 그녀에게는 다른 사람의 마음을 읽을 수 있는 능력이 있다. 그러던 어느 날, 매력적인 뱀파이어 빌이 나타나는데, 그녀는 그의 마음을 읽어낼 수가 없다. 그러면서 수키는 빌에게 빠져들기 시작한다. 하지만 뱀파이어들은 살인을 저질렀다는 의심을 받고 자꾸 무서운 일들이 일어나는데..
# 등급: 19
# 출연진:
# 안나 패퀸
# Stephen Moyer
# 알렉산더 스카스가드
# 제작진:
# Alan Ball
# 로고 URL: https://image.tmdb.org/t/p/original/mETkvJgly1edlc6gOyqwrXYrppi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/ktEp6fzL4xzCWsSVtrcH8JaQNQy.jpg
# 예고편 URL: https://www.youtube.com/watch?v=3Wk3HSiX-vQ
#
# id: 4656
# 제목: WWE Raw
# 장르: Reality
# 시즌 수: 32
# 줄거리: A regularly scheduled, live, year-round program featuring some of the biggest WWE Superstars.
# 등급: 12
# 출연진:
# Michael Coulthard
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/eKLTUA3cwn0Y8CaF29Vx2nR4mdl.png
# 포스터 URL: https://image.tmdb.org/t/p/original/qvQ2Fu75bNUiZ1yzuHI3wkTGy7C.jpg
# 예고편 URL: https://www.youtube.com/watch?v=FVO6mUQMon8
#
# id: 71728
# 제목: 영 셸든
# 장르: 코미디, 가족
# 시즌 수: 7
# 줄거리: '빅뱅이론'의 주인공 셸든 쿠퍼의 어린 시절을 다룬 이야기.
# 등급: 12
# 출연진:
# Iain Armitage
# Zoe Perry
# Lance Barber
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/phbaDwOu5BKrWpN3FiKgFRxhkn4.png
# 포스터 URL: https://image.tmdb.org/t/p/original/tKwjkqTSq5fJdSxIk4yOh61tOKD.jpg
# 예고편 URL: https://www.youtube.com/watch?v=FStMMcj-RiA
#
# id: 1918
# 제목: 환상특급
# 장르: Sci-Fi & Fantasy, 드라마
# 시즌 수: 3
# 줄거리: 1959년 방영한 동명의 TV 시리즈의 후속작으로 스티븐 스필버그, 웨스 크레이븐, 조지 R.R. 마틴 등 유명 감독, 작가들이 다양한 장르의 신비한 이야기를 만들어 구성한 옴니버스 TV 시리즈
# 등급: None
# 출연진:
# Robin Ward
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/5OYHoUEKE3RJMqiHcJ8XA5kB7bw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qfyjWtMZx-g
#
# id: 1409
# 제목: 썬즈 오브 아나키
# 장르: 범죄, 드라마
# 시즌 수: 7
# 줄거리: 2008년 9월 FX Networks에서 방영을 시작한 범죄 드라마. 캘리포니아 북부의 마을인 차밍은 SOA라는 바이크 클럽이 실권을 잡아 살아가고 있는 곳이다. SOA의 부보스인 잭스 텔러는 조직의 보스이자 양아버지인 클레이와 함께 조직을 꾸려나가고 있다. 잭스는 아이를 거의 죽일 뻔 한 마약 중독자 부인인 웬디를 재활시설로 보내버리고, 어린 시절 연인이었던 타라와 재회한다. 어느 날 우연히 사망한 아버지인 존 텔러의 일기장을 발견하게 되고, 아버지가 꿈꾸었던 조직의 발전 방향과 조직의 현실 사이에서 갈등하게 된다.
# 등급: 18
# 출연진:
# 찰리 허냄
# Katey Sagal
# Tommy Flanagan
# 제작진:
# Bob Thiele Jr.
# 로고 URL: https://image.tmdb.org/t/p/original/tAknQsZla2CacPVM2Pmw5b6z43J.png
# 로고 URL: https://image.tmdb.org/t/p/original/U8ZQukMwiOdafPBp5jjC6KK1v3.png
# 포스터 URL: https://image.tmdb.org/t/p/original/jzsCDbn0UCod1SjtUaPNeBblved.jpg
# 예고편 URL: https://www.youtube.com/watch?v=paBZJJXUEtg
#
# id: 39340
# 제목: 투 브로크 걸스
# 장르: 코미디
# 시즌 수: 6
# 줄거리: 뉴욕 브룩클린에서 웨이트리스로 일하는 20대 여성, 맥스와 캐롤라인의 이야기. 금수저 출신 캐롤라인과 빈곤한 가정에서 자란 맥스는 삶을 바라보는 방식은 다르지만, 함께 컵케이크 가게를 내기 위해 돈을 모으고 있다.
# 등급: 12
# 출연진:
# 캣 데닝스
# 베스 베어스
# Garrett Morris
# 제작진:
# Brian Rubenstein
# 로고 URL: https://image.tmdb.org/t/p/original/9mceGesAMTi7fBV6jHReeWsPyZU.png
# 포스터 URL: https://image.tmdb.org/t/p/original/qCa4ANpF1QOioqRUNHgk2B3KFMZ.jpg
# 예고편 URL: https://www.youtube.com/watch?v=aUkwxpMVW9M
#
# id: 3172
# 제목: 프라이빗 프랙티스
# 장르: 드라마
# 시즌 수: 6
# 줄거리: 스핀오프 시리즈. 시애틀의 그레이스 병원을 떠나, LA의 작은 병원 씨사이드 웰니스(Seaside Wellness)로 근무지를 옮긴 애디슨 몽고메리 박사와 그 동료들의 이야기.
# 등급: 12
# 출연진:
# 케이트 월시
# Paul Adelstein
# KaDee Strickland
# 제작진:
# Mark Gordon
# 로고 URL: https://image.tmdb.org/t/p/original/s7sVPIHXsWPEaHR17ag3MXp0bQR.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pW20ANAGdrgreYJExduUVaWos6H.jpg
#
# id: 64513
# 제목: 아메리칸 크라임 스토리
# 장르: 범죄, 드라마
# 시즌 수: 4
# 줄거리: 미국에서 발생한 유명 범죄 사건을 극화한 시리즈. O.J. 심슨 재판, 앤드류 쿠내넌의 연쇄 살인을 다룬다. 범행을 포함, 당시 미국 사회의 단면을 첨예하게 보여주는 연작.
# 등급: 19
# 출연진:
# 사라 폴슨
# 비니 펠드스타인
# Annaleigh Ashford
# 제작진:
# Hayley Byrnes
# 로고 URL: https://image.tmdb.org/t/p/original/7OTXTdRXl9HXFLRctLiKgWF6nl1.png
# 포스터 URL: https://image.tmdb.org/t/p/original/dqzY6BTXsbDzX5vxrZEXjG8U4rX.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ZT0m9MBCMDo
#
# id: 62286
# 제목: 피어 더 워킹 데드
# 장르: Action & Adventure, 드라마
# 시즌 수: 8
# 줄거리: 2015년 8월 AMC에서 방영을 시작한 좀비 좀비 아포칼립스물. 인기 시리즈 워킹 데드의 스핀오프 작품으로, 본편과 달리 좀비 사태가 벌어진 최초의 시점에서 당황하며 어쩔 줄 몰라하던 사람들이 점차 적응해 가는 이야기를 다루고 있다. 폐쇄된 교회에서 약에 취한 채 깨어난 닉은 함께 마약을 하던 글로리아가 사라지자 그녀를 찾기 위해 아래층으로 내려간다. 그곳에서 피와 시체들이 널부러져 있는 사이에서 글로리아가 시체를 뜯어먹고 있는 모습을 보게 된다. 겁에 질려 교회 밖으로 도망치다가 차에 치여 병원에 실려간 닉은 마약 중독 치료 권고를 받고, 자신이 본 것을 얘기하지만 정신병으로 오해 받는다.
# 등급: 19
# 출연진:
# Kim Dickens
# Lennie James
# Rubén Blades
# 제작진:
# Frank Hildebrand
# 로고 URL: https://image.tmdb.org/t/p/original/zhCc9jAnHtVW12KhRU9RI8Bm6Yf.png
# 포스터 URL: https://image.tmdb.org/t/p/original/l7N9aS6VyYvjelKoCB2eZge0Qky.jpg
# 예고편 URL: https://www.youtube.com/watch?v=WDxew5SguVw
#
# id: 2290
# 제목: 스타게이트 아틀란티스
# 장르: Sci-Fi & Fantasy, Action & Adventure, 드라마
# 시즌 수: 5
# 줄거리: 스타게이트 아틀란티스는 스타게이트 SG-1에 이어 제작된 드라마이다. 영화 스타게이트의 스토리를 이어 제작된 스타게이트 SG-1이 종영되기 전에 방영되기 시작했다. 페가수스 은하계를 무대로 스타게이트를 건설한 고대인들의 자취를 찾아 아틀란티스로 떠난 일행의 이야기이다.
# 등급: 12
# 출연진:
# Joe Flanigan
# David Hewlett
# Rachel Luttrell
# 제작진:
# Chris Beach
# 로고 URL: https://image.tmdb.org/t/p/original/tkQKGyEvxJ5JV8MOfnKyy0lzXoT.png
# 포스터 URL: https://image.tmdb.org/t/p/original/l0JYr2iqwId6VOmCV8dHzlIM6Wd.jpg
# 예고편 URL: https://www.youtube.com/watch?v=j7ZXaSMffjo
#
# id: 1877
# 제목: 피니와 퍼브
# 장르: 애니메이션, 코미디, 가족, Sci-Fi & Fantasy
# 시즌 수: 5
# 줄거리: 피니와 퍼브에게 불가능이란 없다! 말썽꾸러기 발명가 형제 피니와 퍼브의 좌충우돌 이야기
# 등급: ALL
# 출연진:
# Vincent Martella
# 토머스 브로디생스터
# 애슐리 티스데일
# 제작진:
# Darrin Drew
# 로고 URL: https://image.tmdb.org/t/p/original/8dpyx3AKsmwZXCz4xrJKYcYPhuW.png
# 포스터 URL: https://image.tmdb.org/t/p/original/oSLwJMOOQGAsyJNMi4Y3MO44iAJ.jpg
# 예고편 URL: https://www.youtube.com/watch?v=EjlTFvKpv2Q
#
# id: 58937
# 제목: 마스터스 오브 섹스
# 장르: 드라마
# 시즌 수: 4
# 줄거리: 성 연구의 개척자인 마스터스, 존슨의 관습에서 탈피한 라이프스타일과 연구, 그리고 그들의 연구 결과로 인해 불붙는 혁명적 변화들을 들여다보는 시리즈.
# 등급: 19
# 출연진:
# 마이클 쉰
# 리지 캐플런
# Caitlin FitzGerald
# 제작진:
# Carl Beverly
# 로고 URL: https://image.tmdb.org/t/p/original/8PE2ccVoZOFer0CDSy901zyVmfr.png
# 포스터 URL: https://image.tmdb.org/t/p/original/bC42ksckQpjfck2BZ5McaEDN4pk.jpg
# 예고편 URL: https://www.youtube.com/watch?v=VS1fn1LWGfk
#
# id: 4177
# 제목: Perry Mason
# 장르: Mystery, Drama, Crime
# 시즌 수: 9
# 줄거리: The cases of master criminal defense attorney Perry Mason and his staff who handled the most difficult of cases in the aid of the innocent.
# 등급: 12
# 출연진:
# Raymond Burr
# Barbara Hale
# William Hopper
# 제작진:
# Herbert Hirschman
# 로고 URL: https://image.tmdb.org/t/p/original/fxgJjWGqBWITlZLD2ugS7PbiwXB.png
# 포스터 URL: https://image.tmdb.org/t/p/original/1th2fC46icNw67k51FykUn3wwC0.jpg
# 예고편 URL: https://www.youtube.com/watch?v=PA9t1nSGXXE
#
# id: 215709
# 제목: Redemption
# 장르: Drama
# 시즌 수: 3
# 줄거리: Orhun is a successful businessman who was raised in a wealthy but loveless family along with his twin sister Nihan, younger sister Nurşah and their cold, distant mother Afife. Nihan left to do volunteer work as a doctor in Eritrea, but recently she has been impossible to contact, and her family is worried about her. While looking for his sister, he comes across Hira, a poor girl living the life of a prisoner at the hands of traffickers. When they find out that Nihan has been poisoned and killed by a local gang, Orhun breaks down. When it emerges that it was actually Hira who poisoned his sister, Orhun hatches an evil revenge plan. Meanwhile, Afife, their mother, has kept Orhun's father away since his childhood secretly. Orhun decides to marry Hira as revenge. Afife hates people of lower status and she’s obsessed with “pure blood”. Will this marriage imprison Afife , or will the couple find redemption after paying all their dues?
# 등급: None
# 출연진:
# Mahassine Merabet
# Cenk Torun
# Fulya Özcan
# 제작진:
#
# id: 1423
# 제목: 레이 도노반
# 장르: 드라마
# 시즌 수: 7
# 줄거리: 유명인들의 뒤처리나 골칫거리 문제들을 깨끗하게 처리해주는 남자의 이야기
# 등급: 19
# 출연진:
# 리에브 슈라이버
# 에디 마산
# Dash Mihok
# 제작진:
# Alex R. Wagner
# 로고 URL: https://image.tmdb.org/t/p/original/2O4zkZpnqdS0yqxQ6oTL3CZu5p5.png
# 포스터 URL: https://image.tmdb.org/t/p/original/zxftW7ZGVrOCqH2ifuruieCTb5X.jpg
# 예고편 URL: https://www.youtube.com/watch?v=7fN5uBZXpLw
#
# id: 253
# 제목: 스타 트렉
# 장르: Sci-Fi & Fantasy, 드라마
# 시즌 수: 3
# 줄거리: 23세기를 배경으로 우주 탐사 임무를 띠고 출항한 엔터프라이즈호의 항해와 평등과 화합 그리고 평화를 그린 드라마
# 등급: 12
# 출연진:
# William Shatner
# Leonard Nimoy
# DeForest Kelley
# 제작진:
# Gene L. Coon
# 로고 URL: https://image.tmdb.org/t/p/original/4FNMPoBLs8wFFMr2ydrgi1pY6HT.png
# 포스터 URL: https://image.tmdb.org/t/p/original/1CIGsKSq4DvJpsC4M7c8mW6iTPf.jpg

# %%
import requests

# TMDB API 키
TMDB_API_KEY = 'cd88d12bfe4c5d842ef9a464b2f0bcd1'
language = 'ko'

#TV SERIES LISTS > POPULAR
#인기있는 tv 시리즈 출력을 위한 API
def fetch_popular_series(language='ko-KR', region='KR', page=1, total_results=200):
    url = f'https://api.themoviedb.org/3/tv/popular'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'region': region,
        'page': page,  # 페이지 번호 설정
    }

    results = []
    while len(results) < total_results:
        response = requests.get(url, params=params)
        data = response.json()
        results.extend(data['results'])
        page += 1
        params['page'] = page

    return results[:total_results]

def fetch_series_rating(series_id):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/content_ratings'
    params = {
        'api_key': TMDB_API_KEY
    }

    response = requests.get(url, params=params)
    data = response.json()
    
    kr_rating = None
    de_rating = None
    
    if 'results' in data:
        for result in data['results']:
            iso_3166_1 = result.get('iso_3166_1')
            rating = result.get('rating')
            
            if iso_3166_1 == 'KR':
                kr_rating = rating
            elif iso_3166_1 == 'DE':
                de_rating = rating
    
    if kr_rating:
        return kr_rating
    elif de_rating:
        return de_rating
    else:
        return None
    
#TV SERIES > DETAILS
def fetch_series_details(series_id, language='ko-KR'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'append_to_response': 'credits'  # 출연진 및 제작진 정보를 가져오기 위해 추가
    }

    response = requests.get(url, params=params)
    data = response.json()

    if 'genres' in data:
        print("장르:")
        for index, genre in enumerate(data['genres']):
            if index < 2:
                print(genre['name'])
            else:
                break
    
    if 'overview' not in data or not data['overview']:
        params['language'] = 'en'
        response = requests.get(url, params=params)
        data = response.json()

    return data

#TV SERIES > IMAGES(로고, 포스터 이미지)
def fetch_series_images(series_id, language='ko'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/images'
   
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'append_to_response': 'credits'  # 출연진 및 제작진 정보를 가져오기 위해 추가
    }

    response = requests.get(url, params=params)
    data = response.json()
    
    # 한국어 포스터가 없거나 로고가 없을 시, 영어 이미지 출력
    if ('posters' not in data or len(data['posters']) == 0) or ('logos' not in data or len(data['logos']) == 0):
        params['language'] = 'en'
        response = requests.get(url, params=params)
        data = response.json()

        if 'posters' in data and len(data['posters']) > 0:
            data['posters'] = data['posters'][:1]
        if 'logos' in data and len(data['logos']) > 0:
            data['logos'] = data['logos'][:1]

    return data

#TV SERIES > VIDEOS
#TRAILER 
def fetch_series_videos(series_id, language='en'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/videos'

    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
    }
    response = requests.get(url, params=params)
    data = response.json()

    key_mapping = {
        'Trailer': 'trailer',
        'Clip': 'clip',
        'Teaser': 'teaser',
        'Opening Credits': 'opening_credits'
    }

    for item in data.get('results', []):
        video_type = item.get('type')
        if video_type in key_mapping:
            return item.get('key')

    return None


def print_series_info(series, series_images, series_videos):
    print("id:", series['id'])
    print("제목:", series['name'])
    print("장르:", ", ".join([genre['name'] for genre in series['genres']]))
    print("시즌 수:", f"{series['number_of_seasons']}")
    print("줄거리:", series['overview'])
    
    #RATING
    series_id = series['id']
    rating = fetch_series_rating(series_id)
    print("등급:", rating)


    #CAST
    if 'credits' in series and 'cast' in series['credits']:
        print("출연진:")
        for cast in series['credits']['cast'][:3]:
            print(f"{cast['name']}")
    
    #CREW
    if 'credits' in series and 'crew' in series['credits']:
        print("제작진:")
        if series['credits']['crew']:  # 제작진 정보가 있는 경우에만 출력
            crew = series['credits']['crew'][0]  # 첫 번째 제작진 정보만 출력
            print(f"{crew['name']}")
    
    #LOGO
    if 'logos' in series_images:
        for logo in series_images['logos']:
            print("로고 URL:", f"https://image.tmdb.org/t/p/original{logo['file_path']}")

    #POSTER_URL
    if 'posters' in series_images:
         for poster in series_images['posters']:
            print("포스터 URL:", f"https://image.tmdb.org/t/p/original{poster['file_path']}")

    #TRAILER_URL
    if series_videos is not None:  # 시리즈 비디오 정보가 있는 경우에만 출력
        print("예고편 URL:", f"https://www.youtube.com/watch?v={series_videos}")

def main():
    popular_tv_series = fetch_popular_series()

    for series in popular_tv_series:
        series_details = fetch_series_details(series['id'])
        series_images = fetch_series_images(series['id'])
        series_videos = fetch_series_videos(series['id'])  # 영상 정보 가져오기 추가
        print_series_info(series_details, series_images, series_videos)  # 영상 정보 전달
        print()

if __name__ == "__main__":
    main()
# Out:
# 장르:
# 범죄
# 드라마
# id: 2734
# 제목: 로 앤 오더: 성범죄 전담반
# 장르: 범죄, 드라마, 미스터리
# 시즌 수: 25
# 줄거리: 추악한 성범죄를 수사하는 뉴욕 경찰 성범죄전담수사반의 활약을 그린 드라마.
# 등급: 15
# 출연진:
# 마리슈카 하기테이
# Ice-T
# Peter Scanavino
# 제작진:
# Dick Wolf
# 로고 URL: https://image.tmdb.org/t/p/original/AhtQAQVcqWl6b0UZSo9vmHE3skK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/onmSVwYsPMYtO8OjLdjS8FfRNKb.jpg
# 예고편 URL: https://www.youtube.com/watch?v=IRXNVdiqMuU
#
# 장르:
# Action & Adventure
# 드라마
# id: 57243
# 제목: 닥터 후
# 장르: Action & Adventure, 드라마, Sci-Fi & Fantasy
# 시즌 수: 13
# 줄거리: 타임로드라는 종족의 외계인인 닥터가 그의 동료들과 함께 시공간을 누비는 여행을 하며 때때로 지구와 인류 그리고 우주를 구하는 이야기.
# 등급: 15
# 출연진:
# Jodie Whittaker
# Mandip Gill
# John Bishop
# 제작진:
# Claire Pritchard
# 로고 URL: https://image.tmdb.org/t/p/original/r6aeDXC3UE8PfzdorYfQWpPJTho.png
# 포스터 URL: https://image.tmdb.org/t/p/original/4edFyasCrkH4MKs6H4mHqlrxA6b.jpg
# 예고편 URL: https://www.youtube.com/watch?v=8L1kU45poro
#
# 장르:
# 코미디
# id: 4556
# 제목: Scrubs
# 장르: Comedy
# 시즌 수: 9
# 줄거리: In the unreal world of Sacred Heart Hospital, John "J.D." Dorian learns the ways of medicine, friendship and life.
# 등급: 12
# 출연진:
# Zach Braff
# Donald Faison
# John C. McGinley
# 제작진:
# Zach Braff
# 로고 URL: https://image.tmdb.org/t/p/original/6lCg07nxaLGpEap849catTySkvi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/u1z05trCA7AuSuDhi365grwdos1.jpg
# 예고편 URL: https://www.youtube.com/watch?v=zOgb3KIJDY8
#
# 장르:
# 드라마
# 미스터리
# id: 1620
# 제목: CSI: 마이애미
# 장르: 드라마, 미스터리, 범죄
# 시즌 수: 10
# 줄거리: 플로리다 주의 마이애미 데이드 경찰청. 호레이쇼 반장과 CSI 과학 수사 대원들은 논리적인 증거 분석과 본능적인 수사로 마이애미에서 일어나는 위험한 범죄들을 해결해나간다.
# 등급: 15
# 출연진:
# David Caruso
# Emily Procter
# Omar Benson Miller
# 제작진:
# Jerry Bruckheimer
# 로고 URL: https://image.tmdb.org/t/p/original/gnThzFN5qgTW3vKLl5mVlqRBQ5T.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pNW64pjaHvf6purNaFhq4SHYRfl.jpg
# 예고편 URL: https://www.youtube.com/watch?v=x2n-h9E8_ck
#
# 장르:
# 드라마
# Action & Adventure
# id: 4376
# 제목: JAG
# 장르: Drama, Action & Adventure, Crime
# 시즌 수: 10
# 줄거리: Harmon "Harm" Rabb Jr. is a former pilot turned lawyer working for the military's JAG (Judge Advocate General) division, the elite legal wing of officers that prosecutes and defends those accused of military-related crimes. He works closely with Lt. Col. Sarah Mackenzie, and together they do what needs to be done to find the truth.
# 등급: 16
# 출연진:
# David James Elliott
# Catherine Bell
# Patrick Labyorteaux
# 제작진:
# Donald P. Bellisario
# 로고 URL: https://image.tmdb.org/t/p/original/ac4uUoKUD0kTxXHm04dp7u10ksc.png
# 포스터 URL: https://image.tmdb.org/t/p/original/zPyHpkJZ5O08lbgrQQIROXtb3xz.jpg
#
# 장르:
# Sci-Fi & Fantasy
# Action & Adventure
# id: 4604
# 제목: 스몰빌
# 장르: Sci-Fi & Fantasy, Action & Adventure, 드라마
# 시즌 수: 10
# 줄거리: 우리에게 슈퍼맨으로 친숙한 클라크 켄트의 유년기를 새로이 재조명한 워너 브라더스사의 SF시리즈물 드라마
# 등급: 15
# 출연진:
# Tom Welling
# Erica Durance
# Cassidy Freeman
# 제작진:
# Alfredo Septién
# 로고 URL: https://image.tmdb.org/t/p/original/ePZAsSSkT2G0j1F1U13ZE675N6I.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pUhJGETy2sec4vEkiqJ9eGeIywc.jpg
# 예고편 URL: https://www.youtube.com/watch?v=70Y32si4yb8
#
# 장르:
# 범죄
# 드라마
# id: 1412
# 제목: 애로우
# 장르: 범죄, 드라마, Action & Adventure
# 시즌 수: 8
# 줄거리: 스탈링 시티의 잘나가는 재벌 2세 올리버 퀸은 아버지와 보트 여행에 나섰다가 태풍을 만나 난파를 당한다. 그는 5년 동안 외딴 섬에 표류되어 생존을 위한 처절한 사투를 벌이고 마침내 고향으로 돌아온다. 아버지의 유언에 따라 스탈링 시티의 엘리트 범죄자들을 사냥하기위해 스스로 자경단원을 자처하는 올리버퀸. 그러나 그의 앞날에는 그의 상상보다 더 큰 진실과 음모가 기다리고 있는데...
# 등급: 15
# 출연진:
# Stephen Amell
# David Ramsey
# Katie Cassidy
# 제작진:
# Mark Bunting
# 로고 URL: https://image.tmdb.org/t/p/original/jUu02PexmdU5xAeDYsv1huceChE.png
# 포스터 URL: https://image.tmdb.org/t/p/original/gKG5QGz5Ngf8fgWpBsWtlg5L2SF.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qo6hU98dXOc
#
# 장르:
# 드라마
# id: 1416
# 제목: 그레이 아나토미
# 장르: 드라마
# 시즌 수: 20
# 줄거리: 시애틀에 있는 병원 의사들의 삶에 대한 이야기. 의사로서의 감정과 개인적인 감정에 대한 묘사가 적절히 조화를 이루어 그려진다. 인턴이지만 결국 레지던트가 되는 메러디스 그레이는 시애틀 병원의 동료 의사들과 함께 사적, 직업적인 열정에 휩쓸리는 자신을 발견한다.
# 등급: 19
# 출연진:
# 엘렌 폼페오
# Chandra Wilson
# James Pickens Jr.
# 제작진:
# 숀다 라임스
# 로고 URL: https://image.tmdb.org/t/p/original/keAZqhg9lmOHEhmG5njqIsuxf0f.png
# 포스터 URL: https://image.tmdb.org/t/p/original/jcEl8SISNfGdlQFwLzeEtsjDvpw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qbkEtYz9acA
#
# 장르:
# 코미디
# 드라마
# id: 1981
# 제목: Charmed
# 장르: Comedy, Drama, Mystery, Sci-Fi & Fantasy
# 시즌 수: 8
# 줄거리: Three sisters (Prue, Piper and Phoebe) reunite and unlock their powers to become the Charmed Ones, the most powerful good witches of all time, whose prophesied destiny is to protect innocent lives from evil beings such as demons and warlocks. Each sister possesses unique magical powers that grow and evolve, while they attempt to maintain normal lives in modern day San Francisco.
# 등급: 12
# 출연진:
# Holly Marie Combs
# Alyssa Milano
# Brian Krause
# 제작진:
# Holly Marie Combs
# 로고 URL: https://image.tmdb.org/t/p/original/dd7ULvZWBk0EL7PrnfoeE7cpSC7.png
# 포스터 URL: https://image.tmdb.org/t/p/original/z4bPJ1BWU2EtV69NII2GVvsugQ2.jpg
#
# 장르:
# Talk
# id: 82873
# 제목: The Kelly Clarkson Show
# 장르: Talk
# 시즌 수: 5
# 줄거리: Kelly Clarkson presents the biggest newsmakers and names in film, television and music; as well as emerging new talent and everyday people who are beacons of hope in their communities.
# 등급: None
# 출연진:
# Kelly Clarkson
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/9Gg1oM8Us8gCS5aJA8e0ZRuIHnf.jpg
# 예고편 URL: https://www.youtube.com/watch?v=BhrdON83gqk
#
# 장르:
# 코미디
# Talk
# id: 59941
# 제목: The Tonight Show Starring Jimmy Fallon
# 장르: Comedy, Talk
# 시즌 수: 11
# 줄거리: After Jay Leno's second retirement from the program, Jimmy Fallon stepped in as his permanent replacement. After 42 years in Los Angeles the program was brought back to New York.
# 등급: 16
# 출연진:
# Jimmy Fallon
# Steve Higgins
# 제작진:
# Lorne Michaels
# 포스터 URL: https://image.tmdb.org/t/p/original/g4amxJvtpnY79J77xeamnAEUO8r.jpg
#
# 장르:
# 범죄
# 드라마
# id: 1431
# 제목: CSI: 라스베가스
# 장르: 범죄, 드라마, 미스터리
# 시즌 수: 15
# 줄거리: 2000년 10월 CBS에서 방영을 시작한 범죄수사물. 최첨단 장비와 과학적인 분석으로 미궁속의 사건을 해결해 가는 라스베가스 시경 과학수사과 심야근무반. 17년 경력의 베테랑 길 그리섬, 혼자서 키우는 딸과 직장 사이에 균형을 잃지 않으며 항상 최선을 다하는 캐서린 윌로스, 도박의 유혹을 뿌리치지 못하지만 날카로운 분석력을 보유한 워릭 브라운, 하바드 출신의 새라 사이들, 그리고 매력적인 남자 닉 스톡스 등 5명이 한 팀으로 구성된 이들은 사건이 미궁에 빠질 때마다 첨단 기술과 예리한 분석력으로 결정적인 단서와 증거를 확보하여 진범을 가려내기 위해 365일 24시간을 투자한다.
# 등급: 15
# 출연진:
# Ted Danson
# George Eads
# Jorja Fox
# 제작진:
# Andi Brittan
# 로고 URL: https://image.tmdb.org/t/p/original/fLhKSEsurxHq3mwEDvCQhnApxkg.png
# 포스터 URL: https://image.tmdb.org/t/p/original/i5hmoRjHNWady4AtAGICTUXknKH.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ApT1EYvrwuk
#
# 장르:
# 범죄
# 드라마
# id: 1438
# 제목: 더 와이어
# 장르: 범죄, 드라마
# 시즌 수: 5
# 줄거리: 2002년 6월 HBO에서 방영을 시작한 범죄수사물. 볼티모어에서 일어난 살인 사건의 범인으로 지목된 마약 딜러 에이본 박스데일의 조카 디안젤로. 그가 증인의 진술 번복으로 풀려나자 이를 수상하게 여긴 강력계 형사 맥널티는 특별전담팀을 꾸린다.
# 등급: 19
# 출연진:
# Dominic West
# 랜스 레딕
# Sonja Sohn
# 제작진:
# Joe Chappelle
# 로고 URL: https://image.tmdb.org/t/p/original/cP5IrOYxU7qtFl3Gyjtj9iPufCn.png
# 포스터 URL: https://image.tmdb.org/t/p/original/4lbclFySvugI51fwsyxBTOm4DqK.jpg
# 예고편 URL: https://www.youtube.com/watch?v=uDcQbk78CSw
#
# 장르:
# 애니메이션
# 코미디
# id: 1433
# 제목: 아메리칸 대드!
# 장르: 애니메이션, 코미디
# 시즌 수: 20
# 줄거리: 랭글리 폴즈라는 도시에서 사는 CIA에서 근무하는 수꼴에 과대망상이 매우 심한 아버지(스탠 스미스)와 전형적인 금발백치 어머니(프랜신 스미스), 반항아에 좌빨인 장녀(헤일리 스미스)에 Nerd 아들(스티브 스미스), 변장을 좋아하는 양성애자자웅동체[1] 외계인(로저), 그리고 동독 스키점퍼의 기억을 가지고 있는 금붕어(클라우스 하이슬러)로 이루어진 스미스 가족과 그 주변인물들을 다루고 있다
# 등급: 12
# 출연진:
# 세스 맥팔레인
# Wendy Schaal
# Rachael MacFarlane
# 제작진:
# Chris McKenna
# 로고 URL: https://image.tmdb.org/t/p/original/56e9hx9CwagmWwxdOZFqq7cqORS.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/xnFFz3etm1vftF0ns8RMHA8XdqT.jpg
# 예고편 URL: https://www.youtube.com/watch?v=W9Kf1RUHLxE
#
# 장르:
# 드라마
# 미스터리
# id: 1622
# 제목: 수퍼내추럴
# 장르: 드라마, 미스터리, Sci-Fi & Fantasy
# 시즌 수: 15
# 줄거리: 어린 시절, 샘과 딘은 정체를 알 수 없는 악마의 힘의 의해 어머니를 잃는다. 그로 인해, 그들의 아버지는 자식들을 헌터로 키우며, 미국 각지에 흩어져 있는 초자연적인 악과 괴물들을 처치하는 법을 가르친다.
#
# 이제 두 윈체스터 형제들은 67년형 쉐비 임팔라에 몸을 싣고 미전역을 가로지르며 그들과 마주치는 모든 초자연적인 위협들을 처리해나가기 시작하는데...
# 등급: 16
# 출연진:
# Jared Padalecki
# Jensen Ackles
# Misha Collins
# 제작진:
# Talli Buchanan
# 로고 URL: https://image.tmdb.org/t/p/original/jpop1hHSw0Cwm4J1lUcP6KDMbVf.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/KoYWXbnYuS3b0GyQPkbuexlVK9.jpg
# 예고편 URL: https://www.youtube.com/watch?v=yy96yJjkvjo
#
# 장르:
# 코미디
# id: 1421
# 제목: 모던 패밀리
# 장르: 코미디
# 시즌 수: 11
# 줄거리: 에미상을 받은 이 시트콤은 로스앤젤레스에 사는 제이 프리쳇과 각양각색의 가족이 일상에서 수많은 난관을 만나고 해결해 나가는 이야기를 그린다.
# 등급: 15
# 출연진:
# Ed O'Neill
# 소피아 베르가라
# 줄리 보언
# 제작진:
# Abraham Higginbotham
# 로고 URL: https://image.tmdb.org/t/p/original/rbKhglYrECjMZNYtT2QyihOQ5F.png
# 포스터 URL: https://image.tmdb.org/t/p/original/klL4yhwiU8aF4AuF5dCfJA9sRnS.jpg
# 예고편 URL: https://www.youtube.com/watch?v=rbpTUPisA78
#
# 장르:
# Sci-Fi & Fantasy
# 코미디
# id: 4620
# 제목: 유레카
# 장르: Sci-Fi & Fantasy, 코미디, 드라마
# 시즌 수: 5
# 줄거리: 미국의 Syfy 채널에서 2006년부터 2012년까지 방영한 SF 드라마이다. 유레카라고 불리는 이 마을은 2차 세계대전이 끝난후에 알베르트 아인슈타인이 해리 S. 트루먼 대통령에게 과학자들의 천국을 만들자고 건의해서 만들어진 마을이며, 현재는 펜타곤이 이 마을을 담당[3]하고 있다. 철통같은 보안으로 51구역이 부러워 한다고 한다...
# 등급: 12
# 출연진:
# Colin Ferguson
# Salli Richardson-Whitfield
# 조 모턴
# 제작진:
# Rick Maguire
# 로고 URL: https://image.tmdb.org/t/p/original/hzfIri2vgVJJhJd7vWnZlUwS9oi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/f2l5hUk63hPqYTucnFy2HmElFV0.jpg
# 예고편 URL: https://www.youtube.com/watch?v=WiPWghJQS3o
#
# 장르:
# 코미디
# id: 2316
# 제목: 오피스
# 장르: 코미디
# 시즌 수: 9
# 줄거리: 팬실베니아 스크랜튼에 위치한 사무용지 판매회사 던더 미플린의 스크랜턴 지점. 무미건조한 사무실에서 깐깐한 지점장과 독특한 캐릭터의 부하들이 벌이는 코믹 해프닝과 가슴 찡한 이야기가 펼쳐진다. BBC에서 방영된 동명 영국 시리즈의 할리우드 리메이크.
# 등급: 15
# 출연진:
# Rainn Wilson
# 존 크래신스키
# 제나 피셔
# 제작진:
# Steve Burgess
# 로고 URL: https://image.tmdb.org/t/p/original/zWozteGoJM0NhHj5lhXSqhu6rUA.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7DJKHzAi83BmQrWLrYYOqcoKfhR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=96ix3P9WaRc
#
# 장르:
# 드라마
# 코미디
# id: 34307
# 제목: 쉐임리스
# 장르: 드라마, 코미디
# 시즌 수: 11
# 줄거리: 미국 시카고 후미진 마을에서 힘겹게 살고 있는 싱글 대디 프랭크와 총명하고 독립적인 그의 여섯 자녀들의 리얼한 이야기
# 등급: 19
# 출연진:
# 윌리엄 H. 메이시
# 제레미 앨런 화이트
# Ethan Cutkosky
# 제작진:
# John Wells
# 로고 URL: https://image.tmdb.org/t/p/original/vmxGfz06Eha0n1UvSckq907wFFz.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9akij7PqZ1g6zl42DQQTtL9CTSb.jpg
# 예고편 URL: https://www.youtube.com/watch?v=9tvkYS5cA58
#
# 장르:
# 애니메이션
# 코미디
# id: 45854
# 제목: 유희왕 ZEXAL
# 장르: 애니메이션, 코미디, Action & Adventure, Sci-Fi & Fantasy
# 시즌 수: 1
# 줄거리: 근미래의 마을, 하트랜드 시티에서는 어른도 아이도 AR 듀얼에 열중하고 있다.
#
# AR 듀얼이란, 「D-게이저」와 「D-패드」를 사용하는 듀얼로,
#
# 이 2가지를 사용하는 것으로,
#
# 지면에서, 하늘에서, 그리고 건물에서
#
# 몬스터가 현실에
#
# 튀어나와 맞부딪치는,
#
# 무지막지 박력 넘치는 듀얼!
#
# 이 마을에 사는 주인공 츠쿠모 유마도
#
# 이 듀얼에 열중하고 있지만,
#
# 실력은 초심자 레벨의 연전연패 챔피언.
#
# 어느 사건을 계기로, 학교 제일의 불량배 료가와
#
# 듀얼로 승부를 내게 된 유마.
#
# 이 듀얼이, 유마의 운명을 크게 바꿔놓는다...!
#
# 이 결투 중, 항상 유마의 꿈에 나오는 불길한 문이 돌연 나타난다.
#
# 굳게 닫혀 있던 문이 개방된 순간, 무수한 빛이 넘쳐 나와,
#
# 놀라서 옆을 올려다보니...
#
# 거기에는 이세계에서 온 수수께끼의 생명체 아스트랄이 서 있었다!
#
# 아스트랄의 잃어버린 기억, 99장의 넘버즈 카드를 되찾기 위해,
#
# 둘은 함께 행동하기로 한다.
#
# 아스트랄이 나타난 진정한 이유란?
#
# 그리고, 새로운 몬스터 「넘버즈 몬스터」의
#
# 존재는 도대체 무엇이란 말인가?
#
# 계속해서 유마의 앞에 나타나는 강력한 라이벌,
#
# 그리고 밝혀져가는 아스트랄의 수수께끼.
#
# 이 콤비에 의한 새로운 듀얼의 전설이 지금, 막을 연다!!
# 등급: 6
# 출연진:
# 하타나카 타스쿠
# 이리노 미유
# 谷育子
# 제작진:
# Wataru Nakagawa
# 포스터 URL: https://image.tmdb.org/t/p/original/3aZUtzeHQrLgQQdYNqHSbJqj59G.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ajFTuo6LQLc
#
# 장르:
# 가족
# 코미디
# id: 49009
# 제목: 골드버그 패밀리
# 장르: 가족, 코미디
# 시즌 수: 10
# 줄거리: 육아 블로그가 생기고, 트로피가 등장하고, 땅콩 알레르기가 유행하기 전에는 80년대라는 단순한 시대가 있었다.
#
# 괴짜 11살 아담에게 이 시기는 경이로운 시절이었고, 그는 비디오 카메라로 무장하고 그 모든 신기한 장면을 카메라에 담았다. 골드버그 가족은 다른 가족들과 마찬가지로 사랑스러운 가족이었지만 고성이 끊이지 않는다..
# 등급: 12
# 출연진:
# Wendi McLendon-Covey
# Sean Giambrone
# Troy Gentile
# 제작진:
# Demetrios Katsantonis
# 로고 URL: https://image.tmdb.org/t/p/original/uQ2lw8cFij434Y5ychYUxW8oxUo.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pZyaKyry0V1muunoTt6pZ6cLduR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=Q_BJzU0ulLE
#
# 장르:
# 코미디
# id: 1668
# 제목: 프렌즈
# 장르: 코미디
# 시즌 수: 10
# 줄거리: 1994년 5월 NBC에서 방영을 시작한 시트콤. 미국 뉴욕 시 맨해튼의 그리니치 빌리지의 아파트와 까페 센트럴 퍼크를 중심으로 2-30대의 세 명의 남자와 세 명의 여자의 우정과 사랑, 삶을 그렸다. 부잣집 맏딸이자 응석받이로 자라 온 레이첼은 결혼식을 앞두고 결혼 선물들을 쳐다보던 중 자신이 남편보다 결혼선물을 더 사랑한다는 사실을 깨닫고 회의감을 느끼게 된다. 이를 계기로 불현듯 결혼식에서 도망쳐 나오게 되고, 뉴욕에 아버지의 그늘을 피할 곳을 찾다가 결혼식 전 우연히 만난 고등학교 동창 모니카와 재회하게 된다.
# 등급: 15
# 출연진:
# 제니퍼 애니스턴
# 코트니 콕스
# 리사 쿠드로
# 제작진:
# Robert Carlock
# 로고 URL: https://image.tmdb.org/t/p/original/a4qZkvpdqCSS60vppgL5xCBsMwi.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/2koX1xLkpTQM4IZebYvKysFW1Nh.jpg
# 예고편 URL: https://www.youtube.com/watch?v=s2TyVQGoCYo
#
# 장르:
# 범죄
# 드라마
# id: 1911
# 제목: 본즈
# 장르: 범죄, 드라마
# 시즌 수: 12
# 줄거리: 워싱턴 D.C.의 제퍼소니안 재단의 연구소 소속 법인류학자인 템퍼런스 브레넌 박사와 FBI 워싱턴 지국 요원인 실리 부스, 그리고 브레넌 박사의 팀이 뼈만 남다시피한 시신을 조사해 해결하는 내용으로 실제 법인류학자인 '캐시 라익스'의 소설을 각색해 제작되었으며 국내에도 '본즈'라는 제목으로 원작 소설 시리즈가 발매되었다.
# 등급: 15
# 출연진:
# Emily Deschanel
# David Boreanaz
# John Boyd
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/xSguBiLk5wgeDqkye3MgIoQ5gCH.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/eyTu5c8LniVciRZIOSHTvvkkgJa.jpg
# 예고편 URL: https://www.youtube.com/watch?v=idiNjlYU7Cs
#
# 장르:
# Talk
# id: 204746
# 제목: The Jennifer Hudson Show
# 장르: Talk
# 시즌 수: 2
# 줄거리: Talented entertainer and newly-minted EGOT Jennifer Hudson takes on the daytime talk show landscape.
# 등급: None
# 출연진:
# Jennifer Hudson
# 제작진:
# Jennifer Hudson
# 포스터 URL: https://image.tmdb.org/t/p/original/6VBNeo8XG90sNKWYQ0yTEmVBXHJ.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ZMPpLofgSTM
#
# 장르:
# 범죄
# 드라마
# id: 764
# 제목: Midsomer Murders
# 장르: Crime, Drama, Mystery
# 시즌 수: 24
# 줄거리: The peacefulness of the Midsomer community is shattered by violent crimes, suspects are placed under suspicion, and it is up to a veteran DCI and his young sergeant to calmly and diligently eliminate the innocent and ruthlessly pursue the guilty.
# 등급: 12
# 출연진:
# Neil Dudgeon
# Nick Hendrix
# Fiona Dolman
# 제작진:
# Kirsten Gair
# 로고 URL: https://image.tmdb.org/t/p/original/m2Jiqj8b4OjkjBHfp2px8gucB4h.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pz7tsWxe0TTdfJnWPjZAEnrSl5M.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ym8b4UJDqcw
#
# 장르:
# 코미디
# 드라마
# id: 4586
# 제목: 길모어 걸스
# 장르: 코미디, 드라마
# 시즌 수: 7
# 줄거리: 독립심이 강한 싱글맘 로렐라이는 아이비리그 진학은 문제없을 정도로 명석한 두뇌를 가진 딸 로리를 키운다. 이 모녀 사이에는 항상 재치 넘치는 대화가 끊이지 않는다.
# 등급: 12
# 출연진:
# Lauren Graham
# 알렉시스 블레델
# Scott Patterson
# 제작진:
# Gavin Polone
# 로고 URL: https://image.tmdb.org/t/p/original/knLz8N6ADgqfRyfgFTFJIEYG3jM.png
# 포스터 URL: https://image.tmdb.org/t/p/original/8hWwBpB1mLUKqzjdGrcvJcIklp4.jpg
# 예고편 URL: https://www.youtube.com/watch?v=Ac47mma8XRA
#
# 장르:
# 드라마
# id: 61733
# 제목: 엠파이어
# 장르: 드라마
# 시즌 수: 6
# 줄거리: 힙합 가수이자 엠파이어 엔터테인먼트의 CEO인 루시어스 라이언. 늘 어려움 없이 권력을 휘두르던 3년 내로 몸을 쓰지 못하게 될 거라는 의사의 진단을 받으면서 굶주린 상어 떼가 몰려드는데. 그는 가족 사이가 더 틀어지지 않게 지키면서도, 세 아들 중 누구에게 자신의 자리를 물려줄지 결정해야 한다. 루시어스가 가장 사랑하는 막내 하킴은 타고난 음악가지만 노력보다 명성을 중시한다. 둘째 자말은 재능이 있지만 쑥스러움을 타는 성격인 데다 동성애자라는 점이 라이언에게는 낯부끄럽다. 장남 안드레는 사업 수완이 있지만 카리스마가 부족하다. 한편, 라이언의 전 아내 쿠키가 다시 나타나면서 상황은 더 복잡해진다. 라이언의 무명 시절에 마약 거래로 생활비를 마련했던 그녀는 고생에 대한 보상을 요구하는데...
# 등급: 16
# 출연진:
# 테런스 하워드
# 터라지 P. 헨슨
# Bryshere Y. Gray
# 제작진:
# Lee Daniels
# 로고 URL: https://image.tmdb.org/t/p/original/tCxJHzyFPHB5OIHdbk0wQCuEnRm.png
# 포스터 URL: https://image.tmdb.org/t/p/original/gTrzYR6gWMhQ8yINW9JCLeoJHvf.jpg
# 예고편 URL: https://www.youtube.com/watch?v=3IpVV7xDMIo
#
# 장르:
# Talk
# 코미디
# id: 61818
# 제목: Late Night with Seth Meyers
# 장르: Talk, Comedy
# 시즌 수: 11
# 줄거리: Seth Meyers, who is "Saturday Night Live’s" longest serving anchor on the show’s wildly popular "Weekend Update," takes over as host of NBC’s "Late Night" — home to A-list celebrity guests, memorable comedy and the best in musical talent. As the Emmy Award-winning head writer for "SNL," Meyers has established a reputation for sharp wit and perfectly timed comedy, and has gained fame for his spot-on jokes and satire. Meyers takes his departure from "SNL" to his new post at "Late Night," as Jimmy Fallon moves to "The Tonight Show".
# 등급: None
# 출연진:
# Seth Meyers
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/g6MrJxNaHYGYU7Sxo72e5B8gKOV.jpg
# 예고편 URL: https://www.youtube.com/watch?v=rLwbzGyC6t4
#
# 장르:
# Reality
# id: 8514
# 제목: 루폴의 드래그 레이스
# 장르: Reality
# 시즌 수: 16
# 줄거리: 독보적인 무대 장악력을 뽐내는 퀸들이 무한 경쟁에 나섰다. 이들의 목표는 10만 달러 상금과 '미국의 차세대 드래그 슈퍼스타'라는 명예. 드래그 퀸의 대모 격인 루폴이 이들의 화려한 무대를 이끈다. 에미상 수상에 빛나는 리얼리티 쇼.
# 등급: 19
# 출연진:
# RuPaul
# Michelle Visage
# Carson Kressley
# 제작진:
# Tori Himes
# 로고 URL: https://image.tmdb.org/t/p/original/y2wUAB4og8Pi6ocOag3LSkKqVHz.png
# 포스터 URL: https://image.tmdb.org/t/p/original/6LThfVcGWSLswQaQh2vvk1Q2IoH.jpg
#
# 장르:
# Sci-Fi & Fantasy
# 코미디
# id: 4482
# 제목: Bewitched
# 장르: Sci-Fi & Fantasy, Comedy, Family, Drama
# 시즌 수: 8
# 줄거리: Samantha Stephens is a seemingly normal suburban housewife who also happens to be a genuine witch, with all the requisite magical powers. Her husband Darrin insists that Samantha keep her witchcraft under wraps, but situations invariably require her to indulge her powers while keeping her bothersome mother Endora at bay.
# 등급: 6
# 출연진:
# Elizabeth Montgomery
# Dick Sargent
# Agnes Moorehead
# 제작진:
# Harry Ackerman
# 로고 URL: https://image.tmdb.org/t/p/original/1RksPe8I9h1Ts24gybDsy2L36Ce.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7UZVO1SclbgVWM2ELrwWGaS7i94.jpg
# 예고편 URL: https://www.youtube.com/watch?v=0oT208N0Xd4
#
# 장르:
# 애니메이션
# 코미디
# id: 60625
# 제목: 릭 앤 모티
# 장르: 애니메이션, 코미디, Sci-Fi & Fantasy, Action & Adventure
# 시즌 수: 7
# 줄거리: 술에 절어 사는 천재 과학자 릭은 투정이 심한 10대 손자 모티를 데리고 외계와 대체 현실로 아슬아슬한 모험을 떠난다.
# 등급: 19
# 출연진:
# Chris Parnell
# Spencer Grammer
# Sarah Chalke
# 제작진:
# Anthony Alfonso
# 로고 URL: https://image.tmdb.org/t/p/original/wq3wqFLwwqnhG6DxmSji9ehLcx6.png
# 포스터 URL: https://image.tmdb.org/t/p/original/gdIrmf2DdY5mgN6ycVP0XlzKzbE.jpg
# 예고편 URL: https://www.youtube.com/watch?v=p_bH42OiUo4
#
# 장르:
# 드라마
# id: 4601
# 제목: Law & Order: Criminal Intent
# 장르: Drama
# 시즌 수: 10
# 줄거리: The third installment of the “Law & Order” franchise takes viewers deep into the minds of its criminals while following the intense psychological approaches the Major Case Squad uses to solve its crimes.
# 등급: 16
# 출연진:
# Vincent D'Onofrio
# Kathryn Erbe
# Julia Ormond
# 제작진:
# Dick Wolf
# 로고 URL: https://image.tmdb.org/t/p/original/zzNoDbK0vvAOdZIzUiwKUjbwyyO.png
# 포스터 URL: https://image.tmdb.org/t/p/original/68MUdrxeokhmd8pvlAjkD6yIfHR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=75IXY062Iqw
#
# 장르:
# 드라마
# 미스터리
# id: 39351
# 제목: 그림형제
# 장르: 드라마, 미스터리, Sci-Fi & Fantasy
# 시즌 수: 6
# 줄거리: 훈훈한 외모의, 미모의 약혼녀까지 겸비한 형사 '닉'은 어느날 괴이한 경험을 하게 된다. 다른 사람들 눈에 보이지 않는 사람들의 숨겨진 얼굴이 보이고, 동화 속 인물들이 현실에 존재한다는 사실을 알게 된다. '그림'의 마지막 후손 닉! 인간들을 공격하는 그들로부터 현실세계를 지키기 위해 그의 특별한 수사가 시작된다.
# 등급: 15
# 출연진:
# David Giuntoli
# Silas Weir Mitchell
# Russell Hornsby
# 제작진:
# Neal Sopata
# 로고 URL: https://image.tmdb.org/t/p/original/nOPg4FutzDnPdwlXMDy8hVRuJAr.png
# 포스터 URL: https://image.tmdb.org/t/p/original/iOptnt1QHi6bIHmOq6adnZTV0bU.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ElSANtJSrWQ
#
# 장르:
# 드라마
# 범죄
# id: 1396
# 제목: 브레이킹 배드
# 장르: 드라마, 범죄
# 시즌 수: 5
# 줄거리: 2008년 1월 AMC에서 방영을 시작한 범죄 스릴러. Breaking Bad는 막가기를 뜻하는 미국 남부 지방의 속어이다. 한때 노벨화학상까지 바라 볼 정도로 뛰어난 과학자였던 고등학교 화학 교사 월터 화이트는 자신의 50세 생일 날에 폐암 3기 진단을 받는다. 어느 날 동서와 함께 마약 단속 현장을 참관한 그는 현장에서 달아나는 옛 제자 제시를 발견한다. 뇌성마비에 걸린 고등학생 아들과 임신한 아내를 위해 제시에게 동업을 제의한 월터는 자신의 화학지식을 이용해 전례없는 고순도 고품질의 메스암페타민을 제조한다.
# 등급: 19
# 출연진:
# 브라이언 크랜스턴
# 아론 폴
# 애나 건
# 제작진:
# Jennifer Bryan
# 로고 URL: https://image.tmdb.org/t/p/original/chw44B2VnLha8iiTdyZcIW0ZELC.png
# 포스터 URL: https://image.tmdb.org/t/p/original/ztkUQFLlC19CCMYHW9o1zWhJRNq.jpg
# 예고편 URL: https://www.youtube.com/watch?v=XZ8daibM3AE
#
# 장르:
# 드라마
# 가족
# id: 1950
# 제목: 에버우드
# 장르: 드라마, 가족
# 시즌 수: 4
# 줄거리: 아내의 갑작스러운 죽음으로 뉴욕에서 전문의로서 명성을 누리던 주인공이 자신의 아이들에게 진정한 아버지가 되고자 시골 소도시 에버우드로 이사를 오게 되면서 벌어지는 마을의 사건들과 주민들의 융화와 갈등을 조명하는 드라마
# 등급: 12
# 출연진:
# Treat Williams
# Gregory Smith
# Emily VanCamp
# 제작진:
# Greg Berlanti
# 포스터 URL: https://image.tmdb.org/t/p/original/4zmuA2Ql1QdUtw9OM6MdmtXnZEF.jpg
#
# 장르:
# Action & Adventure
# 범죄
# id: 4357
# 제목: Mission: Impossible
# 장르: Action & Adventure, Crime, Drama, Mystery
# 시즌 수: 7
# 줄거리: Mission: Impossible is an American television series that was created and initially produced by Bruce Geller. It chronicles the missions of a team of secret government agents known as the Impossible Missions Force. In the first season, the team is led by Dan Briggs, played by Steven Hill; Jim Phelps, played by Peter Graves, takes charge for the remaining seasons. A hallmark of the series shows Briggs or Phelps receiving his instructions on a recording that then self-destructs, followed by the theme music composed by Lalo Schifrin.
#
# The series aired on the CBS network from September 1966 to March 1973, then returned to television for two seasons on ABC, from 1988 to 1990, retaining only Graves in the cast. It later inspired a popular series of theatrical motion pictures starring Tom Cruise, beginning in 1996.
# 등급: 12
# 출연진:
# Peter Graves
# Greg Morris
# Peter Lupus
# 제작진:
# Robert H. Justman
# 로고 URL: https://image.tmdb.org/t/p/original/5dTv8RjhPOln3Y5hANqdfxm7B59.png
# 포스터 URL: https://image.tmdb.org/t/p/original/bAnCcwe70IXHRwUgsRJT4ZlQ47o.jpg
#
# 장르:
# 가족
# 드라마
# id: 14929
# 제목: 하트랜드
# 장르: 가족, 드라마, 코미디
# 시즌 수: 17
# 줄거리: 야무진 소녀 에이미는 어머니의 갑작스럽게 죽은 충격에서 헤어나지 못 한다. 한편 에이미와 그녀의 할아버지는 목장을 잃을 수 있는 위기에 봉착한다.
# 등급: 12
# 출연진:
# Amber Marshall
# Graham Wardle
# Shaun Johnston
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/1bVQuM21SMsCAIkSe61HvBdKlfi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/uc2gtWczT58BiAUJWFz9P5aZmNF.jpg
# 예고편 URL: https://www.youtube.com/watch?v=gnLKnXN6VQc
#
# 장르:
# 코미디
# Talk
# id: 66465
# 제목: The Kapil Sharma Show
# 장르: Comedy, Talk
# 시즌 수: 3
# 줄거리:
# 등급: None
# 출연진:
# Kapil Sharma
# Archana Puran Singh
# Krishna Abhishek
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/fBPNBNFmcwhYXUpkW2Kb6jbeJOR.jpg
#
# 장르:
# 코미디
# Talk
# id: 4419
# 제목: Real Time with Bill Maher
# 장르: Comedy, Talk
# 시즌 수: 22
# 줄거리: Each week Bill Maher surrounds himself with a panel of guests which include politicians, actors, comedians, musicians and the like to discuss what's going on in the world.
# 등급: 18
# 출연진:
# Bill Maher
# 제작진:
# Alessio Pollacci
# 포스터 URL: https://image.tmdb.org/t/p/original/pbpoLLp4kvnYVfnEGiEhagpJuVZ.jpg
#
# 장르:
# 드라마
# id: 21762
# 제목: Parenthood
# 장르: Drama
# 시즌 수: 6
# 줄거리: The trials and tribulations of the very large, colorful and imperfect Braverman family.
# 등급: None
# 출연진:
# Peter Krause
# Monica Potter
# Lauren Graham
# 제작진:
# Debra James
# 로고 URL: https://image.tmdb.org/t/p/original/sugCFBeGOxmIXp0bC0iPMrM7pBW.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9KjKLJrrUI1sU9bNsQaQ5H8kTyY.jpg
# 예고편 URL: https://www.youtube.com/watch?v=o_cblVvo5bg
#
# 장르:
# 드라마
# Sci-Fi & Fantasy
# id: 56296
# 제목: 오펀 블랙
# 장르: 드라마, Sci-Fi & Fantasy
# 시즌 수: 5
# 줄거리: 세라는 자신과 똑 닮은 여성이 자살하는 충격적인 장면을 목격하고, 죽은 이의 신분으로 위장한 채 새로운 인생을 살려고 한다.
# 등급: 19
# 출연진:
# Tatiana Maslany
# Jordan Gavaris
# Josh Vokey
# 제작진:
# Jessica Stein
# 로고 URL: https://image.tmdb.org/t/p/original/b9LYnRp4eEX2280BOCPBALI5Via.png
# 포스터 URL: https://image.tmdb.org/t/p/original/xKo79AxtabAFoJTqz4RuC3APND4.jpg
# 예고편 URL: https://www.youtube.com/watch?v=OcnIQeWY6MA
#
# 장르:
# 코미디
# 가족
# id: 4313
# 제목: 풀 하우스
# 장르: 코미디, 가족
# 시즌 수: 8
# 줄거리: 1987년부터 1995년 사이 미국에서 많은 사랑을 받았던 시트콤
# 등급: 0
# 출연진:
# John Stamos
# Bob Saget
# Dave Coulier
# 제작진:
# Tom Amundsen
# 로고 URL: https://image.tmdb.org/t/p/original/uMFvvQYCYaDD4j6GMiobUj0y4Ws.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7g0EyKsIaYjYw3gCIBKMHHE0Kcu.jpg
# 예고편 URL: https://www.youtube.com/watch?v=SDP7__2F1YE
#
# 장르:
# 드라마
# id: 71712
# 제목: 굿 닥터
# 장르: 드라마
# 시즌 수: 7
# 줄거리: 자폐증을 가진 젊은 외과 의사가 명문 병원에 들어가게된다. 이에 사람들과 소통하지 못하는 의사가 사람의 목숨을 구할 수 있을 까 하는 의문이 제기되는데...
# 등급: 15
# 출연진:
# 프레디 하이모어
# Fiona Gubelmann
# Will Yun Lee
# 제작진:
# 박재범
# 로고 URL: https://image.tmdb.org/t/p/original/zhHSO2xwslKy1PsDltKslEh0rjj.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/pFqzXacKsi9or1GVdxTLutXD9zM.jpg
# 예고편 URL: https://www.youtube.com/watch?v=lnY9FWUTY84
#
# 장르:
# 코미디
# 범죄
# id: 1695
# 제목: 몽크
# 장르: 코미디, 범죄, 드라마, 미스터리
# 시즌 수: 8
# 줄거리: 현대 샌프란시스코를 배경으로 하는 코미디 수사물 미드. 3년 전 자동차 폭발 사건으로 아내를 잃은이후 큰 충격에서 빠져나오지 못한 채, 독특한 강박관념에 사로잡혀 많은 사람들이 모인 군중과 높은 곳, 그리고 어둠을 두려워하는 증세를 보이는 전직 경찰 에이드리언 몽크가 샌프란시스코 경찰을 도와 복잡한 사건들을 해결한다.
# 등급: 15
# 출연진:
# 토니 샬호브
# 테드 러바인
# Jason Gray-Stanford
# 제작진:
# Josh Siegal
# 로고 URL: https://image.tmdb.org/t/p/original/pIOqR6IchhSOmaIZIyDGW9QB982.svg
# 포스터 URL: https://image.tmdb.org/t/p/original/3axGMbUecXXOPSeG47v2i9wK5y5.jpg
# 예고편 URL: https://www.youtube.com/watch?v=mftbaaU82Uc
#
# 장르:
# Soap
# 드라마
# id: 3769
# 제목: Dynasty
# 장르: Soap, Drama
# 시즌 수: 9
# 줄거리: The saga of a wealthy Denver family in the oil business: Blake Carrington, the patriarch; Krystle, his former secretary and wife; his children: Adam, lost in childhood after a kidnapping; Fallon, pampered and spoiled; Steven, openly gay; and Amanda, hidden from him by his ex-wife, the conniving Alexis. Most of the show features the conflict between 2 large corporations, Blake's Denver Carrington and Alexis' ColbyCo.
# 등급: 12
# 출연진:
# John Forsythe
# Linda Evans
# Joan Collins
# 제작진:
# Elaine Rich
# 로고 URL: https://image.tmdb.org/t/p/original/wFLfnNQjGnO0Dvg7f07mnTZ9Y5K.png
# 포스터 URL: https://image.tmdb.org/t/p/original/bKBTf22IDwD39GbpQ6clYQ2WCtA.jpg
# 예고편 URL: https://www.youtube.com/watch?v=oftDrdDBTkw
#
# 장르:
# 드라마
# Sci-Fi & Fantasy
# id: 62688
# 제목: 슈퍼걸
# 장르: 드라마, Sci-Fi & Fantasy, Action & Adventure
# 시즌 수: 6
# 줄거리: 재난을 막기 위해 자신의 초능력과 정체를 드러낸 카라 댄버스. 슈퍼맨의 사촌이자 슈퍼걸로 알려진 그녀가 내셔널 시티의 수호자로 나선다.
# 등급: 15
# 출연진:
# 멜리사 베노이스트
# Chyler Leigh
# David Harewood
# 제작진:
# Karen Maser
# 로고 URL: https://image.tmdb.org/t/p/original/uN3wd0a3QEpIIKEmXVGmIa1Gw22.png
# 포스터 URL: https://image.tmdb.org/t/p/original/vqBsgL9nd2v04ZvCqPzwtckDdFD.jpg
# 예고편 URL: https://www.youtube.com/watch?v=Mh8MYFadTmQ
#
# 장르:
# 코미디
# id: 2691
# 제목: 두 남자와 1/2
# 장르: 코미디
# 시즌 수: 12
# 줄거리: 자유로운 영혼이었던 찰리가 떠나간 이후, 앨런과 그의 아들 제이크에게 찾아온 앨런의 친구 월든이 다시금 새로운 가족으로 생활하게 되면서 벌어지는 코믹한 일상을 담은 시트콤
# 등급: 15
# 출연진:
# 애쉬튼 커쳐
# Jon Cryer
# Conchata Ferrell
# 제작진:
# Jim Patterson
# 로고 URL: https://image.tmdb.org/t/p/original/ivAjR58o2LaAHDThE923k7VOV37.png
# 포스터 URL: https://image.tmdb.org/t/p/original/xgfjxyV3g1S68opzuvG6G87muDp.jpg
# 예고편 URL: https://www.youtube.com/watch?v=h1YadOPGL-0
#
# 장르:
# 드라마
# Soap
# id: 72002
# 제목: 다이너스티: 1%의 1%
# 장르: 드라마, Soap
# 시즌 수: 5
# 줄거리: 모든 것을 가진 두 가문 캐링턴과 콜비. 그들이 격돌한다. 막대한 부를 차지하고 자식들을 길들이기 위해. 새로운 모습으로 돌아온 80년대 미국 드라마의 전설.
# 등급: 15
# 출연진:
# Elizabeth Gillies
# Grant Show
# Daniella Alonso
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/pFjglX2YwbbfogHh32VakoffjRr.png
# 포스터 URL: https://image.tmdb.org/t/p/original/rVQ35erLIoV8hyh7lIKAMiChmOO.jpg
# 예고편 URL: https://www.youtube.com/watch?v=PzBX_c-F6sk
#
# 장르:
# Soap
# 드라마
# id: 223365
# 제목: Rebirth
# 장르: Soap, Drama
# 시즌 수: 1
# 줄거리: After making a pact with Jequitibá, José Inocêncio becomes a mythical figure, known as the most successful cocoa farmer in the region. While still young, he wins the heart of Maria Santa. Their intense passion results in four children: José Augusto, José Bento, José Venâncio, and the youngest, João Pedro, who never had the opportunity to know his mother, as she dies while giving birth to him. This tragedy fuels José Inocêncio’s anger, blaming João Pedro for the loss of his great love. Throughout their lives, indifference and resentment mark the relationship between the father and his youngest son. As if the past weren’t enough, years later, the arrival of the mysterious Mariana puts all these emotions to the test when both father and son fall in love with the same woman. This situation reawakens feelings that were either dormant or previously unknown to them.
# 등급: None
# 출연진:
# Marcos Palmeira
# Theresa Fonseca
# Juan Paiva
# 제작진:
# Bruno Luperi
#
# 장르:
# 드라마
# War & Politics
# id: 61378
# 제목: 마담 세크리터리
# 장르: 드라마, War & Politics
# 시즌 수: 6
# 줄거리: 전임자의 갑작스러운 사망으로 국무장관에 임명된 전직 CIA 요원 엘리자베스. 국내외 현안을 책임지는 동시에 아내와 엄마의 역할도 소홀하지 않고자 동분서주한다.
# 등급: 15
# 출연진:
# 테아 레오니
# Tim Daly
# Zeljko Ivanek
# 제작진:
# Eric Stoltz
# 로고 URL: https://image.tmdb.org/t/p/original/v2lhWorIskFunq2vwzBrtbeWuWR.png
# 포스터 URL: https://image.tmdb.org/t/p/original/6Nl1ablo4DNTLb4ZH7Mycz81AEt.jpg
# 예고편 URL: https://www.youtube.com/watch?v=dR9dEhaCnhA
#
# 장르:
# Action & Adventure
# 애니메이션
# id: 31911
# 제목: 강철의 연금술사 BROTHERHOOD
# 장르: Action & Adventure, 애니메이션, Sci-Fi & Fantasy, 코미디, 드라마
# 시즌 수: 1
# 줄거리: 죽은 어머니를 살리기 위해 시도한 금단의 연금술로 인해 신체의 일부와 전부를 빼앗긴 에드워드와 알폰스 형제. 동생 알폰스의 신체를 되찾기 위해 현자의 돌을 찾아나선다. 강철의 연금술사 오리지널판 이후 제작되어 원작 만화를 더욱 충실히 반영한 리메이크 버전이다.
# 등급: 15
# 출연진:
# 박로미
# 쿠기미야 리에
# 미키 신이치로
# 제작진:
# Akira Senju
# 로고 URL: https://image.tmdb.org/t/p/original/gMIqyAOrFP1E6lQ9S093KcNgoHK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/5ZFUEOULaVml7pQuXxhpR2SmVUw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=8nm-Qd0zwJM
#
# 장르:
# Talk
# 코미디
# id: 22980
# 제목: Watch What Happens Live with Andy Cohen
# 장르: Talk, Comedy
# 시즌 수: 21
# 줄거리: Bravo network executive Andy Cohen discusses pop culture topics with celebrities and reality show personalities.
# 등급: None
# 출연진:
# Andy Cohen
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/oYB3zGjXNrmmznTUAxORfReWzhw.png
# 포스터 URL: https://image.tmdb.org/t/p/original/onSD9UXfJwrMXWhq7UY7hGF2S1h.jpg
#
# 장르:
# 범죄
# 드라마
# id: 58841
# 제목: 시카고 PD
# 장르: 범죄, 드라마
# 시즌 수: 11
# 줄거리: 시카고 경찰들의 이야기. 일선에서 직접 범죄자들과 싸우는 제복 경찰들과, 조직범죄나 마약밀매 등의 범죄를 조사하는 정보팀 소속 대원들의 활약을 그린다.
# 등급: 15
# 출연진:
# Jason Beghe
# Tracy Spiridakos
# Marina Squerciati
# 제작진:
# Dick Wolf
# 로고 URL: https://image.tmdb.org/t/p/original/mcwj8Di0nBdaraQrMji6VauMBeZ.png
# 포스터 URL: https://image.tmdb.org/t/p/original/mZObarMPF76PGVmwywQ7Ks4UFpR.jpg
# 예고편 URL: https://www.youtube.com/watch?v=NZcr9IFS9R0
#
# 장르:
# 코미디
# id: 65701
# 제목: Good Mythical Morning
# 장르: Comedy
# 시즌 수: 25
# 줄거리: Two "Internetainers" (Rhett & Link) go far out and do the weirdest  things, giving you a daily dose of casual comedy every Monday-Friday.
# 등급: None
# 출연진:
# Link Neal
# Rhett McLaughlin
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/2Fja87aTeuXxTEI1MH2IuHHSsLq.jpg
# 예고편 URL: https://www.youtube.com/watch?v=1iLbfGIygO0
#
# 장르:
# Soap
# 드라마
# id: 237480
# 제목: No Rancho Fundo
# 장르: Soap, Drama, Comedy
# 시즌 수: 1
# 줄거리:
# 등급: None
# 출연진:
# Larissa Bocchino
# Andréa Beltrão
# Alexandre Nero
# 제작진:
# Mário Teixeira
#
# 장르:
# 드라마
# id: 3172
# 제목: 프라이빗 프랙티스
# 장르: 드라마
# 시즌 수: 6
# 줄거리: 스핀오프 시리즈. 시애틀의 그레이스 병원을 떠나, LA의 작은 병원 씨사이드 웰니스(Seaside Wellness)로 근무지를 옮긴 애디슨 몽고메리 박사와 그 동료들의 이야기.
# 등급: 12
# 출연진:
# 케이트 월시
# Paul Adelstein
# KaDee Strickland
# 제작진:
# Mark Gordon
# 로고 URL: https://image.tmdb.org/t/p/original/s7sVPIHXsWPEaHR17ag3MXp0bQR.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pW20ANAGdrgreYJExduUVaWos6H.jpg
#
# 장르:
# 코미디
# id: 1778
# 제목: Zoey 101
# 장르: Comedy
# 시즌 수: 4
# 줄거리: Zoey 101 is an American television series which originally aired on Nickelodeon from January 9, 2005 until May 2, 2008. It focuses on the lives of teenager Zoey Brooks and her friends as they attend Pacific Coast Academy, a fictional boarding school in Southern California. It was created by Dan Schneider. It was initially filmed at Pepperdine University in Malibu, California, then at stages in Valencia, California beginning in season 3. It was nominated for an "Outstanding Children's Program" Emmy in 2005. Zoey 101 was the most expensive production ever for Nickelodeon series, as it was shot completely on location in Malibu. It was also Nickelodeon's best performance for a series premiere in almost eight years. Despite this, many critics have made negative comments about the show, its setting, and its characters.
# 등급: 6
# 출연진:
# Jamie Lynn Spears
# Paul Butcher
# Victoria Justice
# 제작진:
# Bill O'Dowd
# 로고 URL: https://image.tmdb.org/t/p/original/x8GvXInGjxOgGQZ3eryFm4ADtZW.png
# 포스터 URL: https://image.tmdb.org/t/p/original/A3O2B4cHEyMpvknrdG4bcV4eaYh.jpg
# 예고편 URL: https://www.youtube.com/watch?v=RX6YeYT3ed8
#
# 장르:
# 드라마
# id: 78191
# 제목: 너의 모든 것
# 장르: 드라마
# 시즌 수: 5
# 줄거리: 지적이고 영리한 서점 직원. 하지만 위험한 내면을 지닌 그가 작가 지망생에게 반한다. 마음이 끌리는 사람에게 다가가기 위해서라면, 무슨 짓이든 할 수 있다. 위험한 매력의 소유자, 집착의 끝을 보여주는 남자. 그의 소름 끼치는 로맨스가 시작된다.
# 등급: 19
# 출연진:
# Penn Badgley
# Charlotte Ritchie
# Tilly Keeper
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/VeNCc4i7LbRQpwC1mYl5jtBzFM.png
# 포스터 URL: https://image.tmdb.org/t/p/original/7bEYwjUvlJW7GerM8GYmqwl4oS3.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ga1m0wjzscU
#
# 장르:
# Soap
# id: 206559
# 제목: Binnelanders
# 장르: Soap
# 시즌 수: 19
# 줄거리: A South African Afrikaans soap opera. It is set in and around the fictional private hospital, Binneland Kliniek, in Pretoria, and the storyline follows the trials, trauma and tribulations of the staff and patients of the hospital.
# 등급: None
# 출연진:
# Hans Strydom
# Reynardt Hugo
# Hykie Berg
# 제작진:
# Jak de Priester
# 예고편 URL: https://www.youtube.com/watch?v=Uegxh8K8g3E
#
# 장르:
# Action & Adventure
# 드라마
# id: 1532
# 제목: Starsky & Hutch
# 장르: Action & Adventure, Drama, Crime
# 시즌 수: 4
# 줄거리: Streetwise Detective David Starsky partners up with a more intellectual partner, Kenneth 'Hutch' Hutchinson, to protect citizens and patrol the streets of Bay City.
# 등급: 12
# 출연진:
# David Soul
# Paul Michael Glaser
# Antonio Fargas
# 제작진:
# Aaron Spelling
# 포스터 URL: https://image.tmdb.org/t/p/original/aBj5oTi1uibVcXDoCJeKseJNY2d.jpg
# 예고편 URL: https://www.youtube.com/watch?v=8WHQ2UWB2ko
#
# 장르:
# News
# id: 94722
# 제목: Tagesschau
# 장르: News
# 시즌 수: 73
# 줄거리: German daily news program, the oldest still existing program on German television.
# 등급: None
# 출연진:
# 제작진:
#
# 장르:
# 범죄
# 드라마
# id: 39852
# 제목: 죄인
# 장르: 범죄, 드라마
# 시즌 수: 4
# 줄거리: 평범한 젊은 엄마가 처음 보는 남자를 칼로 찔러 죽인다. 그녀 자신마저 알 수 없는 이유로. 그녀를 동정하는 형사는 진실을 찾아 사라진 기억의 미궁 속으로 발을 들인다.
# 등급: 16
# 출연진:
# 빌 풀먼
# 프랜시스 피셔
# Alice Kremelberg
# 제작진:
# David DeMarinis
# 로고 URL: https://image.tmdb.org/t/p/original/xbOpER6gqANjw7GpQz3wfMzasRK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/rmibFGdqOe0kKKhPls0jVOdZCWw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ZEfnpFuzxnE
#
# 장르:
# 드라마
# id: 269
# 제목: One Tree Hill
# 장르: Drama
# 시즌 수: 9
# 줄거리: In Tree Hill, North Carolina two half brothers share a last name and nothing else. Brooding, blue-collar Lucas is a talented street-side basketball player, but his skills are appreciated only by his friends at the river court. Popular, affluent Nathan basks in the hero-worship of the town, as the star of his high school team. And both boys are the son of former college ball player Dan Scott whose long ago choice to abandon Lucas and his mother Karen, will haunt him long into his life with wife Deb and their son Nathan.
# 등급: 16
# 출연진:
# James Lafferty
# Bethany Joy Lenz
# Sophia Bush
# 제작진:
# Joe Davola
# 로고 URL: https://image.tmdb.org/t/p/original/oEcHVvhnD4XHwdbR7Bg2F7y2vZB.png
# 포스터 URL: https://image.tmdb.org/t/p/original/sOrelBaAhp7DZbPTivDwKEyPslC.jpg
# 예고편 URL: https://www.youtube.com/watch?v=GIFbz7uTOKI
#
# 장르:
# 코미디
# Talk
# id: 63770
# 제목: The Late Show with Stephen Colbert
# 장르: Comedy, Talk
# 시즌 수: 9
# 줄거리: Stephen Colbert brings his signature satire and comedy to The Late Show with Stephen Colbert, the #1 show in late night, where he talks with an eclectic mix of guests about what is new and relevant in the worlds of politics, entertainment, business, music, technology, and more. Featuring bandleader Jon Batiste with his band Stay Human, the Emmy Award-nominated show is broadcast from the historic Ed Sullivan Theater. Stephen Colbert, Chris Licht, Tom Purcell, and Jon Stewart are executive producers. Barry Julien and Denise Rehrig serve as co-executive producers.must watch
# 등급: None
# 출연진:
# Stephen Colbert
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/wdjsrCJWXtwNpW9NmtpcTJqOCNY.png
# 포스터 URL: https://image.tmdb.org/t/p/original/9jkThAGYj2yp8jsS6Nriy5mzKFT.jpg
# 예고편 URL: https://www.youtube.com/watch?v=nWufb0qL1xU
#
# 장르:
# 코미디
# Reality
# id: 31248
# 제목: It's Showtime
# 장르: Comedy, Reality
# 시즌 수: 4
# 줄거리: A Philippine noontime musical and party variety show. What began as a search for the country’s most entertaining acts evolves into a hit variety program thriving on spontaneity and animated conversations while drawing talents from all walks of life.
# 등급: None
# 출연진:
# Vice Ganda
# Anne Curtis
# Vhong Navarro
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/nKxXaAIO2ljugKhKFYQ8LmIJ1x7.jpg
#
# 장르:
# 범죄
# id: 41149
# 제목: Die Rosenheim-Cops
# 장르: Crime
# 시즌 수: 23
# 줄거리:
# 등급: 12
# 출연진:
# Max Müller
# Marisa Burger
# Igor Jeftic
# 제작진:
#
# 장르:
# 범죄
# Action & Adventure
# id: 71790
# 제목: 스와트
# 장르: 범죄, Action & Adventure, 드라마
# 시즌 수: 7
# 줄거리: 로스앤젤레스에서 발생하는 특수임무를 수행하는 특수 기동대, S.W.A.T.은 리더 혼도의 지휘 아래, 팀원들은 꼬리에 꼬리를 무는 사건과 그 뒤에 숨은 거대한 세력에 맞서 도시를 지킨다.
# 등급: 12
# 출연진:
# Shemar Moore
# Jay Harrington
# David Lim
# 제작진:
# 로고 URL: https://image.tmdb.org/t/p/original/uBxIeTKeYhtdI8TtWYqIrAgFvSt.png
# 포스터 URL: https://image.tmdb.org/t/p/original/1l7vsAIkqOzrqiPwjO27Cb5QdfJ.jpg
# 예고편 URL: https://www.youtube.com/watch?v=HHVae76dbqI
#
# 장르:
# 코미디
# News
# id: 1667
# 제목: Saturday Night Live
# 장르: Comedy, News
# 시즌 수: 49
# 줄거리: A late-night live television sketch comedy and variety show created by Lorne Michaels. The show's comedy sketches, which parody contemporary culture and politics, are performed by a large and varying cast of repertory and newer cast members. Each episode is hosted by a celebrity guest, who usually delivers an opening monologue and performs in sketches with the cast, and features performances by a musical guest.
# 등급: 16
# 출연진:
# Michael Che
# Mikey Day
# Andrew Dismukes
# 제작진:
# Lorne Michaels
# 로고 URL: https://image.tmdb.org/t/p/original/p7y5gW1JqePKQTrpmkiRFnH6fUX.png
# 포스터 URL: https://image.tmdb.org/t/p/original/sHGuKFjIBisPk8cvtCZTDVktYfs.jpg
# 예고편 URL: https://www.youtube.com/watch?v=_Np6fu-0OoY
#
# 장르:
# Action & Adventure
# 애니메이션
# id: 30984
# 제목: 블리치
# 장르: Action & Adventure, 애니메이션, Sci-Fi & Fantasy
# 시즌 수: 2
# 줄거리: '쿠로사키 이치고'는 유령을 볼 수 있는 15세의 남자다. 특수한 체질을 가지고도 평범한 생활을 하던 이치고에게 갑자기 스스로를 사신이라고 소개하는 소녀 '쿠치키 루키아'가 나타난다. 유아울러 산 사람, 죽은 사람 안 가리고 공격해서 영혼을 먹어치우는 나쁜 혼령 '호로'도 모습을 드러낸다. 그런데 호로로 인해 이치고의 가족이 쓰러져가는데...
# 등급: 15
# 출연진:
# Masakazu Morita
# 折笠富美子
# 安元洋貴
# 제작진:
# Haruo Miyagawa
# 로고 URL: https://image.tmdb.org/t/p/original/21zm3sP3j6rmpbZR3j0quusRe6h.png
# 포스터 URL: https://image.tmdb.org/t/p/original/2EewmxXe72ogD0EaWM8gqa0ccIw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=T6wo7bfYYu4
#
# 장르:
# Soap
# 드라마
# id: 231418
# 제목: Salón de té La Moderna
# 장르: Soap, Drama
# 시즌 수: 2
# 줄거리:
# 등급: 12
# 출연진:
# 제작진:
#
# 장르:
# 애니메이션
# Action & Adventure
# id: 46298
# 제목: 헌터x헌터
# 장르: 애니메이션, Action & Adventure, Sci-Fi & Fantasy
# 시즌 수: 3
# 줄거리: 주인공 곤 프릭스는 아버지 진 프릭스를 찾기 위해 헌터 시험에 응시한다. 그리고 그곳에서 새로운 친구들과 만나 모험을 떠난다.
# 등급: 12
# 출연진:
# 한 메구미
# 이세 마리야
# 二又一成
# 제작진:
# Hiroshi Koujina
# 로고 URL: https://image.tmdb.org/t/p/original/aPCnfL0Tt4CxUXQLBIRmsbrF02X.png
# 포스터 URL: https://image.tmdb.org/t/p/original/ucpgmUR1h5Te1BYegKItoPjOeF7.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qibSkLoSVAA
#
# 장르:
# Sci-Fi & Fantasy
# 드라마
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 188
#     185         print()
#     187 if __name__ == "__main__":
# --> 188     main()
#
# Cell In[1], line 183, in main()
#     181 series_details = fetch_series_details(series['id'])
#     182 series_images = fetch_series_images(series['id'])
# --> 183 series_videos = fetch_series_videos(series['id'])  # 영상 정보 가져오기 추가
#     184 print_series_info(series_details, series_images, series_videos)  # 영상 정보 전달
#     185 print()
#
# Cell In[1], line 119, in fetch_series_videos(series_id, language)
#     113 url = f'https://api.themoviedb.org/3/tv/{series_id}/videos'
#     115 params = {
#     116     'api_key': TMDB_API_KEY,
#     117     'language': language,
#     118 }
# --> 119 response = requests.get(url, params=params)
#     120 data = response.json()
#     122 key_mapping = {
#     123     'Trailer': 'trailer',
#     124     'Clip': 'clip',
#     125     'Teaser': 'teaser',
#     126     'Opening Credits': 'opening_credits'
#     127 }
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
#     466     # Trigger any extra validation we need to do.
#     467     try:
# --> 468         self._validate_conn(conn)
#     469     except (SocketTimeout, BaseSSLError) as e:
#     470         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1095 # Force connect early to allow us to validate the connection.
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#    1100     warnings.warn(
#    1101         (
#    1102             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1107         InsecureRequestWarning,
#    1108     )
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\connection.py:783, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     780     if is_ipaddress(normalized):
#     781         server_hostname = normalized
# --> 783 ssl_sock = ssl_wrap_socket(
#     784     sock=sock,
#     785     keyfile=key_file,
#     786     certfile=cert_file,
#     787     key_password=key_password,
#     788     ca_certs=ca_certs,
#     789     ca_cert_dir=ca_cert_dir,
#     790     ca_cert_data=ca_cert_data,
#     791     server_hostname=server_hostname,
#     792     ssl_context=context,
#     793     tls_in_tls=tls_in_tls,
#     794 )
#     796 try:
#     797     if assert_fingerprint:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:446, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     444 if ca_certs or ca_cert_dir or ca_cert_data:
#     445     try:
# --> 446         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     447     except OSError as e:
#     448         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %% [markdown]
# #최종본 + 장르를 한국어로만 출력하도록(단, 영어로된 장르명이 유일한 경우에는 영어로 출력되도록)

# %%
from langdetect import detect
import requests

# TMDB API 키
TMDB_API_KEY = 'cd88d12bfe4c5d842ef9a464b2f0bcd1'
language = 'ko'

#TV SERIES LISTS > POPULAR
#인기있는 tv 시리즈 출력을 위한 API
def fetch_popular_series(language='ko-KR', region='KR', page=1, total_results=200):
    url = f'https://api.themoviedb.org/3/tv/popular'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'region': region,
        'page': page,  # 페이지 번호 설정
    }

    results = []
    while len(results) < total_results:
        response = requests.get(url, params=params)
        data = response.json()
        results.extend(data['results'])
        page += 1
        params['page'] = page

    return results[:total_results]

def fetch_series_rating(series_id):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/content_ratings'
    params = {
        'api_key': TMDB_API_KEY
    }

    response = requests.get(url, params=params)
    data = response.json()
    
    kr_rating = None
    de_rating = None
    
    if 'results' in data:
        for result in data['results']:
            iso_3166_1 = result.get('iso_3166_1')
            rating = result.get('rating')
            
            if iso_3166_1 == 'KR':
                kr_rating = rating
            elif iso_3166_1 == 'DE':
                de_rating = rating
    
    if kr_rating:
        return kr_rating
    elif de_rating:
        return de_rating
    else:
        return None
    
#TV SERIES > DETAILS
def fetch_series_details(series_id, language='ko-KR'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}'
    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
        'append_to_response': 'credits'  # 출연진 및 제작진 정보
    }

    response = requests.get(url, params=params)
    data = response.json()

    #GENRE
    if 'genres' in data:
        print("장르:")
        if len(data['genres']) == 1: #GENRE 내 리스트가 하나뿐인 경우에는 언어 상관없이 출력
            print(data['genres'][0]['name'])
        else:
            for genre in data['genres']:
                #GENRE가 한국어로 저장된 것만 출력
                if detect(genre['name']) == 'ko':
                    print(genre['name'])
    
    if 'overview' not in data or not data['overview']:
        params['language'] = 'en'
        response = requests.get(url, params=params)
        data = response.json()

    return data

#TV SERIES > IMAGES(로고, 포스터 이미지)
def fetch_series_images(series_id, language='ko'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/images'
   
    params = {
        'api_key': TMDB_API_KEY,
        'language': language
    }

    response = requests.get(url, params=params)
    data = response.json()
    
    # 한국어 포스터/로고가 없을 시 영어버전 출력
    if ('posters' not in data or len(data['posters']) == 0) or ('logos' not in data or len(data['logos']) == 0):
        params['language'] = 'en'
        response = requests.get(url, params=params)
        data = response.json()

        if 'posters' in data and len(data['posters']) > 0:
            data['posters'] = data['posters'][:1]
        if 'logos' in data and len(data['logos']) > 0:
            data['logos'] = data['logos'][:1]

    return data

#TV SERIES > VIDEOS
#TRAILER 
def fetch_series_videos(series_id, language='en'):
    url = f'https://api.themoviedb.org/3/tv/{series_id}/videos'

    params = {
        'api_key': TMDB_API_KEY,
        'language': language,
    }
    response = requests.get(url, params=params)
    data = response.json()

    key_mapping = {
        'Trailer': 'trailer',
        'Clip': 'clip',
        'Teaser': 'teaser',
        'Opening Credits': 'opening_credits'
    }

    for item in data.get('results', []):
        video_type = item.get('type')
        if video_type in key_mapping:
            return item.get('key')

    return None


def print_series_info(series, series_images, series_videos):
    print("id:", series['id'])
    print("제목:", series['name'])
    print("장르:", ", ".join([genre['name'] for genre in series['genres']]))
    print("시즌 수:", f"{series['number_of_seasons']}")
    print("줄거리:", series['overview'])
    
    #RATING
    series_id = series['id']
    rating = fetch_series_rating(series_id)
    print("등급:", rating)


    #CAST
    if 'credits' in series and 'cast' in series['credits']:
        print("출연진:")
        for cast in series['credits']['cast'][:3]:
            print(f"{cast['name']}")
    
    #CREW
    if 'credits' in series and 'crew' in series['credits']:
        print("제작진:")
        if series['credits']['crew']:  # 제작진 정보가 있는 경우에만 출력
            crew = series['credits']['crew'][0]  # 첫 번째 제작진 정보만 출력
            print(f"{crew['name']}")
    
    #LOGO
    if 'logos' in series_images:
        for logo in series_images['logos']:
            print("로고 URL:", f"https://image.tmdb.org/t/p/original{logo['file_path']}")

    #POSTER_URL
    if 'posters' in series_images:
         for poster in series_images['posters']:
            print("포스터 URL:", f"https://image.tmdb.org/t/p/original{poster['file_path']}")

    #TRAILER_URL
    if series_videos is not None:  
        print("예고편 URL:", f"https://www.youtube.com/watch?v={series_videos}")

def main():
    popular_tv_series = fetch_popular_series()

    for series in popular_tv_series:
        series_details = fetch_series_details(series['id'])
        series_images = fetch_series_images(series['id'])
        series_videos = fetch_series_videos(series['id']) 
        print_series_info(series_details, series_images, series_videos) 
        print()

if __name__ == "__main__":
    main()
# Out:
# 장르:
# 범죄
# 드라마
# 미스터리
# id: 2734
# 제목: 로 앤 오더: 성범죄 전담반
# 장르: 범죄, 드라마, 미스터리
# 시즌 수: 25
# 줄거리: 추악한 성범죄를 수사하는 뉴욕 경찰 성범죄전담수사반의 활약을 그린 드라마.
# 등급: 15
# 출연진:
# 마리슈카 하기테이
# Ice-T
# Peter Scanavino
# 제작진:
# Dick Wolf
# 로고 URL: https://image.tmdb.org/t/p/original/AhtQAQVcqWl6b0UZSo9vmHE3skK.png
# 포스터 URL: https://image.tmdb.org/t/p/original/onmSVwYsPMYtO8OjLdjS8FfRNKb.jpg
# 예고편 URL: https://www.youtube.com/watch?v=IRXNVdiqMuU
#
# 장르:
# 드라마
# id: 57243
# 제목: 닥터 후
# 장르: Action & Adventure, 드라마, Sci-Fi & Fantasy
# 시즌 수: 13
# 줄거리: 타임로드라는 종족의 외계인인 닥터가 그의 동료들과 함께 시공간을 누비는 여행을 하며 때때로 지구와 인류 그리고 우주를 구하는 이야기.
# 등급: 15
# 출연진:
# Jodie Whittaker
# Mandip Gill
# John Bishop
# 제작진:
# Claire Pritchard
# 로고 URL: https://image.tmdb.org/t/p/original/r6aeDXC3UE8PfzdorYfQWpPJTho.png
# 포스터 URL: https://image.tmdb.org/t/p/original/4edFyasCrkH4MKs6H4mHqlrxA6b.jpg
# 예고편 URL: https://www.youtube.com/watch?v=8L1kU45poro
#
# 장르:
# 코미디
# id: 4556
# 제목: Scrubs
# 장르: Comedy
# 시즌 수: 9
# 줄거리: In the unreal world of Sacred Heart Hospital, John "J.D." Dorian learns the ways of medicine, friendship and life.
# 등급: 12
# 출연진:
# Zach Braff
# Donald Faison
# John C. McGinley
# 제작진:
# Zach Braff
# 로고 URL: https://image.tmdb.org/t/p/original/6lCg07nxaLGpEap849catTySkvi.png
# 포스터 URL: https://image.tmdb.org/t/p/original/u1z05trCA7AuSuDhi365grwdos1.jpg
# 예고편 URL: https://www.youtube.com/watch?v=zOgb3KIJDY8
#
# 장르:
# 드라마
# 미스터리
# 범죄
# id: 1620
# 제목: CSI: 마이애미
# 장르: 드라마, 미스터리, 범죄
# 시즌 수: 10
# 줄거리: 플로리다 주의 마이애미 데이드 경찰청. 호레이쇼 반장과 CSI 과학 수사 대원들은 논리적인 증거 분석과 본능적인 수사로 마이애미에서 일어나는 위험한 범죄들을 해결해나간다.
# 등급: 15
# 출연진:
# David Caruso
# Emily Procter
# Omar Benson Miller
# 제작진:
# Jerry Bruckheimer
# 로고 URL: https://image.tmdb.org/t/p/original/gnThzFN5qgTW3vKLl5mVlqRBQ5T.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pNW64pjaHvf6purNaFhq4SHYRfl.jpg
# 예고편 URL: https://www.youtube.com/watch?v=x2n-h9E8_ck
#
# 장르:
# 드라마
# 범죄
# id: 4376
# 제목: JAG
# 장르: Drama, Action & Adventure, Crime
# 시즌 수: 10
# 줄거리: Harmon "Harm" Rabb Jr. is a former pilot turned lawyer working for the military's JAG (Judge Advocate General) division, the elite legal wing of officers that prosecutes and defends those accused of military-related crimes. He works closely with Lt. Col. Sarah Mackenzie, and together they do what needs to be done to find the truth.
# 등급: 16
# 출연진:
# David James Elliott
# Catherine Bell
# Patrick Labyorteaux
# 제작진:
# Donald P. Bellisario
# 로고 URL: https://image.tmdb.org/t/p/original/ac4uUoKUD0kTxXHm04dp7u10ksc.png
# 포스터 URL: https://image.tmdb.org/t/p/original/zPyHpkJZ5O08lbgrQQIROXtb3xz.jpg
#
# 장르:
# 드라마
# id: 4604
# 제목: 스몰빌
# 장르: Sci-Fi & Fantasy, Action & Adventure, 드라마
# 시즌 수: 10
# 줄거리: 우리에게 슈퍼맨으로 친숙한 클라크 켄트의 유년기를 새로이 재조명한 워너 브라더스사의 SF시리즈물 드라마
# 등급: 15
# 출연진:
# Tom Welling
# Erica Durance
# Cassidy Freeman
# 제작진:
# Alfredo Septién
# 로고 URL: https://image.tmdb.org/t/p/original/ePZAsSSkT2G0j1F1U13ZE675N6I.png
# 포스터 URL: https://image.tmdb.org/t/p/original/pUhJGETy2sec4vEkiqJ9eGeIywc.jpg
# 예고편 URL: https://www.youtube.com/watch?v=70Y32si4yb8
#
# 장르:
# 범죄
# 드라마
# id: 1412
# 제목: 애로우
# 장르: 범죄, 드라마, Action & Adventure
# 시즌 수: 8
# 줄거리: 스탈링 시티의 잘나가는 재벌 2세 올리버 퀸은 아버지와 보트 여행에 나섰다가 태풍을 만나 난파를 당한다. 그는 5년 동안 외딴 섬에 표류되어 생존을 위한 처절한 사투를 벌이고 마침내 고향으로 돌아온다. 아버지의 유언에 따라 스탈링 시티의 엘리트 범죄자들을 사냥하기위해 스스로 자경단원을 자처하는 올리버퀸. 그러나 그의 앞날에는 그의 상상보다 더 큰 진실과 음모가 기다리고 있는데...
# 등급: 15
# 출연진:
# Stephen Amell
# David Ramsey
# Katie Cassidy
# 제작진:
# Mark Bunting
# 로고 URL: https://image.tmdb.org/t/p/original/jUu02PexmdU5xAeDYsv1huceChE.png
# 포스터 URL: https://image.tmdb.org/t/p/original/gKG5QGz5Ngf8fgWpBsWtlg5L2SF.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qo6hU98dXOc
#
# 장르:
# 드라마
# id: 1416
# 제목: 그레이 아나토미
# 장르: 드라마
# 시즌 수: 20
# 줄거리: 시애틀에 있는 병원 의사들의 삶에 대한 이야기. 의사로서의 감정과 개인적인 감정에 대한 묘사가 적절히 조화를 이루어 그려진다. 인턴이지만 결국 레지던트가 되는 메러디스 그레이는 시애틀 병원의 동료 의사들과 함께 사적, 직업적인 열정에 휩쓸리는 자신을 발견한다.
# 등급: 19
# 출연진:
# 엘렌 폼페오
# Chandra Wilson
# James Pickens Jr.
# 제작진:
# 숀다 라임스
# 로고 URL: https://image.tmdb.org/t/p/original/keAZqhg9lmOHEhmG5njqIsuxf0f.png
# 포스터 URL: https://image.tmdb.org/t/p/original/jcEl8SISNfGdlQFwLzeEtsjDvpw.jpg
# 예고편 URL: https://www.youtube.com/watch?v=qbkEtYz9acA
#
# 장르:
# 코미디
# 드라마
# 미스터리
# id: 1981
# 제목: Charmed
# 장르: Comedy, Drama, Mystery, Sci-Fi & Fantasy
# 시즌 수: 8
# 줄거리: Three sisters (Prue, Piper and Phoebe) reunite and unlock their powers to become the Charmed Ones, the most powerful good witches of all time, whose prophesied destiny is to protect innocent lives from evil beings such as demons and warlocks. Each sister possesses unique magical powers that grow and evolve, while they attempt to maintain normal lives in modern day San Francisco.
# 등급: 12
# 출연진:
# Holly Marie Combs
# Alyssa Milano
# Brian Krause
# 제작진:
# Holly Marie Combs
# 로고 URL: https://image.tmdb.org/t/p/original/dd7ULvZWBk0EL7PrnfoeE7cpSC7.png
# 포스터 URL: https://image.tmdb.org/t/p/original/z4bPJ1BWU2EtV69NII2GVvsugQ2.jpg
#
# 장르:
# Talk
# id: 82873
# 제목: The Kelly Clarkson Show
# 장르: Talk
# 시즌 수: 5
# 줄거리: Kelly Clarkson presents the biggest newsmakers and names in film, television and music; as well as emerging new talent and everyday people who are beacons of hope in their communities.
# 등급: None
# 출연진:
# Kelly Clarkson
# 제작진:
# 포스터 URL: https://image.tmdb.org/t/p/original/9Gg1oM8Us8gCS5aJA8e0ZRuIHnf.jpg
# 예고편 URL: https://www.youtube.com/watch?v=BhrdON83gqk
#
# 장르:
# 코미디
# id: 59941
# 제목: The Tonight Show Starring Jimmy Fallon
# 장르: Comedy, Talk
# 시즌 수: 11
# 줄거리: After Jay Leno's second retirement from the program, Jimmy Fallon stepped in as his permanent replacement. After 42 years in Los Angeles the program was brought back to New York.
# 등급: 16
# 출연진:
# Jimmy Fallon
# Steve Higgins
# 제작진:
# Lorne Michaels
# 포스터 URL: https://image.tmdb.org/t/p/original/g4amxJvtpnY79J77xeamnAEUO8r.jpg
#
# 장르:
# 범죄
# 드라마
# 미스터리
# id: 1431
# 제목: CSI: 라스베가스
# 장르: 범죄, 드라마, 미스터리
# 시즌 수: 15
# 줄거리: 2000년 10월 CBS에서 방영을 시작한 범죄수사물. 최첨단 장비와 과학적인 분석으로 미궁속의 사건을 해결해 가는 라스베가스 시경 과학수사과 심야근무반. 17년 경력의 베테랑 길 그리섬, 혼자서 키우는 딸과 직장 사이에 균형을 잃지 않으며 항상 최선을 다하는 캐서린 윌로스, 도박의 유혹을 뿌리치지 못하지만 날카로운 분석력을 보유한 워릭 브라운, 하바드 출신의 새라 사이들, 그리고 매력적인 남자 닉 스톡스 등 5명이 한 팀으로 구성된 이들은 사건이 미궁에 빠질 때마다 첨단 기술과 예리한 분석력으로 결정적인 단서와 증거를 확보하여 진범을 가려내기 위해 365일 24시간을 투자한다.
# 등급: 15
# 출연진:
# Ted Danson
# George Eads
# Jorja Fox
# 제작진:
# Andi Brittan
# 로고 URL: https://image.tmdb.org/t/p/original/fLhKSEsurxHq3mwEDvCQhnApxkg.png
# 포스터 URL: https://image.tmdb.org/t/p/original/i5hmoRjHNWady4AtAGICTUXknKH.jpg
# 예고편 URL: https://www.youtube.com/watch?v=ApT1EYvrwuk
#
# 장르:
# 범죄
# 드라마
# id: 1438
# 제목: 더 와이어
# 장르: 범죄, 드라마
# 시즌 수: 5
# 줄거리: 2002년 6월 HBO에서 방영을 시작한 범죄수사물. 볼티모어에서 일어난 살인 사건의 범인으로 지목된 마약 딜러 에이본 박스데일의 조카 디안젤로. 그가 증인의 진술 번복으로 풀려나자 이를 수상하게 여긴 강력계 형사 맥널티는 특별전담팀을 꾸린다.
# 등급: 19
# 출연진:
# Dominic West
# 랜스 레딕
# Sonja Sohn
# 제작진:
# Joe Chappelle
# 로고 URL: https://image.tmdb.org/t/p/original/cP5IrOYxU7qtFl3Gyjtj9iPufCn.png
# 포스터 URL: https://image.tmdb.org/t/p/original/4lbclFySvugI51fwsyxBTOm4DqK.jpg
# 예고편 URL: https://www.youtube.com/watch?v=uDcQbk78CSw
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 191
#     188         print()
#     190 if __name__ == "__main__":
# --> 191     main()
#
# Cell In[3], line 184, in main()
#     181 popular_tv_series = fetch_popular_series()
#     183 for series in popular_tv_series:
# --> 184     series_details = fetch_series_details(series['id'])
#     185     series_images = fetch_series_images(series['id'])
#     186     series_videos = fetch_series_videos(series['id'])
#
# Cell In[3], line 67, in fetch_series_details(series_id, language)
#      60 url = f'https://api.themoviedb.org/3/tv/{series_id}'
#      61 params = {
#      62     'api_key': TMDB_API_KEY,
#      63     'language': language,
#      64     'append_to_response': 'credits'  # 출연진 및 제작진 정보
#      65 }
# ---> 67 response = requests.get(url, params=params)
#      68 data = response.json()
#      70 #GENRE
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\USER\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
#     466     # Trigger any extra validation we need to do.
#     467     try:
# --> 468         self._validate_conn(conn)
#     469     except (SocketTimeout, BaseSSLError) as e:
#     470         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1095 # Force connect early to allow us to validate the connection.
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#    1100     warnings.warn(
#    1101         (
#    1102             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1107         InsecureRequestWarning,
#    1108     )
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\connection.py:783, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     780     if is_ipaddress(normalized):
#     781         server_hostname = normalized
# --> 783 ssl_sock = ssl_wrap_socket(
#     784     sock=sock,
#     785     keyfile=key_file,
#     786     certfile=cert_file,
#     787     key_password=key_password,
#     788     ca_certs=ca_certs,
#     789     ca_cert_dir=ca_cert_dir,
#     790     ca_cert_data=ca_cert_data,
#     791     server_hostname=server_hostname,
#     792     ssl_context=context,
#     793     tls_in_tls=tls_in_tls,
#     794 )
#     796 try:
#     797     if assert_fingerprint:
#
# File c:\Users\USER\anaconda3\Lib\site-packages\urllib3\util\ssl_.py:446, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     444 if ca_certs or ca_cert_dir or ca_cert_data:
#     445     try:
# --> 446         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     447     except OSError as e:
#     448         raise SSLError(e) from e
#
# KeyboardInterrupt:
